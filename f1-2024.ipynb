# %% [markdown]
# # Modelling Formula 1 Outcomes for Fantasy EV Projections

# %% [markdown]
# F1 Fantasy is well-suited to optimisation when compared to other fantasy sports. The problem space is relatively small - a team consists of only 5 assets, chosen from a pool of 30. You can also change half of your assets each race without a penalty, so planning more than 1 week ahead is almost always unneccesary. This makes for a much easier challenge than e.g. FPL optimisation, where we are choosing 15 assets from hundreds in a multi-period problem. Many drivers are either far too expenisve to be viable at their price point or sufficiently inexpensive to make them essential. Marginal decisions exist, but are less common than in other fantasy sports, which makes modelling it quite forgiving.

# %%
# %pip install unidecode
# %pip install gurobipy
# %pip install pulp
# %pip install pandas
# %pip install unidecode
# %pip install seaborn
# %pip install scipy
# %pip install scikit-learn
# Out:
# Requirement already satisfied: unidecode in /opt/homebrew/lib/python3.11/site-packages (1.3.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gurobipy in /opt/homebrew/lib/python3.11/site-packages (11.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pulp in /opt/homebrew/lib/python3.11/site-packages (2.8.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: unidecode in /opt/homebrew/lib/python3.11/site-packages (1.3.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /opt/homebrew/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/homebrew/lib/python3.11/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=1.2 in /opt/homebrew/lib/python3.11/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/homebrew/lib/python3.11/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (1.12.0)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /opt/homebrew/lib/python3.11/site-packages (from scipy) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from itertools import product

import unidecode
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import optimize
from sklearn.linear_model import LinearRegression
import gurobipy as gp
from pulp import *

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# To play Formula 1 Fantasy optimally, we split our process into two parts: predicting outcomes from which we can develop expected value projections, and using these projections to optimize our team.
#
# First, we need to model a probability distribution of outcomes (i.e. the likelihood of each outcome to occur to each driver). We are deriving estimates for the probability of these outcomes from odds.

# %% [markdown]
# ## Converting Odds into Implied Probabilities

# %% [markdown]
# The first step is to collect our odds. I use the shortest decimal odds available (i.e. highest decimal) across spread markets and traditional bookmakers.
#
# The relevant markets are winner, podium finish, top 6 finish, points finish, fastest lap, and to finish unclassified.

# %%
#df = pd.read_csv('https://raw.githubusercontent.com/harryrgrove/F1_model/master/odds_input.csv', index_col=0)
#df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/odds_input_2022.csv', index_col=0)
df = pd.read_csv('odds_input_2024.csv', index_col=0)

df
# Out:
#                     team   winner    top3    top6  top10    flap   dnf
# driver
# Hamilton        Mercedes    10.00    8.00    1.22   1.15    3.25  6.50
# Verstappen      Red Bull     1.58    1.32    1.20   1.15    2.63  6.00
# Russell         Mercedes    20.00   18.00   14.00   3.00    7.00  5.00
# Perez           Red Bull     6.00    5.00    1.32   1.21    6.00  6.00
# Piastri          McLaren  3000.00  200.00  100.00  10.00   41.00  5.50
# Leclerc          Ferrari     2.00    1.90    1.45   1.25   19.00  5.00
# Alonso      Aston Martin  1001.00  500.00   66.00  10.00  251.00  5.00
# Gasly             Alpine   300.00   34.00   15.00   1.62  251.00  5.50
# Sainz            Ferrari     3.00    2.50    1.56   1.33   34.00  6.00
# Stroll      Aston Martin  1501.00  151.00   50.00   4.00  251.00  5.00
# Norris           McLaren   276.00   50.00   22.00  10.00   41.00  5.50
# Ricciardo             RB    67.00    7.00    1.75   1.33   51.00  5.00
# Ocon              Alpine  1001.00  101.00  100.00   3.25  251.00  5.00
# Zhou              Sauber  2001.00  151.00  100.00  10.00  251.00  5.50
# Tsunoda               RB  1001.00  200.00  100.00  10.00  251.00  4.00
# Bottas            Sauber    60.00   20.00    2.00   1.50  251.00  5.00
# Sargeant        Williams  2001.00  501.00  101.00   7.00  501.00  5.00
# Albon           Williams  2001.00  151.00  100.00   3.40  251.00  5.00
# Hulkenberg          Haas   500.00  300.00   55.00   3.00  501.00  5.00
# Magnussen           Haas   400.00  200.00   10.00   2.00  501.00  3.75

# %% [markdown]
# The basic implied probability from these projections can be obtained by finding their multiplicative inverse:

# %%
odds_cols = ['winner', 'top3', 'top6', 'top10', 'flap', 'dnf']
for col in odds_cols:
    df[col] **= -1
df
# Out:
#                     team    winner      top3      top6     top10      flap  \
# driver
# Hamilton        Mercedes  0.100000  0.125000  0.819672  0.869565  0.307692
# Verstappen      Red Bull  0.632911  0.757576  0.833333  0.869565  0.380228
# Russell         Mercedes  0.050000  0.055556  0.071429  0.333333  0.142857
# Perez           Red Bull  0.166667  0.200000  0.757576  0.826446  0.166667
# Piastri          McLaren  0.000333  0.005000  0.010000  0.100000  0.024390
# Leclerc          Ferrari  0.500000  0.526316  0.689655  0.800000  0.052632
# Alonso      Aston Martin  0.000999  0.002000  0.015152  0.100000  0.003984
# Gasly             Alpine  0.003333  0.029412  0.066667  0.617284  0.003984
# Sainz            Ferrari  0.333333  0.400000  0.641026  0.751880  0.029412
# Stroll      Aston Martin  0.000666  0.006623  0.020000  0.250000  0.003984
# Norris           McLaren  0.003623  0.020000  0.045455  0.100000  0.024390
# Ricciardo             RB  0.014925  0.142857  0.571429  0.751880  0.019608
# Ocon              Alpine  0.000999  0.009901  0.010000  0.307692  0.003984
# Zhou              Sauber  0.000500  0.006623  0.010000  0.100000  0.003984
# Tsunoda               RB  0.000999  0.005000  0.010000  0.100000  0.003984
# Bottas            Sauber  0.016667  0.050000  0.500000  0.666667  0.003984
# Sargeant        Williams  0.000500  0.001996  0.009901  0.142857  0.001996
# Albon           Williams  0.000500  0.006623  0.010000  0.294118  0.003984
# Hulkenberg          Haas  0.002000  0.003333  0.018182  0.333333  0.001996
# Magnussen           Haas  0.002500  0.005000  0.100000  0.500000  0.001996
#
#                  dnf
# driver
# Hamilton    0.153846
# Verstappen  0.166667
# Russell     0.200000
# Perez       0.166667
# Piastri     0.181818
# Leclerc     0.200000
# Alonso      0.200000
# Gasly       0.181818
# Sainz       0.166667
# Stroll      0.200000
# Norris      0.181818
# Ricciardo   0.200000
# Ocon        0.200000
# Zhou        0.181818
# Tsunoda     0.250000
# Bottas      0.200000
# Sargeant    0.200000
# Albon       0.200000
# Hulkenberg  0.200000
# Magnussen   0.266667

# %% [markdown]
# Probabilities implied directly odds are never optimal to begin with because they are overrounded. There are many ways to adjust for this, as explained in this paper: http://article.sciencepublishinggroup.com/pdf/10.11648.j.ajss.20170506.12.pdf
#
# We will be using the "power" adjustment method favoured by the paper's authors. For example, if we want a column of probabilities to add to 1 (e.g. for race winner, since there can be only 1 winner), then we must raise each probability $p_i$ to the same exponent $k$, such that the sum of the probabilities raised to $k$ equals the desired total $T$, i.e. we want $k$ such that $\sum_{i=1}^{20}p_i^k=T$

# %%
def adjust_odds(odds_series, target_sum, method='power'):
    if method == 'power':
        def f(x):
            return sum([i**x for i in odds_series]) - target_sum
        k = optimize.fsolve(f, 1) # optimise k such that the sum of p_i^k - T = 0
        return odds_series ** k
    elif method == 'linear':
        return odds_series / sum(odds_series) * target_sum

# %% [markdown]
# We want the winner column to add to 1, the top 3 column to add to 3, etc.

# %%
for col, target in zip(odds_cols[:-1], [1, 3, 6, 10, 1]):
    df[col] = adjust_odds(df[col], target)
df
# Out:
#                     team    winner      top3      top6     top10      flap  \
# driver
# Hamilton        Mercedes  0.020113  0.189865  0.855886  0.894565  0.272704
# Verstappen      Red Bull  0.460229  0.801057  0.867029  0.894565  0.344377
# Russell         Mercedes  0.006205  0.099325  0.126782  0.416525  0.117044
# Perez           Red Bull  0.047846  0.276397  0.804712  0.859021  0.138725
# Piastri          McLaren  0.000001  0.014505  0.027216  0.159516  0.016674
# Leclerc          Ferrari  0.308529  0.598798  0.747680  0.837035  0.038930
# Alonso      Aston Martin  0.000008  0.006975  0.037675  0.159516  0.002262
# Gasly             Alpine  0.000063  0.059755  0.120118  0.680731  0.002262
# Sainz            Ferrari  0.155079  0.480897  0.706095  0.796647  0.020496
# Stroll      Aston Martin  0.000004  0.018156  0.046818  0.331162  0.002262
# Norris           McLaren  0.000072  0.043909  0.089010  0.159516  0.016674
# Ricciardo             RB  0.000798  0.211242  0.645360  0.796647  0.013108
# Ocon              Alpine  0.000008  0.025037  0.027216  0.390777  0.002262
# Zhou              Sauber  0.000003  0.018156  0.027216  0.159516  0.002262
# Tsunoda               RB  0.000008  0.014505  0.027216  0.159516  0.002262
# Bottas            Sauber  0.000962  0.091306  0.581324  0.723804  0.002262
# Sargeant        Williams  0.000003  0.006964  0.027005  0.211978  0.001056
# Albon           Williams  0.000003  0.018156  0.027216  0.376970  0.002262
# Hulkenberg          Haas  0.000026  0.010491  0.043453  0.416525  0.001056
# Magnussen           Haas  0.000039  0.014505  0.164973  0.575467  0.001056
#
#                  dnf
# driver
# Hamilton    0.153846
# Verstappen  0.166667
# Russell     0.200000
# Perez       0.166667
# Piastri     0.181818
# Leclerc     0.200000
# Alonso      0.200000
# Gasly       0.181818
# Sainz       0.166667
# Stroll      0.200000
# Norris      0.181818
# Ricciardo   0.200000
# Ocon        0.200000
# Zhou        0.181818
# Tsunoda     0.250000
# Bottas      0.200000
# Sargeant    0.200000
# Albon       0.200000
# Hulkenberg  0.200000
# Magnussen   0.266667

# %% [markdown]
# We also need to adjust our DNF odds, since currently they may show a driver's DNF probability and top 10 probability to add to more than 1, which is of course impossible.
#
# We can adjust these under the assumption that given a top driver finishes the race, they are 96% likely to finish in the top 10:

# %%
df['dnf'] **= (np.log(0.96 - df['top10']) / np.log(df['dnf'])).max()
df['winner'] = df[['winner', 'top3']].min(axis=1)
df
# Out:
#                     team    winner      top3      top6     top10      flap  \
# driver
# Hamilton        Mercedes  0.020113  0.189865  0.855886  0.894565  0.272704
# Verstappen      Red Bull  0.460229  0.801057  0.867029  0.894565  0.344377
# Russell         Mercedes  0.006205  0.099325  0.126782  0.416525  0.117044
# Perez           Red Bull  0.047846  0.276397  0.804712  0.859021  0.138725
# Piastri          McLaren  0.000001  0.014505  0.027216  0.159516  0.016674
# Leclerc          Ferrari  0.308529  0.598798  0.747680  0.837035  0.038930
# Alonso      Aston Martin  0.000008  0.006975  0.037675  0.159516  0.002262
# Gasly             Alpine  0.000063  0.059755  0.120118  0.680731  0.002262
# Sainz            Ferrari  0.155079  0.480897  0.706095  0.796647  0.020496
# Stroll      Aston Martin  0.000004  0.018156  0.046818  0.331162  0.002262
# Norris           McLaren  0.000072  0.043909  0.089010  0.159516  0.016674
# Ricciardo             RB  0.000798  0.211242  0.645360  0.796647  0.013108
# Ocon              Alpine  0.000008  0.025037  0.027216  0.390777  0.002262
# Zhou              Sauber  0.000003  0.018156  0.027216  0.159516  0.002262
# Tsunoda               RB  0.000008  0.014505  0.027216  0.159516  0.002262
# Bottas            Sauber  0.000962  0.091306  0.581324  0.723804  0.002262
# Sargeant        Williams  0.000003  0.006964  0.027005  0.211978  0.001056
# Albon           Williams  0.000003  0.018156  0.027216  0.376970  0.002262
# Hulkenberg          Haas  0.000026  0.010491  0.043453  0.416525  0.001056
# Magnussen           Haas  0.000039  0.014505  0.164973  0.575467  0.001056
#
#                  dnf
# driver
# Hamilton    0.057931
# Verstappen  0.065435
# Russell     0.086359
# Perez       0.065435
# Piastri     0.074699
# Leclerc     0.086359
# Alonso      0.086359
# Gasly       0.074699
# Sainz       0.065435
# Stroll      0.086359
# Norris      0.074699
# Ricciardo   0.086359
# Ocon        0.086359
# Zhou        0.074699
# Tsunoda     0.121279
# Bottas      0.086359
# Sargeant    0.086359
# Albon       0.086359
# Hulkenberg  0.086359
# Magnussen   0.133795

# %% [markdown]
# ## Estimating Race Finishing Position Distributions

# %% [markdown]
# After adjusting our odds, we can move on to looking at the probability distributions they imply.
#
# If we assume the probabilities are as uniform as the odds could possibly imply, this is what the implied distribution looks like for Pierre Gasly:

# %%
def get_probs(idx):
    probs = [df.loc[idx, 'winner']]
    probs += [(df.loc[idx, 'top3'] - df.loc[idx, 'winner'])/2] * 2
    probs += [(df.loc[idx, 'top6'] - df.loc[idx, 'top3']) / 3] * 3
    probs += [(df.loc[idx, 'top10'] - df.loc[idx, 'top6']) / 4] * 4
    probs += [(1 - df.loc[idx, 'top10'] - df.loc[idx, 'dnf']) / 10] * 10
    probs.append(df.loc[idx, 'dnf'])
    return probs

driver = 'Alonso'

plt.bar(['P{}'.format(i) for i in range(1, 21)] + ['DNF'], get_probs(driver))
plt.xticks(rotation=90)
plt.ylabel('likelihood')
plt.show()

# %% [markdown]
# If we wanted, we could calculate expected value projections using these uniform distributions, and this would work fine. To improve them slightly (and also for the sake of fun), we want them to resemble a bell-curve. An easy way to do this is to minimize the squared difference between the implied probabilities of consecutive finishes, which can be done with quadratic optimisation.
#
# In other words, for each driver we need to solve the following optimisation problem, given $p_i$ is the probability a driver finishes in position $i$:
#
# $$\text{Minimise} \ \sum_{i=1}^{19} (p_{i+1} - p_i)^2$$
#
# $$\text{Subject to: } \ p_1 = P(\text{win}); \ \ \sum_{i=1}^3 p_i = P(\text{podium finish}); \ \ \sum_{i=1}^6 p_i = P(\text{top 6 finish}); \\ \sum_{i=1}^{10} p_i = P(\text{points finish}); \ \ \sum_{i=11}^{20} p_i = 1 - P(\text{points finish}) - P(\text{dnf}).$$
#
# Let's first demonstrate on Gasly's probability distribution:

# %%
quadratic_model = gp.Model('quadratic')
quadratic_model.setParam('outputFlag', False)
driver = 'Hamilton'
# Add the probability of finishing in each position as a model variable
x = {i: quadratic_model.addVar(vtype=gp.GRB.CONTINUOUS, lb=0, ub=1, name=f'x_{i}') for i in range(1, 21)}
# Set objective to minimize the differences between probabilities of consecutive positions
obj = sum([(x[i] - x[i + 1])**2 for i in range(1, 20)])
quadratic_model.setObjective(obj, gp.GRB.MINIMIZE)
# Set model constraints
quadratic_model.addConstr(x[1] == df.loc[driver, 'winner'])
quadratic_model.addConstr(x[2] + x[3] == df.loc[driver, 'top3'] - df.loc[driver, 'winner'])
quadratic_model.addConstr(x[4] + x[5] + x[6] == df.loc[driver, 'top6'] - df.loc[driver, 'top3'])
quadratic_model.addConstr(x[7] + x[8] + x[9] + x[10] == df.loc[driver, 'top10'] - df.loc[driver, 'top6'])
quadratic_model.addConstr(sum([x[i] for i in range(11, 21)]) == 1 - df.loc[driver, 'top10'] - df.loc[driver, 'dnf'])
if df.loc[driver, 'top10'] >= 0.5:
    quadratic_model.addConstr(x[20] == 0)
# Optimize model parameters
quadratic_model.optimize()
vals = [v.x for v in quadratic_model.getVars()]
plt.bar(['P{}'.format(i) for i in range(1, 21)] + ['DNF'], vals + [df.loc[driver, 'dnf']])
plt.xticks(rotation=90)
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# Much more satisfying! Now we can apply this method to all other drivers:

# %%
pos_dict = {}

for driver in df.index:
    print(driver)
    quadratic_model = gp.Model('quadratic')
    quadratic_model.setParam('outputFlag', False)
    x = {i: quadratic_model.addVar(vtype=gp.GRB.CONTINUOUS, lb=0, ub=1, name=f'x_{i}') for i in range(1, 21)}
    obj = sum([(x[i] - x[i + 1])**2 for i in range(1, 20)])
    quadratic_model.setObjective(obj, gp.GRB.MINIMIZE)
    quadratic_model.addConstr(x[1] == df.loc[driver, 'winner'])
    quadratic_model.addConstr(x[2] + x[3] == df.loc[driver, 'top3'] - df.loc[driver, 'winner'])
    quadratic_model.addConstr(x[4] + x[5] + x[6] == df.loc[driver, 'top6'] - df.loc[driver, 'top3'])
    quadratic_model.addConstr(x[7] + x[8] + x[9] + x[10] == df.loc[driver, 'top10'] - df.loc[driver, 'top6'])
    quadratic_model.addConstr(sum([x[i] for i in range(11, 21)]) == 1 - df.loc[driver, 'top10'] - df.loc[driver, 'dnf'])
    quadratic_model.optimize()
    # print(quadratic_model.getVars())
    pos_dict[driver] = {i + 1: v.x for i, v in enumerate(quadratic_model.getVars())}
# Out:
# Hamilton
# Verstappen
# Russell
# Perez
# Piastri
# Leclerc
# Alonso
# Gasly
# Sainz
# Stroll
# Norris
# Ricciardo
# Ocon
# Zhou
# Tsunoda
# Bottas
# Sargeant
# Albon
# Hulkenberg
# Magnussen

# %% [markdown]
# We can store this information in a DataFrame $\texttt{pos_df}$, alongside other essential information such as mean projected position.

# %%
pos_df = pd.DataFrame(pos_dict).T
pos_df['dnf'] = df.dnf
pos_df['team'] = df.team
pos_df['mean_pos'] = sum([i / (1 - df['dnf']) * pos_df[i] for i in range(1, 21)])
pos_df.head(10).T
# Out:
#           Hamilton Verstappen    Russell     Perez    Piastri   Leclerc  \
# 1         0.020113   0.460229   0.006205  0.047846   0.000001  0.308529
# 2         0.050241   0.238868   0.045432  0.090658   0.006859  0.184757
# 3         0.119511    0.10196   0.047687  0.137893   0.007645  0.105512
# 4         0.227924   0.049506    0.01297  0.189552   0.002359  0.070793
# 5         0.250589   0.015756   0.001428  0.192381   0.002446  0.046239
# 6         0.187508    0.00071   0.013059  0.146381   0.007906   0.03185
# 7         0.038679   0.004367   0.047864  0.051551   0.018738  0.027627
# 8              0.0   0.006837   0.071615  0.002758   0.028806  0.023822
# 9              0.0   0.008119   0.084311       0.0   0.038109  0.020437
# 10             0.0   0.008212   0.085953       0.0   0.046648   0.01747
# 11        0.001234   0.007118   0.076539  0.001963   0.054422  0.014922
# 12        0.002344   0.006134   0.068067  0.003729   0.061419  0.012629
# 13        0.003331   0.005258   0.060537  0.005298   0.067638  0.010591
# 14        0.004195   0.004492   0.053948  0.006672    0.07308  0.008807
# 15        0.004936   0.003836     0.0483  0.007849   0.077745  0.007278
# 16        0.005552   0.003289   0.043593   0.00883   0.081632  0.006004
# 17        0.006046   0.002851   0.039828  0.009614   0.084741  0.004985
# 18        0.006416   0.002523   0.037004  0.010203   0.087074  0.004221
# 19        0.006663   0.002304   0.035121  0.010595   0.088629  0.003711
# 20        0.006786   0.002195    0.03418  0.010792   0.089406  0.003457
# dnf       0.057931   0.065435   0.086359  0.065435   0.074699  0.086359
# team      Mercedes   Red Bull   Mercedes  Red Bull    McLaren   Ferrari
# mean_pos  5.123597   2.504095  11.186895  5.217426  14.554374  3.858112
#
#                 Alonso     Gasly     Sainz        Stroll
# 1             0.000008  0.000063  0.155079      0.000004
# 2             0.002388  0.028944   0.17088      0.008854
# 3              0.00458  0.030748  0.154937      0.009298
# 4             0.006585  0.005477   0.10725      0.001337
# 5             0.009822  0.010142   0.07119      0.005509
# 6             0.014293  0.044743  0.046758      0.021814
# 7             0.019996  0.109281  0.033954      0.050252
# 8             0.026463  0.147445  0.024305      0.069961
# 9             0.033694  0.159235  0.017814       0.08094
# 10            0.041689  0.144652  0.014479      0.083191
# 11            0.050448  0.103696    0.0143      0.076712
# 12            0.058332  0.069504   0.01414      0.070881
# 13            0.065339  0.042075  0.013997      0.065698
# 14            0.071471  0.021411  0.013872      0.061163
# 15            0.076726   0.00751  0.013765      0.057276
# 16            0.081106  0.000373  0.013676      0.054037
# 17             0.08461       0.0  0.013604      0.051445
# 18            0.087238       0.0  0.013551      0.049502
# 19            0.088989       0.0  0.013515      0.048206
# 20            0.089865       0.0  0.013497      0.047558
# dnf           0.086359  0.074699  0.065435      0.086359
# team      Aston Martin    Alpine   Ferrari  Aston Martin
# mean_pos     14.559103  8.921967  5.237463      12.52395

# %% [markdown]
# We can also create another DataFrame $\texttt{ev_df}$, which will store all the expected value of all sources of points, such as race position, dnf penalty, etc.

# %%
ev_df = pd.DataFrame(index=df.index)
ev_df['race'] = 25 * pos_df[1] + 18 * pos_df[2] + 15 * pos_df[3] \
                 + 12 * pos_df[4] + 10 * pos_df[5] + 8 * pos_df[6] \
                 + 6 * pos_df[7] + 4 * pos_df[8] + 2 * pos_df[9] \
                 + pos_df[10] + (1 - pos_df['dnf']) * 1
ev_df['flap'] = df['flap'] * 5
ev_df['dnf'] = -15 * df['dnf']

ev_df.head()
# Out:
#                  race      flap       dnf
# driver
# Hamilton    11.115015  1.363521 -0.868960
# Verstappen  19.104632  1.721886 -0.981524
# Russell      3.704475  0.585222 -1.295385
# Perez       11.520791  0.693624 -0.981524
# Piastri      1.629998  0.083370 -1.120488

# %% [markdown]
# ## Modelling Sources of Points outside of Odds

# %% [markdown]
# Next, we must estimate the value of other sources of points based on these race position distributions.
#
# There is little/no market data on these categories, so we can attempt to infer the distributions from past data analysis of players with similar race end expectations (i.e. running a linear regression to formulate expectations, then building probability distributions from this expectation matrix). First we need to collect data, which I've already stored in csv files for race data and result data.

# %%
# race_df = pd.read_csv("https://raw.githubusercontent.com/harryrgrove/F1_model/master/races.csv")
race_df = pd.read_csv("f1db_csv/races.csv")
# result_df = pd.read_csv("https://raw.githubusercontent.com/harryrgrove/F1_model/master/results.csv")
result_df = pd.read_csv("f1db_csv/results.csv")

race_df
# Out:
#       raceId  year  round  circuitId                    name        date  \
# 0          1  2009      1          1   Australian Grand Prix  2009-03-29
# 1          2  2009      2          2    Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17      Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3      Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4      Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                     ...         ...
# 1120    1140  2024     20         32  Mexico City Grand Prix  2024-10-27
# 1121    1141  2024     21         18    São Paulo Grand Prix  2024-11-03
# 1122    1142  2024     22         80    Las Vegas Grand Prix  2024-11-23
# 1123    1143  2024     23         78        Qatar Grand Prix  2024-12-01
# 1124    1144  2024     24         24    Abu Dhabi Grand Prix  2024-12-08
#
#           time                                                url fp1_date  \
# 0     06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1     09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2     07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3     12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4     12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
# ...        ...                                                ...      ...
# 1120        \N  https://en.wikipedia.org/wiki/2024_Mexico_City...       \N
# 1121        \N  https://en.wikipedia.org/wiki/2024_S%C3%A3o_Pa...       \N
# 1122        \N  https://en.wikipedia.org/wiki/2024_Las_Vegas_G...       \N
# 1123        \N  https://en.wikipedia.org/wiki/2024_Qatar_Grand...       \N
# 1124        \N  https://en.wikipedia.org/wiki/2024_Abu_Dhabi_G...       \N
#
#      fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# 0          \N       \N       \N       \N       \N         \N         \N
# 1          \N       \N       \N       \N       \N         \N         \N
# 2          \N       \N       \N       \N       \N         \N         \N
# 3          \N       \N       \N       \N       \N         \N         \N
# 4          \N       \N       \N       \N       \N         \N         \N
# ...       ...      ...      ...      ...      ...        ...        ...
# 1120       \N       \N       \N       \N       \N         \N         \N
# 1121       \N       \N       \N       \N       \N         \N         \N
# 1122       \N       \N       \N       \N       \N         \N         \N
# 1123       \N       \N       \N       \N       \N         \N         \N
# 1124       \N       \N       \N       \N       \N         \N         \N
#
#      sprint_date sprint_time
# 0             \N          \N
# 1             \N          \N
# 2             \N          \N
# 3             \N          \N
# 4             \N          \N
# ...          ...         ...
# 1120          \N          \N
# 1121          \N          \N
# 1122          \N          \N
# 1123          \N          \N
# 1124          \N          \N
#
# [1125 rows x 18 columns]

# %%
# Gather IDs of all races
race_dict = {}
for year in range(2021, 2024):
    races = race_df[race_df['year']==year]['raceId'].tolist()
    race_dict[year] = races
    
# We are interested in how mean race position predicts mean grid position, mean fantasy points from quali, 
# % of Q2 finishes, % of Q3 finishes, and mean number of positions gained.
values = {'grid': [], 'position': [], 'fantasy': [], 'top10': [], 'top15': [], 'mean_gain': []}

# Iterate through the result data to collect these data points for each driver who raced more than 15
# times in a season since 2015
for year in race_dict:
    season_df = result_df[result_df['raceId'].isin(race_dict[year])]
    drivers = season_df['driverId'].unique()
    for driver in drivers:
        driver_df = season_df[season_df['driverId']==driver]
        grid_pos_df = driver_df[['grid', 'position']][driver_df['position'].str.isnumeric() & (driver_df['grid'] != 0)]
        grid_pos_df['grid'] = grid_pos_df['grid'].astype(float)
        grid_pos_df['position'] = grid_pos_df['position'].astype(float)
        
        if len(grid_pos_df) > 15:
            values['grid'].append(grid_pos_df['grid'].mean())
            values['position'].append(grid_pos_df['position'].mean())
            values['fantasy'].append(sum([sum(grid_pos_df['grid']==i) * 
                                          (11 - i) for i in range(1, 11)]) / len(grid_pos_df))
            values['top10'].append(sum(grid_pos_df['grid'] <= 10) / len(grid_pos_df))
            values['top15'].append(sum(grid_pos_df['grid'] <= 15) / len(grid_pos_df))

            total = 0
            for idx in grid_pos_df.index:
                if grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position'] > 0:
                    total += min(10, (grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position']) * 2)
                elif grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position'] < 0:
                    if grid_pos_df.loc[idx, 'grid'] <= 10:
                        total += max(-10, (grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position']) * 2)
                    else:
                        total += max(-5, grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position'])
            values['mean_gain'].append(total / len(grid_pos_df))

# %%
result_df = pd.DataFrame(values)
result_df.head()
# Out:
#        grid  position   fantasy     top10     top15  mean_gain
# 0  3.047619  2.761905  7.952381  0.952381  1.000000   0.857143
# 1  3.052632  1.842105  8.421053  0.947368  0.947368   1.157895
# 2  5.777778  5.000000  6.055556  0.833333  0.888889   0.666667
# 3  6.904762  6.619048  4.714286  0.857143  0.952381   0.380952
# 4  5.500000  5.250000  5.500000  0.937500  1.000000   1.500000

# %% [markdown]
# First, let's model the points we expect from qualifying position from mean race finishing position. As seen below, this relationaship can be appropriately captured with a polynomial interpolation (degree 2).

# %%
sns.scatterplot(x='position', y='fantasy', data=result_df)
weights = np.polyfit(result_df['position'], result_df['fantasy'], 2)
model = np.poly1d(weights)
x = np.linspace(1, 17)
y = model(x)

y_pred = model(result_df['position'])

plt.plot(x, y)
plt.show()

# %% [markdown]
# From this relationship we can build a function to predict qualifying EV from mean race position.

# %%
def qual_pts(pos):
    weights = np.polyfit(result_df['position'], result_df['fantasy'], 2)
    model = np.poly1d(weights)
    return max(model(pos), 0)

# %% [markdown]
# Next, let's do the same for modelling the probability of completing Q2 given a mean race position. A logistic relationship is clear in this case.

# %%
result_df = result_df.sort_values(by='position')
sns.scatterplot(x=result_df['position'], y=result_df['top10'])

x = result_df['position'].to_numpy()
y = result_df['top10'].to_numpy()

def f(x, a, b, c, d):
    return a / (1. + np.exp(-c * (x - d))) + b

popt, pcov = optimize.curve_fit(f, x, y, method="trf")
y_fit = f(x, *popt)
plt.plot(x, y_fit, '-')
plt.show()

# %% [markdown]
# From this relationship, we can model the number of points expected from Q2 appearance.

# %%
def q2_finish_pts(pos):
    x = result_df['position'].to_numpy()
    y = result_df['top10'].to_numpy()

    def f(x, a, b, c, d):
        return a / (1. + np.exp(-c * (x - d))) + b

    popt, pcov = optimize.curve_fit(f, x, y, method="trf")
    return f(pos, *popt) * 2

# %% [markdown]
# Next, let's look at Q3 finishes. We can use the same logistic regression model as a reasonable estimate.

# %%
result_df = result_df.sort_values(by='position')
sns.scatterplot(x=result_df['position'], y=result_df['top15'])

x = result_df['position'].to_numpy()
y = result_df['top15'].to_numpy()

def f(x, a, b, c, d):
    return a / (1. + np.exp(-c * (x - d))) + b

popt, pcov = optimize.curve_fit(f, x, y, method="trf")
y_fit = f(x, *popt)
plt.plot(x, y_fit, '-')
plt.show()

# %%
def q3_finish_pts(pos):
    x = result_df['position'].to_numpy()
    y = result_df['top15'].to_numpy()

    def f(x, a, b, c, d):
        return a / (1. + np.exp(-c * (x - d))) + b

    popt, pcov = optimize.curve_fit(f, x, y, method="trf")
    return max(f(pos, *popt) * 3, 0)

# %% [markdown]
# Next, we want to look at modeling the relationship between expected race finish position and how many places one can be expected to gain in the race. A very loose but statistically significant correlation exists here.

# %%
sns.lmplot(x='position', y='mean_gain', data=result_df)
plt.show()

# %%
def gain_pts(pos):  
    x, y = result_df['position'].values.reshape(-1, 1), result_df['mean_gain'].values.reshape(-1,1)
    reg = LinearRegression().fit(x, y)
    return reg.predict(np.array(pos).reshape(-1, 1))[0][0]

# %% [markdown]
# We can add the expected points from these new sources to $\texttt{ev_df}$

# %%
ev_df['qual'] = [qual_pts(i) for i in pos_df['mean_pos']]
ev_df['gain'] = [gain_pts(i) for i in pos_df['mean_pos']]
ev_df['q'] = [q2_finish_pts(i) + q3_finish_pts(i) for i in pos_df['mean_pos']]
ev_df.head()
# Out:
#                  race      flap       dnf      qual      gain         q
# driver
# Hamilton    11.115015  1.363521 -0.868960  5.242566  1.584842  4.568430
# Verstappen  19.104632  1.721886 -0.981524  7.726510  1.442411  4.730361
# Russell      3.704475  0.585222 -1.295385  1.292876  1.914522  2.965620
# Perez       11.520791  0.693624 -0.981524  5.162296  1.589943  4.558786
# Piastri      1.629998  0.083370 -1.120488  0.184985  2.097622  1.566404

# %% [markdown]
# The next source of points to model is when drivers beat their teammates. Since we now have more data from this season to work from, we can use this to better effect than historical data. First we need to scrape this season's data:

# %%
hrefs = [
    "1226/abu-dhabi"
]

qualifying_dfs, race_dfs, grid_dfs = [], [], []
season_length = 1 # Update after each race

# Collect qualifying, race and grid orders for this season's GPs
for href in hrefs[:season_length]:
    qualifying_url = f'https://www.formula1.com/en/results.html/2023/races/{href}/qualifying.html'
    qualifying_df = pd.read_html(qualifying_url)[0]
    # print(qualifying_df)
    qualifying_df['Driver'] = [unidecode.unidecode(name.split('  ')[1]) 
                               for name in qualifying_df['Driver']]
    qualifying_df['Driver'] = ['Zhou' if driver=='Guanyu' else driver for driver in qualifying_df['Driver']]
    qualifying_df['Driver'] = ['Vettel' if driver=='Hulkenberg' else driver for driver in qualifying_df['Driver']]
    qualifying_dfs.append(qualifying_df.set_index('Driver')[['Pos', 'Car', 'Q2', 'Q3']])
    # print(qualifying_df)
    
    race_url = f'https://www.formula1.com/en/results.html/2023/races/{href}.html'
    race_df = pd.read_html(race_url)[0]
    race_df['Driver'] = [unidecode.unidecode(name.split('  ')[1]) for name in race_df['Driver']]
    race_df['Driver'] = ['Zhou' if driver=='Guanyu' else driver for driver in race_df['Driver']]
    race_df['Driver'] = ['Vettel' if driver=='Hulkenberg' else driver for driver in race_df['Driver']]
    race_dfs.append(race_df.set_index('Driver')[['Pos', 'Car', 'Time/Retired']])
    
    grid_url = f'https://www.formula1.com/en/results.html/2023/races/{href}/starting-grid.html'
    grid_df = pd.read_html(grid_url)[0]
    grid_df['Driver'] = [unidecode.unidecode(name.split('  ')[1]) for name in grid_df['Driver']]
    # print(grid_df)
    grid_df['Driver'] = ['Zhou' if driver=='Guanyu' else driver for driver in grid_df['Driver']]
    grid_df['Driver'] = ['Vettel' if driver=='Hulkenberg' else driver for driver in grid_df['Driver']]
    print(grid_df['Driver'])
    grid_dfs.append(grid_df.set_index('Driver')[['Pos', 'Car']])
# Out:
# 0     Verstappen
# 1        Leclerc
# 2        Piastri
# 3        Russell
# 4         Norris
# 5        Tsunoda
# 6         Alonso
# 7         Vettel
# 8          Perez
# 9          Gasly
# 10      Hamilton
# 11          Ocon
# 12        Stroll
# 13         Albon
# 14     Ricciardo
# 15         Sainz
# 16     Magnussen
# 17        Bottas
# 18          Zhou
# 19      Sargeant
# Name: Driver, dtype: object

# %% [markdown]
# Next, we can use this data to see how often each driver beats their teammate, as well as their distribution of position gains and whether they tend to complete Q2 and Q3.

# %%
drivers = race_dfs[0].index

event_df = pd.DataFrame(index=drivers)
event_df['team'] = race_dfs[0].Car
event_df['beat_teammate_race'] = np.empty((20, 0)).tolist()
event_df['beat_teammate_qualifying'] = np.empty((20, 0)).tolist()

event_df['position_gain'] = np.empty((20, 0)).tolist()
event_df['q2_finish'] = np.empty((20, 0)).tolist()
event_df['q3_finish'] = np.empty((20, 0)).tolist()



for i, (race_df, qualifying_df, grid_df) in enumerate(zip(race_dfs, qualifying_dfs, grid_dfs)):
    for team in race_df['Car'].unique():
        # Collect teammate race data
        team_df = race_df.loc[race_df['Car']==team]
        try:
            event_df.loc[team_df.index[0], 'beat_teammate_race'].append(1)
            event_df.loc[team_df.index[1], 'beat_teammate_race'].append(0)
        except IndexError:
            continue
        except KeyError:
            continue

        # Collect teammate qualifying data
        team_df = qualifying_df.loc[qualifying_df['Car']==team]
        try:
            event_df.loc[team_df.index[1], 'beat_teammate_qualifying'].append(0)
            event_df.loc[team_df.index[0], 'beat_teammate_qualifying'].append(1)
        except IndexError:
            continue

    for driver in drivers:
        # Collect position gain data
        if race_df.loc[driver, 'Pos'] == 'NC':
            gain = 0
        elif race_df.loc[driver, 'Time/Retired'] in ['DNF', 'DNS']:
            gain = 0
        else:
            try:
                gain = int(grid_df.loc[driver, 'Pos']) - int(race_df.loc[driver, 'Pos'])
            except KeyError:
                gain = 20 - int(race_df.loc[driver, 'Pos'])
            except ValueError:
                gain = 0
        event_df.loc[driver, 'position_gain'].append(gain)
        
        # Collect Q2 qualification data
        try:
            if pd.isnull(qualifying_df.loc[driver, 'Q2']):
                event_df.loc[driver, 'q2_finish'].append(0)
            else:
                event_df.loc[driver, 'q2_finish'].append(1)
        except KeyError:
            event_df.loc[driver, 'q2_finish'].append(0)
        
        # Collect Q3 qualification data
        try:
            if pd.isnull(qualifying_df.loc[driver, 'Q3']):
                event_df.loc[driver, 'q3_finish'].append(0)
            else:
                event_df.loc[driver, 'q3_finish'].append(1)
        except KeyError:
            event_df.loc[driver, 'q3_finish'].append(0)

# We must normalise each probability towards mean to account for sample noise
event_df['P(beat_teammate_race)'] = [np.mean(l) for l in event_df['beat_teammate_race']]
event_df['P(beat_teammate_race)'] = (5 * event_df['P(beat_teammate_race)'] + 0.5) / 6
event_df['P(beat_teammate_qualifying)'] = [np.mean(l) for l in event_df['beat_teammate_qualifying']]
event_df['P(beat_teammate_qualifying)'] = (5 * event_df['P(beat_teammate_qualifying)'] + 0.5) / 6
event_df = pd.DataFrame(event_df[['team', 'P(beat_teammate_race)', 'P(beat_teammate_qualifying)']])
# event_df.head()
event_df
# Out:
#                                     team  P(beat_teammate_race)  \
# Driver
# Verstappen    Red Bull Racing Honda RBPT               0.916667
# Leclerc                          Ferrari               0.916667
# Russell                         Mercedes               0.916667
# Perez         Red Bull Racing Honda RBPT               0.083333
# Norris                  McLaren Mercedes               0.916667
# Piastri                 McLaren Mercedes               0.083333
# Alonso      Aston Martin Aramco Mercedes               0.916667
# Tsunoda            AlphaTauri Honda RBPT               0.916667
# Hamilton                        Mercedes               0.083333
# Stroll      Aston Martin Aramco Mercedes               0.083333
# Ricciardo          AlphaTauri Honda RBPT               0.083333
# Ocon                      Alpine Renault               0.916667
# Gasly                     Alpine Renault               0.083333
# Albon                  Williams Mercedes               0.916667
# Vettel                      Haas Ferrari               0.916667
# Sargeant               Williams Mercedes               0.083333
# Zhou                  Alfa Romeo Ferrari               0.916667
# Sainz                            Ferrari               0.083333
# Bottas                Alfa Romeo Ferrari               0.083333
# Magnussen                   Haas Ferrari               0.083333
#
#             P(beat_teammate_qualifying)
# Driver
# Verstappen                     0.916667
# Leclerc                        0.916667
# Russell                        0.916667
# Perez                          0.083333
# Norris                         0.083333
# Piastri                        0.916667
# Alonso                         0.916667
# Tsunoda                        0.916667
# Hamilton                       0.083333
# Stroll                         0.083333
# Ricciardo                      0.083333
# Ocon                           0.083333
# Gasly                          0.916667
# Albon                          0.916667
# Vettel                         0.916667
# Sargeant                       0.083333
# Zhou                           0.083333
# Sainz                          0.083333
# Bottas                         0.916667
# Magnussen                      0.083333

# %% [markdown]
# Finally, we must adjust the beating teammate probabilities to take into account the events that either (or both) drivers in each team are not classified in the race:

# %%
for team in event_df.team.unique():
    drivers = event_df[event_df['team']==team].index.tolist()
    print(drivers)
    p_no_dnf = (1 - df.loc[drivers[0], 'dnf']) * (1 - df.loc[drivers[1], 'dnf'])
    
    adjusted = adjust_odds(np.array(event_df.loc[drivers, 'P(beat_teammate_race)']), p_no_dnf, method='linear')
    event_df.loc[drivers, 'P(beat_teammate_race)'] = adjusted
    
    event_df.loc[drivers[0], 'P(beat_teammate_race)'] += (1 - df.loc[drivers[0], 'dnf']) * df.loc[drivers[1], 'dnf']
    event_df.loc[drivers[1], 'P(beat_teammate_race)'] += (1 - df.loc[drivers[1], 'dnf']) * df.loc[drivers[0], 'dnf']
    
event_df.loc.head()
# Out:
# ['Verstappen', 'Perez']
# ['Leclerc', 'Sainz']
# ['Russell', 'Hamilton']
# ['Norris', 'Piastri']
# ['Alonso', 'Stroll']
# ['Tsunoda', 'Ricciardo']
# ['Ocon', 'Gasly']
# ['Albon', 'Sargeant']
# ['Vettel', 'Magnussen']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Vettel'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 4
#       2 drivers = event_df[event_df['team']==team].index.tolist()
#       3 print(drivers)
# ----> 4 p_no_dnf = (1 - df.loc[drivers[0], 'dnf']) * (1 - df.loc[drivers[1], 'dnf'])
#       6 adjusted = adjust_odds(np.array(event_df.loc[drivers, 'P(beat_teammate_race)']), p_no_dnf, method='linear')
#       7 event_df.loc[drivers, 'P(beat_teammate_race)'] = adjusted
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:4209, in DataFrame._get_value(self, index, col, takeable)
#    4203 engine = self.index._engine
#    4205 if not isinstance(self.index, MultiIndex):
#    4206     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4207     #  results if our categories are integers that dont match our codes
#    4208     # IntervalIndex: IntervalTree has no get_loc
# -> 4209     row = self.index.get_loc(index)
#    4210     return series._values[row]
#    4212 # For MultiIndex going through engine effectively restricts us to
#    4213 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Vettel'

# %%
for driver in df.index:
    if driver in event_df.index:
        ev_df.loc[driver, 'beat_teammate'] = event_df.loc[driver, 'P(beat_teammate_race)'] * 3 \
                                        + event_df.loc[driver, 'P(beat_teammate_qualifying)'] * 2
    else:
        print(driver)
        ev_df.loc[driver, 'beat_teammate'] = 0
# Out:
# Hulkenberg

# %% [markdown]
# The last source of Fantasy F1 points we need to model is streaks - drivers get 5 points for a qualifying streak and 10 points for a race streak.

# %%
q_streak_drivers = []
race_streak_drivers = []

# %%
for driver in pos_df.index:
    if driver in q_streak_drivers:
        streak_prob = q3_finish_pts(pos_df.loc[driver, 'mean_pos']) / 3
        ev_df.loc[driver, 'q_streak'] = streak_prob * 5
    else:
        ev_df.loc[driver, 'q_streak'] = 0

for driver in pos_df.index:
    if driver in race_streak_drivers:
        streak_prob = sum([pos_df.loc[driver, i] for i in range(1,11)])
        ev_df.loc[driver, 'race_streak'] = streak_prob * 10
    else:
        ev_df.loc[driver, 'race_streak'] = 0
        
ev_df
# Out:
#                  race      flap       dnf      qual      gain         q  \
# driver
# Hamilton    11.115015  1.363521 -0.868960  5.242566  1.584842  4.568430
# Verstappen  19.104632  1.721886 -0.981524  7.726510  1.442411  4.730361
# Russell      3.704475  0.585222 -1.295385  1.292876  1.914522  2.965620
# Perez       11.520791  0.693624 -0.981524  5.162296  1.589943  4.558786
# Piastri      1.629998  0.083370 -1.120488  0.184985  2.097622  1.566404
# Leclerc     15.421268  0.194649 -1.295385  6.383983  1.516033  4.668386
# Alonso       1.651994  0.011312 -1.295385  0.183975  2.097879  1.564366
# Gasly        4.142764  0.011312 -1.120488  2.474158  1.791371  3.795639
# Sainz       12.935471  0.102481 -0.981524  5.145232  1.591033  4.556680
# Stroll       2.284677  0.011312 -1.295385  0.760178  1.987222  2.423328
# Norris       2.288109  0.083370 -1.120488  0.212763  2.090701  1.621206
# Ricciardo    9.421539  0.065542 -1.295385  4.315584  1.646305  4.425771
# Ocon         2.359087  0.011312 -1.295385  1.051172  1.945469  2.737138
# Zhou         1.652884  0.011312 -1.120488  0.188115  2.096829  1.572693
# Tsunoda      1.586119  0.011312 -1.819183  0.206721  2.092183  1.609479
# Bottas       7.963445  0.011312 -1.295385  3.345345  1.717947  4.171053
# Sargeant     1.720728  0.005280 -1.295385  0.325943  2.064929  1.824197
# Albon        2.274905  0.011312 -1.295385  0.970269  1.956515  2.654680
# Hulkenberg   2.459314  0.005280 -1.295385  1.132210  1.934773  2.816566
# Magnussen    3.824210  0.005280 -2.006922  2.228666  1.814203  3.656883
#
#             beat_teammate  q_streak  race_streak
# driver
# Hamilton         0.625913       0.0          0.0
# Verstappen       4.418676       0.0          0.0
# Russell          4.359078       0.0          0.0
# Perez            0.568479       0.0          0.0
# Piastri          2.254736       0.0          0.0
# Leclerc          4.360792       0.0          0.0
# Alonso           4.365571       0.0          0.0
# Gasly            2.284406       0.0          0.0
# Sainz            0.622255       0.0          0.0
# Stroll           0.612055       0.0          0.0
# Norris           2.728524       0.0          0.0
# Ricciardo        0.699792       0.0          0.0
# Ocon             2.696242       0.0          0.0
# Zhou             2.916667       0.0          0.0
# Tsunoda          4.268788       0.0          0.0
# Bottas           2.083333       0.0          0.0
# Sargeant         0.612055       0.0          0.0
# Albon            4.365571       0.0          0.0
# Hulkenberg       0.000000       0.0          0.0
# Magnussen        0.416667       0.0          0.0

# %% [markdown]
# And those are all the point sources for drivers! Let's compile this into a new DataFrame to review:

# %%
driver_df = pd.DataFrame(ev_df.T.sum(), columns=['EV'])
driver_df.sort_values(by='EV', ascending=False)
# Out:
#                    EV
# driver
# Verstappen  38.162952
# Leclerc     31.249727
# Sainz       23.971629
# Hamilton    23.631327
# Perez       23.112395
# Ricciardo   19.279147
# Bottas      17.997051
# Russell     13.526409
# Gasly       13.379161
# Albon       10.937867
# Magnussen    9.938986
# Ocon         9.505035
# Alonso       8.579712
# Tsunoda      7.955419
# Norris       7.904184
# Zhou         7.318010
# Hulkenberg   7.052758
# Stroll       6.783387
# Piastri      6.696628
# Sargeant     5.257747

# %% [markdown]
# Next, let's add up the current points projections for constructors:

# %%
team_df = pd.DataFrame(index=pos_df['team'].unique().tolist())

for team in pos_df['team'].unique():
    t_df = ev_df[pos_df['team']==team]
    team_df.loc[team, 'EV'] = t_df['race'].sum() + t_df['qual'].sum() + t_df['q'].sum() + t_df['gain'].sum() 
team_df.sort_values(by='EV', ascending=False)
# Out:
#                      EV
# Red Bull      55.835731
# Ferrari       52.218087
# Mercedes      32.388347
# RB            25.303700
# Sauber        22.708311
# Alpine        20.296798
# Haas          19.866824
# Williams      13.792165
# Aston Martin  12.953619
# McLaren       11.691788

# %% [markdown]
# Constructors also get 5 points if both of their drivers get streaks in qualifying and 10 in race. We can work out the probability of this happening with the values from $\texttt{pos_df}$.

# %%
q_streak_teams = []
race_streak_teams = []

# %%
for team in q_streak_teams:
    drivers = pos_df[pos_df['team']==team].index.tolist()
    streak_prob = q3_finish_pts(pos_df.loc[drivers[0], 'mean_pos']) / 3 * q3_finish_pts(pos_df.loc[drivers[1], 'mean_pos']) / 3
    team_df.loc[team, 'EV'] += streak_prob * 5

for team in race_streak_teams:
    drivers = pos_df[pos_df['team']==team].index.tolist()
    streak_prob = sum([pos_df.loc[drivers[0], i] for i in range(1,11)]) * sum([pos_df.loc[drivers[1], i] for i in range(1,11)])
    team_df.loc[team, 'EV'] += streak_prob * 10

team_df.sort_values(by='EV', ascending=False)
# Out:
#                      EV
# Red Bull      55.835731
# Ferrari       52.218087
# Mercedes      32.388347
# RB            25.303700
# Sauber        22.708311
# Alpine        20.296798
# Haas          19.866824
# Williams      13.792165
# Aston Martin  12.953619
# McLaren       11.691788

# %% [markdown]
# ## Optimising EV Projections

# %% [markdown]
# Now we move onto the last part of the model - using these EV projections to optimise teams.
#
# To do this, we need to get the prices of each driver and constructor.

# %%
driver_prices = {
    "Verstappen": 30,
    "Norris": 23,
    "Perez": 20.8,
    "Hamilton": 19.3,
    "Leclerc": 19.1,
    "Piastri": 19,
    "Russell": 18.8,
    "Sainz": 18.5,
    "Alonso": 15.8,
    "Stroll": 10.7,
    "Ricciardo": 9,
    "Tsunoda": 8,
    "Gasly": 7.8,
    "Ocon": 7.8,
    "Albon": 7,
    "Zhou": 6.6,
    "Bottas": 6.4,
    "Hulkenberg": 6.4,
    "Magnussen": 6.2,
    "Sargeant": 5.5
}

team_prices = {
    "Red Bull": 27.9,
    "McLaren": 23.2,
    "Mercedes": 20.1,
    "Ferrari": 19.3,
    "Aston Martin": 13.6,
    "RB": 8.5,
    "Alpine": 8.4,
    "Sauber": 6.6,
    "Williams": 6.3,
    "Haas": 6.3
}



for i in driver_prices:
    driver_df.loc[i, 'price'] = driver_prices[i]

for i in team_prices:
    team_df.loc[i, 'price'] = team_prices[i]

# %%
pd.concat([team_df.sort_values(by='EV', ascending=False), driver_df.sort_values(by='EV', ascending=False)])
# Out:
#                      EV  price
# Red Bull      55.835731   27.9
# Ferrari       52.218087   19.3
# Mercedes      32.388347   20.1
# RB            25.303700    8.5
# Sauber        22.708311    6.6
# Alpine        20.296798    8.4
# Haas          19.866824    6.3
# Williams      13.792165    6.3
# Aston Martin  12.953619   13.6
# McLaren       11.691788   23.2
# Verstappen    38.162952   30.0
# Leclerc       31.249727   19.1
# Sainz         23.971629   18.5
# Hamilton      23.631327   19.3
# Perez         23.112395   20.8
# Ricciardo     19.279147    9.0
# Bottas        17.997051    6.4
# Russell       13.526409   18.8
# Gasly         13.379161    7.8
# Albon         10.937867    7.0
# Magnussen      9.938986    6.2
# Ocon           9.505035    7.8
# Alonso         8.579712   15.8
# Tsunoda        7.955419    8.0
# Norris         7.904184   23.0
# Zhou           7.318010    6.6
# Hulkenberg     7.052758    6.4
# Stroll         6.783387   10.7
# Piastri        6.696628   19.0
# Sargeant       5.257747    5.5

# %%
driver_df.sort_values(by='EV', ascending=False)
# Out:
#                    EV  price
# driver
# Verstappen  38.162952   30.0
# Leclerc     31.249727   19.1
# Sainz       23.971629   18.5
# Hamilton    23.631327   19.3
# Perez       23.112395   20.8
# Ricciardo   19.279147    9.0
# Bottas      17.997051    6.4
# Russell     13.526409   18.8
# Gasly       13.379161    7.8
# Albon       10.937867    7.0
# Magnussen    9.938986    6.2
# Ocon         9.505035    7.8
# Alonso       8.579712   15.8
# Tsunoda      7.955419    8.0
# Norris       7.904184   23.0
# Zhou         7.318010    6.6
# Hulkenberg   7.052758    6.4
# Stroll       6.783387   10.7
# Piastri      6.696628   19.0
# Sargeant     5.257747    5.5

# %% [markdown]
# At last we are ready to construct a linear optimisation model!

# %%
def solve_team(budget, owned_drivers, owned_team, force_include, force_exclude, transfers=3):
    # Turn owned_drivers and owned_team into an array for linear programming
    owned_drivers = {d: 0 + int(d in owned_drivers) for d in driver_df.index}
    owned_team = {c: 0 + int(c in owned_team) for c in team_df.index}

    # Initialise optimisation problem and set up decision variables
    prob = LpProblem("F1_model", LpMaximize)
    drivers = LpVariable.dicts('drivers', driver_df.index, cat='Binary')
    teams = LpVariable.dicts('teams', team_df.index, cat='Binary')
    turbo = LpVariable.dicts('turbo', driver_df.index, cat='Binary')

    # Set objective function
    prob += lpSum([drivers[d] * driver_df.loc[d, 'EV'] for d in drivers]) \
            + lpSum([teams[t] * team_df.loc[t, 'EV'] for t in teams]) \
            + lpSum([turbo[d] * driver_df.loc[d, 'EV'] for d in drivers])

    # Constrain number of drivers to 5, and number of teams to 2 and turbo drivers to 1
    prob += lpSum(drivers) == 5
    prob += lpSum(teams) == 2
    prob += lpSum(turbo) == 1
    
    # Total price of assets must be less than or equal to total budget
    prob += lpSum([drivers[d] * driver_df.loc[d, 'price'] for d in drivers]) + \
            lpSum([teams[t] * team_df.loc[t, 'price'] for t in teams]) <= budget

    # Turbo driver must cost at most 19.9 - this is not a requirement for 2024
    prob += lpSum([turbo[d] * driver_df.loc[d, 'price'] for d in drivers]) <= 35.9
    for d in drivers:
        prob += turbo[d] <= drivers[d]
    
    # The total number of assets kept the same must be at least 6 minus the number of available transfers
    prob += lpSum([owned_drivers[d] * drivers[d] for d in drivers]) \
                + lpSum([owned_team[t] * teams[t] for t in teams]) >= 7 - transfers

    # Force the inclusion and exclusion of given drivers and teams
    for d in force_include['driver']:
        prob += drivers[d] == 1
    for t in force_include['team']:
        prob += teams[t] == 1
    for d in force_exclude['driver']:
        prob += drivers[d] == 0
    for t in force_exclude['team']:
        prob += team[t] == 0
    
    # We can expect Schumacher to outscore Latifi & Russell
    # for d in ['Latifi']:
    #     prob += drivers[d] <= drivers['Schumacher']

    # Solve problem and return optimal decision variables and objective value
    status = prob.solve()
    return {
        'drivers': sorted([d for d in drivers if drivers[d].varValue == 1], key=lambda x: -driver_prices[x]),
        'team': sorted([t for t in teams if teams[t].varValue == 1], key=lambda x: -team_prices[x]),
        'turbo driver': [d for d in drivers if turbo[d].varValue == 1][0],
        'EV': value(prob.objective)
    }

# %% [markdown]
# Let's solve the problem for my team this week!

# %%
print(
    solve_team(
        budget=100,
        owned_drivers=[],
        owned_team=[],
        force_include={'driver': [], 'team': []},
        force_exclude={'driver': [], 'team': []},
        transfers=12,
    )
)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/f12fb02b8a604f3eacab4e08cf02a3f6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/f12fb02b8a604f3eacab4e08cf02a3f6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 322 RHS
# At line 349 BOUNDS
# At line 400 ENDATA
# Problem MODEL has 26 rows, 50 columns and 140 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 237.496 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 50 columns (50 integer (50 of which binary)) and 140 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.722689
# Cbc0038I Solution found of -231.148
# Cbc0038I Before mini branch and bound, 46 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 50 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -231.782
# Cbc0038I Reduced cost fixing fixed 30 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.04499 (2) obj. -231.782 iterations 3
# Cbc0038I Pass   2: suminf.    0.40816 (2) obj. -233.182 iterations 3
# Cbc0038I Pass   3: suminf.    0.32311 (2) obj. -231.782 iterations 2
# Cbc0038I Pass   4: suminf.    0.21111 (2) obj. -231.782 iterations 2
# Cbc0038I Pass   5: suminf.    0.21111 (2) obj. -231.782 iterations 2
# Cbc0038I Pass   6: suminf.    0.43720 (3) obj. -231.782 iterations 6
# Cbc0038I Pass   7: suminf.    0.17336 (2) obj. -231.782 iterations 6
# Cbc0038I Pass   8: suminf.    0.17336 (2) obj. -231.782 iterations 0
# Cbc0038I Pass   9: suminf.    0.76563 (3) obj. -231.782 iterations 8
# Cbc0038I Pass  10: suminf.    0.43720 (3) obj. -231.782 iterations 6
# Cbc0038I Pass  11: suminf.    0.17336 (2) obj. -231.782 iterations 7
# Cbc0038I Pass  12: suminf.    0.40816 (2) obj. -233.182 iterations 3
# Cbc0038I Pass  13: suminf.    0.32311 (2) obj. -231.782 iterations 2
# Cbc0038I Pass  14: suminf.    0.90763 (3) obj. -231.782 iterations 6
# Cbc0038I Pass  15: suminf.    0.32311 (2) obj. -231.782 iterations 4
# Cbc0038I Pass  16: suminf.    0.12019 (4) obj. -231.782 iterations 3
# Cbc0038I Pass  17: suminf.    0.07459 (2) obj. -231.782 iterations 2
# Cbc0038I Pass  18: suminf.    1.08756 (4) obj. -231.782 iterations 7
# Cbc0038I Pass  19: suminf.    0.75117 (2) obj. -232.738 iterations 4
# Cbc0038I Pass  20: suminf.    0.80886 (2) obj. -231.782 iterations 2
# Cbc0038I Pass  21: suminf.    1.48684 (4) obj. -231.782 iterations 2
# Cbc0038I Pass  22: suminf.    0.80886 (2) obj. -231.782 iterations 2
# Cbc0038I Pass  23: suminf.    1.13671 (4) obj. -231.782 iterations 2
# Cbc0038I Pass  24: suminf.    0.92779 (3) obj. -231.782 iterations 5
# Cbc0038I Pass  25: suminf.    0.47150 (2) obj. -231.782 iterations 3
# Cbc0038I Pass  26: suminf.    0.47347 (2) obj. -231.815 iterations 2
# Cbc0038I Pass  27: suminf.    0.56171 (3) obj. -231.782 iterations 1
# Cbc0038I Pass  28: suminf.    0.07459 (2) obj. -231.782 iterations 6
# Cbc0038I Pass  29: suminf.    0.07459 (2) obj. -231.782 iterations 0
# Cbc0038I Pass  30: suminf.    0.40816 (2) obj. -233.182 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 35 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 50 columns, reduced to 3 rows 13 columns
# Cbc0038I Mini branch and bound improved solution from -231.148 to -233.157 (0.03 seconds)
# Cbc0038I Round again with cutoff of -234.025
# Cbc0038I Reduced cost fixing fixed 36 variables on major pass 3
# Cbc0038I Pass  30: suminf.    0.20390 (2) obj. -234.025 iterations 0
# Cbc0038I Pass  31: suminf.    0.36134 (2) obj. -236.247 iterations 2
# Cbc0038I Pass  32: suminf.    0.11218 (2) obj. -234.025 iterations 5
# Cbc0038I Pass  33: suminf.    0.11218 (2) obj. -234.025 iterations 0
# Cbc0038I Pass  34: suminf.    0.31925 (2) obj. -235.005 iterations 4
# Cbc0038I Pass  35: suminf.    0.26008 (2) obj. -234.025 iterations 3
# Cbc0038I Pass  36: suminf.    0.26008 (2) obj. -234.025 iterations 0
# Cbc0038I Pass  37: suminf.    0.26008 (2) obj. -234.025 iterations 0
# Cbc0038I Pass  38: suminf.    0.19977 (2) obj. -234.025 iterations 2
# Cbc0038I Pass  39: suminf.    0.19977 (2) obj. -234.025 iterations 0
# Cbc0038I Pass  40: suminf.    0.24413 (2) obj. -234.76 iterations 3
# Cbc0038I Pass  41: suminf.    0.69484 (2) obj. -234.464 iterations 1
# Cbc0038I Pass  42: suminf.    0.69484 (2) obj. -234.464 iterations 1
# Cbc0038I Pass  43: suminf.    0.72133 (2) obj. -234.025 iterations 3
# Cbc0038I Pass  44: suminf.    0.78264 (2) obj. -234.025 iterations 1
# Cbc0038I Pass  45: suminf.    0.81026 (3) obj. -234.025 iterations 4
# Cbc0038I Pass  46: suminf.    0.01550 (2) obj. -235.588 iterations 2
# Cbc0038I Pass  47: suminf.    0.71721 (2) obj. -234.025 iterations 3
# Cbc0038I Pass  48: suminf.    0.61972 (2) obj. -234.709 iterations 5
# Cbc0038I Pass  49: suminf.    0.66102 (2) obj. -234.025 iterations 3
# Cbc0038I Pass  50: suminf.    1.58704 (4) obj. -234.025 iterations 2
# Cbc0038I Pass  51: suminf.    0.05239 (2) obj. -234.025 iterations 3
# Cbc0038I Pass  52: suminf.    0.16901 (2) obj. -235.957 iterations 2
# Cbc0038I Pass  53: suminf.    0.26008 (2) obj. -234.025 iterations 2
# Cbc0038I Pass  54: suminf.    0.26008 (2) obj. -234.025 iterations 0
# Cbc0038I Pass  55: suminf.    0.31925 (2) obj. -235.005 iterations 2
# Cbc0038I Pass  56: suminf.    0.26008 (2) obj. -234.025 iterations 2
# Cbc0038I Pass  57: suminf.    0.26008 (2) obj. -234.025 iterations 0
# Cbc0038I Pass  58: suminf.    1.79777 (6) obj. -234.025 iterations 3
# Cbc0038I Pass  59: suminf.    1.00000 (3) obj. -234.025 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 50 columns, reduced to 5 rows 11 columns
# Cbc0038I Mini branch and bound improved solution from -233.157 to -233.311 (0.03 seconds)
# Cbc0038I Round again with cutoff of -235.066
# Cbc0038I Reduced cost fixing fixed 39 variables on major pass 4
# Cbc0038I Pass  59: suminf.    0.27769 (2) obj. -235.066 iterations 0
# Cbc0038I Pass  60: suminf.    0.36134 (2) obj. -236.247 iterations 2
# Cbc0038I Pass  61: suminf.    0.21450 (2) obj. -235.066 iterations 3
# Cbc0038I Pass  62: suminf.    0.21450 (2) obj. -235.066 iterations 0
# Cbc0038I Pass  63: suminf.    0.80589 (3) obj. -235.066 iterations 4
# Cbc0038I Pass  64: suminf.    0.51884 (4) obj. -235.066 iterations 2
# Cbc0038I Pass  65: suminf.    0.90315 (6) obj. -235.066 iterations 4
# Cbc0038I Pass  66: suminf.    0.73704 (4) obj. -235.066 iterations 1
# Cbc0038I Pass  67: suminf.    0.16901 (2) obj. -235.957 iterations 2
# Cbc0038I Pass  68: suminf.    0.11525 (2) obj. -235.066 iterations 2
# Cbc0038I Pass  69: suminf.    0.11525 (2) obj. -235.066 iterations 0
# Cbc0038I Pass  70: suminf.    0.11525 (2) obj. -235.066 iterations 0
# Cbc0038I Pass  71: suminf.    0.11525 (2) obj. -235.066 iterations 0
# Cbc0038I Pass  72: suminf.    0.11525 (2) obj. -235.066 iterations 0
# Cbc0038I Pass  73: suminf.    0.11525 (2) obj. -235.066 iterations 0
# Cbc0038I Pass  74: suminf.    0.43819 (4) obj. -235.066 iterations 1
# Cbc0038I Pass  75: suminf.    0.43819 (4) obj. -235.066 iterations 0
# Cbc0038I Pass  76: suminf.    0.43819 (4) obj. -235.066 iterations 0
# Cbc0038I Pass  77: suminf.    0.43819 (4) obj. -235.066 iterations 0
# Cbc0038I Pass  78: suminf.    0.16901 (2) obj. -235.957 iterations 1
# Cbc0038I Pass  79: suminf.    0.43819 (4) obj. -235.066 iterations 1
# Cbc0038I Pass  80: suminf.    0.43819 (4) obj. -235.066 iterations 0
# Cbc0038I Pass  81: suminf.    0.16901 (2) obj. -235.957 iterations 1
# Cbc0038I Pass  82: suminf.    0.11525 (2) obj. -235.066 iterations 2
# Cbc0038I Pass  83: suminf.    1.53889 (4) obj. -235.066 iterations 2
# Cbc0038I Pass  84: suminf.    0.95975 (6) obj. -235.066 iterations 1
# Cbc0038I Pass  85: suminf.    0.27769 (2) obj. -235.066 iterations 3
# Cbc0038I Pass  86: suminf.    0.27769 (2) obj. -235.066 iterations 1
# Cbc0038I Pass  87: suminf.    0.36134 (2) obj. -236.247 iterations 2
# Cbc0038I Pass  88: suminf.    0.88696 (4) obj. -236.276 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 41 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 50 columns, reduced to 4 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -233.311 - took 0.01 seconds
# Cbc0012I Integer solution of -233.31148 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 25 rows 50 columns, reduced to 3 rows 6 columns
# Cbc0031I 1 added rows had average density of 5
# Cbc0013I At root node, 18 cuts changed objective from -237.49593 to -233.31148 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 10 row cuts average 9.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 7 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 2 row cuts average 10.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 40 row cuts average 8.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -233.31148210084, took 32 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 40 variables fixed on reduced cost
# Cuts at root node changed objective from -237.496 to -233.311
# Probing was tried 6 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 6 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 6 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 6 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 6 times and created 40 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                233.31148210
# Enumerated nodes:               0
# Total iterations:               32
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.05
#
# {'drivers': ['Verstappen', 'Leclerc', 'Ricciardo', 'Albon', 'Bottas'], 'team': ['Ferrari', 'RB'], 'turbo driver': 'Verstappen', 'EV': 233.31148210085735}

# %% [markdown]
# Over a range of different prices, here are the optimal solutions:

# %%
optimal_teams = {}

min_budget, max_budget = 100, 100
last_team = {}
b = min_budget
while b <= max_budget:
    b = round(b, 1)
    team = solve_team(
                budget=b,
                owned_drivers=[],
                owned_team='',
                force_include={'driver': [], 'team': []},
                force_exclude={'driver': [], 'team': []},
                transfers=12
                )
    if team != last_team:
        optimal_teams[b] = team
    last_team = team
    b += 0.1

out_df = pd.DataFrame(optimal_teams).T
for i in range(5):
    out_df[f'driver {i+1}'] = [d[i] for d in out_df['drivers']]
out_df.index = [f'{out_df.index[i-1]}-{round(out_df.index[i] - 0.1, 1)}' 
                for i in range(1, len(out_df))] + [f'{out_df.index[-1]}-{max_budget}']
out_df.index.name = 'budget range'
out_df.drop('drivers', axis=1)[['driver 1', 'driver 2', 'driver 3', 'driver 4', 'driver 5', 
                                'turbo driver', 'team', 'EV']]
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/ce6d4cee5a8e4ce7a7ead52d2cdbee8e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/ce6d4cee5a8e4ce7a7ead52d2cdbee8e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 332 RHS
# At line 364 BOUNDS
# At line 415 ENDATA
# Problem MODEL has 31 rows, 50 columns and 145 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 202.02 - 0.00 seconds
# Cgl0002I 2 variables fixed
# Cgl0004I processed model has 21 rows, 42 columns (42 integer (42 of which binary)) and 116 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.15748
# Cbc0038I Pass   1: suminf.    0.15385 (2) obj. -201.855 iterations 2
# Cbc0038I Solution found of -171.992
# Cbc0038I Before mini branch and bound, 39 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 21 rows 42 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from -171.992 to -174.833 (0.02 seconds)
# Cbc0038I Round again with cutoff of -177.552
# Cbc0038I Reduced cost fixing fixed 5 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.15385 (2) obj. -201.855 iterations 0
# Cbc0038I Pass   3: suminf.    0.30916 (2) obj. -177.552 iterations 5
# Cbc0038I Pass   4: suminf.    0.88889 (2) obj. -191.975 iterations 3
# Cbc0038I Pass   5: suminf.    1.68916 (4) obj. -177.552 iterations 6
# Cbc0038I Pass   6: suminf.    1.60276 (4) obj. -177.552 iterations 2
# Cbc0038I Pass   7: suminf.    0.39869 (2) obj. -177.552 iterations 2
# Cbc0038I Pass   8: suminf.    0.83333 (2) obj. -189.089 iterations 4
# Cbc0038I Pass   9: suminf.    0.52519 (2) obj. -177.552 iterations 3
# Cbc0038I Pass  10: suminf.    0.22018 (2) obj. -177.777 iterations 8
# Cbc0038I Pass  11: suminf.    0.18462 (2) obj. -178.305 iterations 2
# Cbc0038I Pass  12: suminf.    0.32527 (3) obj. -177.552 iterations 3
# Cbc0038I Pass  13: suminf.    1.09276 (4) obj. -177.552 iterations 5
# Cbc0038I Pass  14: suminf.    0.39130 (2) obj. -183.641 iterations 3
# Cbc0038I Pass  15: suminf.    0.56921 (2) obj. -177.552 iterations 6
# Cbc0038I Pass  16: suminf.    0.76852 (2) obj. -185.573 iterations 5
# Cbc0038I Pass  17: suminf.    0.78548 (2) obj. -177.552 iterations 3
# Cbc0038I Pass  18: suminf.    0.19973 (4) obj. -177.552 iterations 6
# Cbc0038I Pass  19: suminf.    0.04859 (2) obj. -177.552 iterations 3
# Cbc0038I Pass  20: suminf.    0.05556 (2) obj. -177.677 iterations 4
# Cbc0038I Pass  21: suminf.    0.13718 (2) obj. -177.552 iterations 5
# Cbc0038I Pass  22: suminf.    1.57176 (6) obj. -177.552 iterations 11
# Cbc0038I Solution found of -187.719
# Cbc0038I Before mini branch and bound, 24 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 21 rows 42 columns, reduced to 3 rows 13 columns
# Cbc0038I Mini branch and bound improved solution from -187.719 to -198.663 (0.03 seconds)
# Cbc0038I Round again with cutoff of -199.334
# Cbc0038I Reduced cost fixing fixed 32 variables on major pass 3
# Cbc0038I Pass  23: suminf.    0.15385 (2) obj. -201.855 iterations 0
# Cbc0038I Pass  24: suminf.    0.30965 (2) obj. -199.334 iterations 3
# Cbc0038I Pass  25: suminf.    0.62876 (4) obj. -199.334 iterations 2
# Cbc0038I Pass  26: suminf.    0.33947 (2) obj. -199.334 iterations 1
# Cbc0038I Pass  27: suminf.    0.15385 (2) obj. -201.855 iterations 3
# Cbc0038I Pass  28: suminf.    0.15385 (2) obj. -201.855 iterations 1
# Cbc0038I Pass  29: suminf.    0.37220 (2) obj. -199.334 iterations 2
# Cbc0038I Pass  30: suminf.    0.18519 (2) obj. -201.851 iterations 2
# Cbc0038I Pass  31: suminf.    0.33947 (2) obj. -199.334 iterations 3
# Cbc0038I Pass  32: suminf.    0.15748 (2) obj. -202.02 iterations 2
# Cbc0038I Pass  33: suminf.    0.17414 (4) obj. -199.334 iterations 3
# Cbc0038I Pass  34: suminf.    0.09848 (4) obj. -199.334 iterations 1
# Cbc0038I Pass  35: suminf.    0.65167 (2) obj. -199.334 iterations 4
# Cbc0038I Pass  36: suminf.    0.23637 (2) obj. -199.334 iterations 1
# Cbc0038I Pass  37: suminf.    0.15385 (2) obj. -201.855 iterations 4
# Cbc0038I Pass  38: suminf.    0.30965 (2) obj. -199.334 iterations 3
# Cbc0038I Pass  39: suminf.    0.17414 (4) obj. -199.334 iterations 3
# Cbc0038I Pass  40: suminf.    0.07616 (2) obj. -199.334 iterations 3
# Cbc0038I Pass  41: suminf.    0.06154 (2) obj. -199.463 iterations 3
# Cbc0038I Pass  42: suminf.    0.06947 (2) obj. -199.334 iterations 2
# Cbc0038I Pass  43: suminf.    0.06154 (2) obj. -199.463 iterations 2
# Cbc0038I Pass  44: suminf.    0.07407 (2) obj. -199.461 iterations 1
# Cbc0038I Pass  45: suminf.    0.06154 (2) obj. -199.463 iterations 1
# Cbc0038I Pass  46: suminf.    0.06154 (2) obj. -199.463 iterations 0
# Cbc0038I Pass  47: suminf.    0.06947 (2) obj. -199.334 iterations 2
# Cbc0038I Pass  48: suminf.    0.06154 (2) obj. -199.463 iterations 1
# Cbc0038I Pass  49: suminf.    0.62876 (4) obj. -199.334 iterations 3
# Cbc0038I Pass  50: suminf.    0.33947 (2) obj. -199.334 iterations 1
# Cbc0038I Pass  51: suminf.    0.15385 (2) obj. -201.855 iterations 3
# Cbc0038I Pass  52: suminf.    0.30965 (2) obj. -199.334 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 33 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 21 rows 42 columns, reduced to 3 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -198.663 - took 0.01 seconds
# Cbc0012I Integer solution of -198.66302 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 21 rows 42 columns, reduced to 1 rows 2 columns
# Cbc0031I 2 added rows had average density of 5.5
# Cbc0013I At root node, 5 cuts changed objective from -202.01954 to -198.66302 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 2 row cuts average 5.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 5 row cuts average 6.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -198.663021896154, took 2 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 33 variables fixed on reduced cost
# Cuts at root node changed objective from -202.02 to -198.663
# Probing was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                198.66302190
# Enumerated nodes:               0
# Total iterations:               2
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.04
#                 driver 1 driver 2 driver 3   driver 4  driver 5 turbo driver  \
# budget range
# 100-100       Verstappen    Sainz   Bottas  Magnussen  Sargeant   Verstappen
#
#                                  team          EV
# budget range
# 100-100       [Ferrari, Aston Martin]  198.663022

# %% [markdown]
# The accuracy of the model is difficult to test. Fantasy F1 is extremely high-variance, and there is no data available to back-test. There is also no hindsight metric available to reduce noise, such as xG can be used for football. Initial results are positive though; so far this season I am in the top 2.5% of players, despite lacking anything beyond a very novice knowledge of F1.
