# %% [markdown]
# # Modelling Formula 1 Outcomes for Fantasy EV Projections

# %% [markdown]
# F1 Fantasy is well-suited to optimisation when compared to other fantasy sports. The problem space is relatively small - a team consists of only 5 assets, chosen from a pool of 30. You can also change half of your assets each race without a penalty, so planning more than 1 week ahead is almost always unneccesary. This makes for a much easier challenge than e.g. FPL optimisation, where we are choosing 15 assets from hundreds in a multi-period problem. Many drivers are either far too expenisve to be viable at their price point or sufficiently inexpensive to make them essential. Marginal decisions exist, but are less common than in other fantasy sports, which makes modelling it quite forgiving.

# %%
# %pip install unidecode
# %pip install gurobipy
# %pip install pulp
# %pip install pandas
# %pip install unidecode
# %pip install seaborn
# %pip install scipy
# %pip install scikit-learn
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: unidecode in /opt/homebrew/lib/python3.11/site-packages (1.3.8)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: gurobipy in /opt/homebrew/lib/python3.11/site-packages (11.0.0)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: pulp in /opt/homebrew/lib/python3.11/site-packages (2.8.0)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: unidecode in /opt/homebrew/lib/python3.11/site-packages (1.3.8)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: seaborn in /opt/homebrew/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/homebrew/lib/python3.11/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=1.2 in /opt/homebrew/lib/python3.11/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/homebrew/lib/python3.11/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (1.12.0)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /opt/homebrew/lib/python3.11/site-packages (from scipy) (1.24.2)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (3.3.0)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from itertools import product

import unidecode
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import optimize
from sklearn.linear_model import LinearRegression
import gurobipy as gp
from pulp import *

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# To play Formula 1 Fantasy optimally, we split our process into two parts: predicting outcomes from which we can develop expected value projections, and using these projections to optimize our team.
#
# First, we need to model a probability distribution of outcomes (i.e. the likelihood of each outcome to occur to each driver). We are deriving estimates for the probability of these outcomes from odds.

# %% [markdown]
# ## Converting Odds into Implied Probabilities

# %% [markdown]
# The first step is to collect our odds. I use the shortest decimal odds available (i.e. highest decimal) across spread markets and traditional bookmakers.
#
# The relevant markets are winner, podium finish, top 6 finish, points finish, fastest lap, and to finish unclassified.

# %%
#df = pd.read_csv('https://raw.githubusercontent.com/harryrgrove/F1_model/master/odds_input.csv', index_col=0)
#df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/odds_input_2022.csv', index_col=0)
df = pd.read_csv('odds.csv', index_col=0)

df
# Out:
#                     team  winner        top3        top6      top10  \
# driver
# Hamilton        Mercedes    8.25    2.062500    1.294118   1.118644
# Perez           Red Bull   13.20    2.640000    1.346939   1.222222
# Ricciardo             RB   66.00   66.000000    6.000000   3.142857
# Bottas            Sauber   66.00    6.000000    3.666667   2.357143
# Verstappen      Red Bull    1.50    1.178571    1.137931   1.081967
# Sainz            Ferrari   33.00    4.125000    1.609756   1.222222
# Ocon              Alpine   66.00   33.000000    7.333333   1.571429
# Leclerc          Ferrari   22.00    3.666667    1.534884   1.245283
# Russell         Mercedes   66.00    6.000000    2.062500   1.609756
# Alonso      Aston Martin  500.00    7.333333    3.000000   1.375000
# Gasly             Alpine  500.00   33.000000    5.076923   2.062500
# Norris           McLaren  500.00    5.500000    2.357143   1.245283
# Piastri          McLaren  500.00   33.000000   13.200000   6.000000
# Magnussen           Haas  500.00  500.000000   66.000000   7.333333
# Stroll      Aston Martin  500.00  500.000000    9.428571   2.275862
# Tsunoda               RB  500.00  500.000000   33.000000   3.882353
# Hulkenberg          Haas  500.00  500.000000  500.000000  66.000000
# Albon           Williams  500.00  500.000000  500.000000   6.600000
# Zhou              Sauber  500.00  500.000000  500.000000  11.000000
# Sargeant        Williams  500.00  500.000000  500.000000  66.000000
#
#                   flap        dnf
# driver
# Hamilton      5.500000  13.200000
# Perez         9.428571   8.250000
# Ricciardo    66.000000  16.500000
# Bottas       16.500000   5.076923
# Verstappen    3.300000  13.200000
# Sainz        33.000000   7.333333
# Ocon        500.000000   5.500000
# Leclerc      22.000000   6.600000
# Russell      13.200000   6.000000
# Alonso       66.000000   6.600000
# Gasly        66.000000   6.600000
# Norris       16.500000  16.500000
# Piastri      33.000000  22.000000
# Magnussen   500.000000   6.600000
# Stroll      500.000000   6.000000
# Tsunoda      66.000000   5.076923
# Hulkenberg  500.000000  33.000000
# Albon       500.000000   7.333333
# Zhou         33.000000   8.250000
# Sargeant    500.000000   9.428571

# %% [markdown]
# The basic implied probability from these projections can be obtained by finding their multiplicative inverse:

# %%
odds_cols = ['winner', 'top3', 'top6', 'top10', 'flap', 'dnf']
for col in odds_cols:
    df[col] **= -1
df
# Out:
#                     team    winner      top3      top6     top10      flap  \
# driver
# Hamilton        Mercedes  0.121212  0.484848  0.772727  0.893939  0.181818
# Perez           Red Bull  0.075758  0.378788  0.742424  0.818182  0.106061
# Ricciardo             RB  0.015152  0.015152  0.166667  0.318182  0.015152
# Bottas            Sauber  0.015152  0.166667  0.272727  0.424242  0.060606
# Verstappen      Red Bull  0.666667  0.848485  0.878788  0.924242  0.303030
# Sainz            Ferrari  0.030303  0.242424  0.621212  0.818182  0.030303
# Ocon              Alpine  0.015152  0.030303  0.136364  0.636364  0.002000
# Leclerc          Ferrari  0.045455  0.272727  0.651515  0.803030  0.045455
# Russell         Mercedes  0.015152  0.166667  0.484848  0.621212  0.075758
# Alonso      Aston Martin  0.002000  0.136364  0.333333  0.727273  0.015152
# Gasly             Alpine  0.002000  0.030303  0.196970  0.484848  0.015152
# Norris           McLaren  0.002000  0.181818  0.424242  0.803030  0.060606
# Piastri          McLaren  0.002000  0.030303  0.075758  0.166667  0.030303
# Magnussen           Haas  0.002000  0.002000  0.015152  0.136364  0.002000
# Stroll      Aston Martin  0.002000  0.002000  0.106061  0.439394  0.002000
# Tsunoda               RB  0.002000  0.002000  0.030303  0.257576  0.015152
# Hulkenberg          Haas  0.002000  0.002000  0.002000  0.015152  0.002000
# Albon           Williams  0.002000  0.002000  0.002000  0.151515  0.002000
# Zhou              Sauber  0.002000  0.002000  0.002000  0.090909  0.030303
# Sargeant        Williams  0.002000  0.002000  0.002000  0.015152  0.002000
#
#                  dnf
# driver
# Hamilton    0.075758
# Perez       0.121212
# Ricciardo   0.060606
# Bottas      0.196970
# Verstappen  0.075758
# Sainz       0.136364
# Ocon        0.181818
# Leclerc     0.151515
# Russell     0.166667
# Alonso      0.151515
# Gasly       0.151515
# Norris      0.060606
# Piastri     0.045455
# Magnussen   0.151515
# Stroll      0.166667
# Tsunoda     0.196970
# Hulkenberg  0.030303
# Albon       0.136364
# Zhou        0.121212
# Sargeant    0.106061

# %% [markdown]
# Probabilities implied directly odds are never optimal to begin with because they are overrounded. There are many ways to adjust for this, as explained in this paper: http://article.sciencepublishinggroup.com/pdf/10.11648.j.ajss.20170506.12.pdf
#
# We will be using the "power" adjustment method favoured by the paper's authors. For example, if we want a column of probabilities to add to 1 (e.g. for race winner, since there can be only 1 winner), then we must raise each probability $p_i$ to the same exponent $k$, such that the sum of the probabilities raised to $k$ equals the desired total $T$, i.e. we want $k$ such that $\sum_{i=1}^{20}p_i^k=T$

# %%
def adjust_odds(odds_series, target_sum, method='power'):
    if method == 'power':
        def f(x):
            return sum([i**x for i in odds_series]) - target_sum
        k = optimize.fsolve(f, 1) # optimise k such that the sum of p_i^k - T = 0
        return odds_series ** k
    elif method == 'linear':
        return odds_series / sum(odds_series) * target_sum

# %% [markdown]
# We want the winner column to add to 1, the top 3 column to add to 3, etc.

# %%
for col, target in zip(odds_cols[:-1], [1, 3, 6, 10, 1]):
    df[col] = adjust_odds(df[col], target)
df
# Out:
#                     team    winner      top3      top6     top10      flap  \
# driver
# Hamilton        Mercedes  0.117046  0.484975  0.776726  0.903283  0.182256
# Perez           Red Bull  0.072586  0.378920  0.746864  0.833551  0.106397
# Ricciardo             RB  0.014135  0.015174  0.172753  0.353832  0.015241
# Bottas            Sauber  0.014135  0.166774  0.279913  0.459356  0.060846
# Verstappen      Red Bull  0.662201  0.848535  0.881064  0.931020  0.303541
# Sainz            Ferrari  0.028597  0.242548  0.627161  0.833551  0.030453
# Ocon              Alpine  0.014135  0.030341  0.141912  0.663605  0.002018
# Leclerc          Ferrari  0.043184  0.272855  0.657127  0.819534  0.045653
# Russell         Mercedes  0.014135  0.166774  0.491926  0.649254  0.076034
# Alonso      Aston Martin  0.001804  0.136461  0.340745  0.749072  0.015241
# Gasly             Alpine  0.001804  0.030341  0.203481  0.518517  0.015241
# Norris           McLaren  0.001804  0.181930  0.431587  0.819534  0.060846
# Piastri          McLaren  0.001804  0.030341  0.079773  0.196795  0.030453
# Magnussen           Haas  0.001804  0.002004  0.016477  0.164039  0.002018
# Stroll      Aston Martin  0.001804  0.002004  0.110933  0.474216  0.002018
# Tsunoda               RB  0.001804  0.002004  0.032500  0.292104  0.015241
# Hulkenberg          Haas  0.001804  0.002004  0.002265  0.022346  0.002018
# Albon           Williams  0.001804  0.002004  0.002265  0.180493  0.002018
# Zhou              Sauber  0.001804  0.002004  0.002265  0.113550  0.030453
# Sargeant        Williams  0.001804  0.002004  0.002265  0.022346  0.002018
#
#                  dnf
# driver
# Hamilton    0.075758
# Perez       0.121212
# Ricciardo   0.060606
# Bottas      0.196970
# Verstappen  0.075758
# Sainz       0.136364
# Ocon        0.181818
# Leclerc     0.151515
# Russell     0.166667
# Alonso      0.151515
# Gasly       0.151515
# Norris      0.060606
# Piastri     0.045455
# Magnussen   0.151515
# Stroll      0.166667
# Tsunoda     0.196970
# Hulkenberg  0.030303
# Albon       0.136364
# Zhou        0.121212
# Sargeant    0.106061

# %% [markdown]
# We also need to adjust our DNF odds, since currently they may show a driver's DNF probability and top 10 probability to add to more than 1, which is of course impossible.
#
# We can adjust these under the assumption that given a top driver finishes the race, they are 96% likely to finish in the top 10:

# %%
df['dnf'] **= (np.log(0.96 - df['top10']) / np.log(df['dnf'])).max()
df['winner'] = df[['winner', 'top3']].min(axis=1)
df
# Out:
#                     team    winner      top3      top6     top10      flap  \
# driver
# Hamilton        Mercedes  0.117046  0.484975  0.776726  0.903283  0.182256
# Perez           Red Bull  0.072586  0.378920  0.746864  0.833551  0.106397
# Ricciardo             RB  0.014135  0.015174  0.172753  0.353832  0.015241
# Bottas            Sauber  0.014135  0.166774  0.279913  0.459356  0.060846
# Verstappen      Red Bull  0.662201  0.848535  0.881064  0.931020  0.303541
# Sainz            Ferrari  0.028597  0.242548  0.627161  0.833551  0.030453
# Ocon              Alpine  0.014135  0.030341  0.141912  0.663605  0.002018
# Leclerc          Ferrari  0.043184  0.272855  0.657127  0.819534  0.045653
# Russell         Mercedes  0.014135  0.166774  0.491926  0.649254  0.076034
# Alonso      Aston Martin  0.001804  0.136461  0.340745  0.749072  0.015241
# Gasly             Alpine  0.001804  0.030341  0.203481  0.518517  0.015241
# Norris           McLaren  0.001804  0.181930  0.431587  0.819534  0.060846
# Piastri          McLaren  0.001804  0.030341  0.079773  0.196795  0.030453
# Magnussen           Haas  0.001804  0.002004  0.016477  0.164039  0.002018
# Stroll      Aston Martin  0.001804  0.002004  0.110933  0.474216  0.002018
# Tsunoda               RB  0.001804  0.002004  0.032500  0.292104  0.015241
# Hulkenberg          Haas  0.001804  0.002004  0.002265  0.022346  0.002018
# Albon           Williams  0.001804  0.002004  0.002265  0.180493  0.002018
# Zhou              Sauber  0.001804  0.002004  0.002265  0.113550  0.030453
# Sargeant        Williams  0.001804  0.002004  0.002265  0.022346  0.002018
#
#                  dnf
# driver
# Hamilton    0.028980
# Perez       0.055238
# Ricciardo   0.021335
# Bottas      0.107552
# Verstappen  0.028980
# Sainz       0.064930
# Ocon        0.096363
# Leclerc     0.075031
# Russell     0.085516
# Alonso      0.075031
# Gasly       0.075031
# Norris      0.021335
# Piastri     0.014376
# Magnussen   0.075031
# Stroll      0.085516
# Tsunoda     0.107552
# Hulkenberg  0.008241
# Albon       0.064930
# Zhou        0.055238
# Sargeant    0.045989

# %% [markdown]
# ## Estimating Race Finishing Position Distributions

# %% [markdown]
# After adjusting our odds, we can move on to looking at the probability distributions they imply.
#
# If we assume the probabilities are as uniform as the odds could possibly imply, this is what the implied distribution looks like for Pierre Gasly:

# %%
def get_probs(idx):
    probs = [df.loc[idx, 'winner']]
    probs += [(df.loc[idx, 'top3'] - df.loc[idx, 'winner'])/2] * 2
    probs += [(df.loc[idx, 'top6'] - df.loc[idx, 'top3']) / 3] * 3
    probs += [(df.loc[idx, 'top10'] - df.loc[idx, 'top6']) / 4] * 4
    probs += [(1 - df.loc[idx, 'top10'] - df.loc[idx, 'dnf']) / 10] * 10
    probs.append(df.loc[idx, 'dnf'])
    return probs

driver = 'Alonso'

plt.bar(['P{}'.format(i) for i in range(1, 21)] + ['DNF'], get_probs(driver))
plt.xticks(rotation=90)
plt.ylabel('likelihood')
plt.show()

# %% [markdown]
# If we wanted, we could calculate expected value projections using these uniform distributions, and this would work fine. To improve them slightly (and also for the sake of fun), we want them to resemble a bell-curve. An easy way to do this is to minimize the squared difference between the implied probabilities of consecutive finishes, which can be done with quadratic optimisation.
#
# In other words, for each driver we need to solve the following optimisation problem, given $p_i$ is the probability a driver finishes in position $i$:
#
# $$\text{Minimise} \ \sum_{i=1}^{19} (p_{i+1} - p_i)^2$$
#
# $$\text{Subject to: } \ p_1 = P(\text{win}); \ \ \sum_{i=1}^3 p_i = P(\text{podium finish}); \ \ \sum_{i=1}^6 p_i = P(\text{top 6 finish}); \\ \sum_{i=1}^{10} p_i = P(\text{points finish}); \ \ \sum_{i=11}^{20} p_i = 1 - P(\text{points finish}) - P(\text{dnf}).$$
#
# Let's first demonstrate on Gasly's probability distribution:

# %%
quadratic_model = gp.Model('quadratic')
quadratic_model.setParam('outputFlag', False)
driver = 'Hamilton'
# Add the probability of finishing in each position as a model variable
x = {i: quadratic_model.addVar(vtype=gp.GRB.CONTINUOUS, lb=0, ub=1, name=f'x_{i}') for i in range(1, 21)}
# Set objective to minimize the differences between probabilities of consecutive positions
obj = sum([(x[i] - x[i + 1])**2 for i in range(1, 20)])
quadratic_model.setObjective(obj, gp.GRB.MINIMIZE)
# Set model constraints
quadratic_model.addConstr(x[1] == df.loc[driver, 'winner'])
quadratic_model.addConstr(x[2] + x[3] == df.loc[driver, 'top3'] - df.loc[driver, 'winner'])
quadratic_model.addConstr(x[4] + x[5] + x[6] == df.loc[driver, 'top6'] - df.loc[driver, 'top3'])
quadratic_model.addConstr(x[7] + x[8] + x[9] + x[10] == df.loc[driver, 'top10'] - df.loc[driver, 'top6'])
quadratic_model.addConstr(sum([x[i] for i in range(11, 21)]) == 1 - df.loc[driver, 'top10'] - df.loc[driver, 'dnf'])
if df.loc[driver, 'top10'] >= 0.5:
    quadratic_model.addConstr(x[20] == 0)
# Optimize model parameters
quadratic_model.optimize()
vals = [v.x for v in quadratic_model.getVars()]
plt.bar(['P{}'.format(i) for i in range(1, 21)] + ['DNF'], vals + [df.loc[driver, 'dnf']])
plt.xticks(rotation=90)
plt.ylabel('Probability')
plt.show()
# Out:
# Restricted license - for non-production use only - expires 2025-11-24

# %% [markdown]
# Much more satisfying! Now we can apply this method to all other drivers:

# %%
pos_dict = {}

for driver in df.index:
    print(driver)
    quadratic_model = gp.Model('quadratic')
    quadratic_model.setParam('outputFlag', False)
    x = {i: quadratic_model.addVar(vtype=gp.GRB.CONTINUOUS, lb=0, ub=1, name=f'x_{i}') for i in range(1, 21)}
    obj = sum([(x[i] - x[i + 1])**2 for i in range(1, 20)])
    quadratic_model.setObjective(obj, gp.GRB.MINIMIZE)
    quadratic_model.addConstr(x[1] == df.loc[driver, 'winner'])
    quadratic_model.addConstr(x[2] + x[3] == df.loc[driver, 'top3'] - df.loc[driver, 'winner'])
    quadratic_model.addConstr(x[4] + x[5] + x[6] == df.loc[driver, 'top6'] - df.loc[driver, 'top3'])
    quadratic_model.addConstr(x[7] + x[8] + x[9] + x[10] == df.loc[driver, 'top10'] - df.loc[driver, 'top6'])
    quadratic_model.addConstr(sum([x[i] for i in range(11, 21)]) == 1 - df.loc[driver, 'top10'] - df.loc[driver, 'dnf'])
    quadratic_model.optimize()
    # print(quadratic_model.getVars())
    pos_dict[driver] = {i + 1: v.x for i, v in enumerate(quadratic_model.getVars())}
# Out:
# Hamilton
# Perez
# Ricciardo
# Bottas
# Verstappen
# Sainz
# Ocon
# Leclerc
# Russell
# Alonso
# Gasly
# Norris
# Piastri
# Magnussen
# Stroll
# Tsunoda
# Hulkenberg
# Albon
# Zhou
# Sargeant

# %% [markdown]
# We can store this information in a DataFrame $\texttt{pos_df}$, alongside other essential information such as mean projected position.

# %%
pos_df = pd.DataFrame(pos_dict).T
pos_df['dnf'] = df.dnf
pos_df['team'] = df.team
pos_df['mean_pos'] = sum([i / (1 - df['dnf']) * pos_df[i] for i in range(1, 21)])
pos_df.head(10).T
# Out:
#           Hamilton     Perez Ricciardo     Bottas Verstappen     Sainz  \
# 1         0.117046  0.072586  0.014135   0.014135   0.662201  0.028597
# 2         0.181147   0.14037       0.0   0.070157   0.186334  0.089024
# 3         0.186782  0.165964  0.001039   0.082482        0.0  0.124927
# 4         0.133953  0.149368  0.037257   0.051111   0.007013  0.136304
# 5         0.093219  0.125179  0.057763    0.03322   0.011639  0.133074
# 6          0.06458  0.093397  0.062558   0.028809   0.013877  0.115235
# 7         0.048036  0.054021  0.051642   0.037879   0.013729  0.082788
# 8          0.03486  0.025331  0.044727     0.0443   0.013174  0.057333
# 9         0.025051  0.007327  0.041812   0.048071   0.012211   0.03887
# 10         0.01861  0.000008  0.042898   0.049192   0.010842  0.027399
# 11        0.015535  0.002895  0.047985   0.047664   0.009064  0.022919
# 12        0.012768  0.005492  0.052564   0.046289   0.007465  0.018887
# 13        0.010309  0.007802  0.056633   0.045067   0.006043  0.015304
# 14        0.008157  0.009822  0.060194   0.043997     0.0048  0.012168
# 15        0.006312  0.011554  0.063246    0.04308   0.003733   0.00948
# 16        0.004775  0.012997   0.06579   0.042316   0.002845   0.00724
# 17        0.003546  0.014152  0.067825   0.041705   0.002134  0.005448
# 18        0.002624  0.015018  0.069351   0.041246   0.001601  0.004104
# 19        0.002009  0.015595  0.070368   0.040941   0.001246  0.003208
# 20        0.001702  0.015884  0.070877   0.040788   0.001068   0.00276
# dnf        0.02898  0.055238  0.021335   0.107552    0.02898   0.06493
# team      Mercedes  Red Bull        RB     Sauber   Red Bull   Ferrari
# mean_pos  4.509563  5.424246  12.51684  10.240708   2.235682  5.918472
#
#               Ocon   Leclerc   Russell        Alonso
# 1         0.014135  0.043184  0.014135      0.001804
# 2         0.008195  0.098742  0.060008      0.056781
# 3         0.008011  0.130928  0.092631      0.077876
# 4         0.013581  0.139744  0.112002      0.065088
# 5          0.03268  0.133208  0.114131      0.064146
# 6          0.06531  0.111321  0.099018       0.07505
# 7          0.11147  0.074083  0.066663      0.097799
# 8         0.137515  0.045795  0.042788      0.108612
# 9         0.143446  0.026458  0.027395      0.107488
# 10        0.129263  0.016072  0.020483      0.094429
# 11        0.094966  0.014636  0.022052      0.069433
# 12        0.065945  0.013343  0.023464      0.048272
# 13        0.042202  0.012195  0.024719      0.030947
# 14        0.023736   0.01119  0.025817      0.017457
# 15        0.010547  0.010328  0.026758      0.007803
# 16        0.002635   0.00961  0.027543      0.001984
# 17             0.0  0.009036   0.02817           0.0
# 18             0.0  0.008605  0.028641           0.0
# 19             0.0  0.008318  0.028955           0.0
# 20             0.0  0.008174  0.029112           0.0
# dnf       0.096363  0.075031  0.085516      0.075031
# team        Alpine   Ferrari  Mercedes  Aston Martin
# mean_pos  8.903421  5.822008  8.158609      7.550604

# %% [markdown]
# We can also create another DataFrame $\texttt{ev_df}$, which will store all the expected value of all sources of points, such as race position, dnf penalty, etc.

# %%
ev_df = pd.DataFrame(index=df.index)
ev_df['race'] = 25 * pos_df[1] + 18 * pos_df[2] + 15 * pos_df[3] \
                 + 12 * pos_df[4] + 10 * pos_df[5] + 8 * pos_df[6] \
                 + 6 * pos_df[7] + 4 * pos_df[8] + 2 * pos_df[9] \
                 + pos_df[10] + (1 - pos_df['dnf']) * 1
ev_df['flap'] = df['flap'] * 5
ev_df['dnf'] = -15 * df['dnf']

ev_df.head()
# Out:
#                  race      flap       dnf
# driver
# Hamilton    13.512162  0.911278 -0.434703
# Perez       12.007024  0.531983 -0.828573
# Ricciardo    3.488095  0.076206 -0.320030
# Bottas       5.471686  0.304230 -1.613282
# Verstappen  21.361951  1.517703 -0.434703

# %% [markdown]
# ## Modelling Sources of Points outside of Odds

# %% [markdown]
# Next, we must estimate the value of other sources of points based on these race position distributions.
#
# There is little/no market data on these categories, so we can attempt to infer the distributions from past data analysis of players with similar race end expectations (i.e. running a linear regression to formulate expectations, then building probability distributions from this expectation matrix). First we need to collect data, which I've already stored in csv files for race data and result data.

# %%
# race_df = pd.read_csv("https://raw.githubusercontent.com/harryrgrove/F1_model/master/races.csv")
race_df = pd.read_csv("f1db_csv/races.csv")
# result_df = pd.read_csv("https://raw.githubusercontent.com/harryrgrove/F1_model/master/results.csv")
result_df = pd.read_csv("f1db_csv/results.csv")

race_df
# Out:
#       raceId  year  round  circuitId                    name        date  \
# 0          1  2009      1          1   Australian Grand Prix  2009-03-29
# 1          2  2009      2          2    Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17      Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3      Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4      Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                     ...         ...
# 1120    1140  2024     20         32  Mexico City Grand Prix  2024-10-27
# 1121    1141  2024     21         18    São Paulo Grand Prix  2024-11-03
# 1122    1142  2024     22         80    Las Vegas Grand Prix  2024-11-23
# 1123    1143  2024     23         78        Qatar Grand Prix  2024-12-01
# 1124    1144  2024     24         24    Abu Dhabi Grand Prix  2024-12-08
#
#           time                                                url fp1_date  \
# 0     06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1     09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2     07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3     12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4     12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
# ...        ...                                                ...      ...
# 1120        \N  https://en.wikipedia.org/wiki/2024_Mexico_City...       \N
# 1121        \N  https://en.wikipedia.org/wiki/2024_S%C3%A3o_Pa...       \N
# 1122        \N  https://en.wikipedia.org/wiki/2024_Las_Vegas_G...       \N
# 1123        \N  https://en.wikipedia.org/wiki/2024_Qatar_Grand...       \N
# 1124        \N  https://en.wikipedia.org/wiki/2024_Abu_Dhabi_G...       \N
#
#      fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# 0          \N       \N       \N       \N       \N         \N         \N
# 1          \N       \N       \N       \N       \N         \N         \N
# 2          \N       \N       \N       \N       \N         \N         \N
# 3          \N       \N       \N       \N       \N         \N         \N
# 4          \N       \N       \N       \N       \N         \N         \N
# ...       ...      ...      ...      ...      ...        ...        ...
# 1120       \N       \N       \N       \N       \N         \N         \N
# 1121       \N       \N       \N       \N       \N         \N         \N
# 1122       \N       \N       \N       \N       \N         \N         \N
# 1123       \N       \N       \N       \N       \N         \N         \N
# 1124       \N       \N       \N       \N       \N         \N         \N
#
#      sprint_date sprint_time
# 0             \N          \N
# 1             \N          \N
# 2             \N          \N
# 3             \N          \N
# 4             \N          \N
# ...          ...         ...
# 1120          \N          \N
# 1121          \N          \N
# 1122          \N          \N
# 1123          \N          \N
# 1124          \N          \N
#
# [1125 rows x 18 columns]

# %%
# Gather IDs of all races
race_dict = {}
for year in range(2021, 2024):
    races = race_df[race_df['year']==year]['raceId'].tolist()
    race_dict[year] = races
    
# We are interested in how mean race position predicts mean grid position, mean fantasy points from quali, 
# % of Q2 finishes, % of Q3 finishes, and mean number of positions gained.
values = {'grid': [], 'position': [], 'fantasy': [], 'top10': [], 'top15': [], 'mean_gain': []}

# Iterate through the result data to collect these data points for each driver who raced more than 15
# times in a season since 2015
for year in race_dict:
    season_df = result_df[result_df['raceId'].isin(race_dict[year])]
    drivers = season_df['driverId'].unique()
    for driver in drivers:
        driver_df = season_df[season_df['driverId']==driver]
        grid_pos_df = driver_df[['grid', 'position']][driver_df['position'].str.isnumeric() & (driver_df['grid'] != 0)]
        grid_pos_df['grid'] = grid_pos_df['grid'].astype(float)
        grid_pos_df['position'] = grid_pos_df['position'].astype(float)
        
        if len(grid_pos_df) > 15:
            values['grid'].append(grid_pos_df['grid'].mean())
            values['position'].append(grid_pos_df['position'].mean())
            values['fantasy'].append(sum([sum(grid_pos_df['grid']==i) * 
                                          (11 - i) for i in range(1, 11)]) / len(grid_pos_df))
            values['top10'].append(sum(grid_pos_df['grid'] <= 10) / len(grid_pos_df))
            values['top15'].append(sum(grid_pos_df['grid'] <= 15) / len(grid_pos_df))

            total = 0
            for idx in grid_pos_df.index:
                if grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position'] > 0:
                    total += min(10, (grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position']) * 2)
                elif grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position'] < 0:
                    if grid_pos_df.loc[idx, 'grid'] <= 10:
                        total += max(-10, (grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position']) * 2)
                    else:
                        total += max(-5, grid_pos_df.loc[idx, 'grid'] - grid_pos_df.loc[idx, 'position'])
            values['mean_gain'].append(total / len(grid_pos_df))

# %%
result_df = pd.DataFrame(values)
result_df.head()
# Out:
#        grid  position   fantasy     top10     top15  mean_gain
# 0  3.047619  2.761905  7.952381  0.952381  1.000000   0.857143
# 1  3.052632  1.842105  8.421053  0.947368  0.947368   1.157895
# 2  5.777778  5.000000  6.055556  0.833333  0.888889   0.666667
# 3  6.904762  6.619048  4.714286  0.857143  0.952381   0.380952
# 4  5.500000  5.250000  5.500000  0.937500  1.000000   1.500000

# %% [markdown]
# First, let's model the points we expect from qualifying position from mean race finishing position. As seen below, this relationaship can be appropriately captured with a polynomial interpolation (degree 2).

# %%
sns.scatterplot(x='position', y='fantasy', data=result_df)
weights = np.polyfit(result_df['position'], result_df['fantasy'], 2)
model = np.poly1d(weights)
x = np.linspace(1, 17)
y = model(x)

y_pred = model(result_df['position'])

plt.plot(x, y)
plt.show()

# %% [markdown]
# From this relationship we can build a function to predict qualifying EV from mean race position.

# %%
def qual_pts(pos):
    weights = np.polyfit(result_df['position'], result_df['fantasy'], 2)
    model = np.poly1d(weights)
    return max(model(pos), 0)

# %% [markdown]
# Next, let's do the same for modelling the probability of completing Q2 given a mean race position. A logistic relationship is clear in this case.

# %%
result_df = result_df.sort_values(by='position')
sns.scatterplot(x=result_df['position'], y=result_df['top10'])

x = result_df['position'].to_numpy()
y = result_df['top10'].to_numpy()

def f(x, a, b, c, d):
    return a / (1. + np.exp(-c * (x - d))) + b

popt, pcov = optimize.curve_fit(f, x, y, method="trf")
y_fit = f(x, *popt)
plt.plot(x, y_fit, '-')
plt.show()

# %% [markdown]
# From this relationship, we can model the number of points expected from Q2 appearance.

# %%
def q2_finish_pts(pos):
    x = result_df['position'].to_numpy()
    y = result_df['top10'].to_numpy()

    def f(x, a, b, c, d):
        return a / (1. + np.exp(-c * (x - d))) + b

    popt, pcov = optimize.curve_fit(f, x, y, method="trf")
    return f(pos, *popt) * 2

# %% [markdown]
# Next, let's look at Q3 finishes. We can use the same logistic regression model as a reasonable estimate.

# %%
result_df = result_df.sort_values(by='position')
sns.scatterplot(x=result_df['position'], y=result_df['top15'])

x = result_df['position'].to_numpy()
y = result_df['top15'].to_numpy()

def f(x, a, b, c, d):
    return a / (1. + np.exp(-c * (x - d))) + b

popt, pcov = optimize.curve_fit(f, x, y, method="trf")
y_fit = f(x, *popt)
plt.plot(x, y_fit, '-')
plt.show()

# %%
def q3_finish_pts(pos):
    x = result_df['position'].to_numpy()
    y = result_df['top15'].to_numpy()

    def f(x, a, b, c, d):
        return a / (1. + np.exp(-c * (x - d))) + b

    popt, pcov = optimize.curve_fit(f, x, y, method="trf")
    return max(f(pos, *popt) * 3, 0)

# %% [markdown]
# Next, we want to look at modeling the relationship between expected race finish position and how many places one can be expected to gain in the race. A very loose but statistically significant correlation exists here.

# %%
sns.lmplot(x='position', y='mean_gain', data=result_df)
plt.show()

# %%
def gain_pts(pos):  
    x, y = result_df['position'].values.reshape(-1, 1), result_df['mean_gain'].values.reshape(-1,1)
    reg = LinearRegression().fit(x, y)
    return reg.predict(np.array(pos).reshape(-1, 1))[0][0]

# %% [markdown]
# We can add the expected points from these new sources to $\texttt{ev_df}$

# %%
ev_df['qual'] = [qual_pts(i) for i in pos_df['mean_pos']]
ev_df['gain'] = [gain_pts(i) for i in pos_df['mean_pos']]
ev_df['q'] = [q2_finish_pts(i) + q3_finish_pts(i) for i in pos_df['mean_pos']]
ev_df.head()
# Out:
#                  race      flap       dnf      qual      gain         q
# driver
# Hamilton    13.512162  0.911278 -0.434703  5.782725  1.551455  4.623366
# Perez       12.007024  0.531983 -0.828573  4.987489  1.601189  4.536237
# Ricciardo    3.488095  0.076206 -0.320030  0.762688  1.986835  2.426260
# Bottas       5.471686  0.304230 -1.613282  1.743706  1.863075  3.333040
# Verstappen  21.361951  1.517703 -0.434703  8.007533  1.427817  4.738927

# %% [markdown]
# The next source of points to model is when drivers beat their teammates. Since we now have more data from this season to work from, we can use this to better effect than historical data. First we need to scrape this season's data:

# %%
hrefs = [
    "1229/bahrain",
    "1230/saudi-arabia",
    "1231/australia"    
]
# https://www.formula1.com/en/results.html/2024/races/1229/bahrain/race-result.html
qualifying_dfs, race_dfs, grid_dfs = [], [], []
season_length = 1 # Update after each race

# Collect qualifying, race and grid orders for this season's GPs
for href in hrefs[:season_length]:
    qualifying_url = f'https://www.formula1.com/en/results.html/2024/races/{href}/qualifying.html'
    qualifying_df = pd.read_html(qualifying_url)[0]
    # print(qualifying_df)
    qualifying_df['Driver'] = [unidecode.unidecode(name.split('  ')[1]) 
                               for name in qualifying_df['Driver']]
    qualifying_df['Driver'] = ['Zhou' if driver=='Guanyu' else driver for driver in qualifying_df['Driver']]
    # qualifying_df['Driver'] = ['Vettel' if driver=='Hulkenberg' else driver for driver in qualifying_df['Driver']]
    qualifying_dfs.append(qualifying_df.set_index('Driver')[['Pos', 'Car', 'Q2', 'Q3']])
    # print(qualifying_df)
    
    race_url = f'https://www.formula1.com/en/results.html/2024/races/{href}.html'
    race_df = pd.read_html(race_url)[0]
    race_df['Driver'] = [unidecode.unidecode(name.split('  ')[1]) for name in race_df['Driver']]
    race_df['Driver'] = ['Zhou' if driver=='Guanyu' else driver for driver in race_df['Driver']]
    # race_df['Driver'] = ['Vettel' if driver=='Hulkenberg' else driver for driver in race_df['Driver']]
    race_dfs.append(race_df.set_index('Driver')[['Pos', 'Car', 'Time/Retired']])
    
    grid_url = f'https://www.formula1.com/en/results.html/2024/races/{href}/starting-grid.html'
    grid_df = pd.read_html(grid_url)[0]
    grid_df['Driver'] = [unidecode.unidecode(name.split('  ')[1]) for name in grid_df['Driver']]
    # print(grid_df)
    grid_df['Driver'] = ['Zhou' if driver=='Guanyu' else driver for driver in grid_df['Driver']]
    # grid_df['Driver'] = ['Vettel' if driver=='Hulkenberg' else driver for driver in grid_df['Driver']]
    print(grid_df['Driver'])
    grid_dfs.append(grid_df.set_index('Driver')[['Pos', 'Car']])
# Out:
# 0     Verstappen
# 1        Leclerc
# 2        Russell
# 3          Sainz
# 4          Perez
# 5         Alonso
# 6         Norris
# 7        Piastri
# 8       Hamilton
# 9     Hulkenberg
# 10       Tsunoda
# 11        Stroll
# 12         Albon
# 13     Ricciardo
# 14     Magnussen
# 15        Bottas
# 16          Zhou
# 17      Sargeant
# 18          Ocon
# 19         Gasly
# Name: Driver, dtype: object

# %% [markdown]
# Next, we can use this data to see how often each driver beats their teammate, as well as their distribution of position gains and whether they tend to complete Q2 and Q3.

# %%
drivers = race_dfs[0].index

event_df = pd.DataFrame(index=drivers)
event_df['team'] = race_dfs[0].Car
event_df['beat_teammate_race'] = np.empty((20, 0)).tolist()
event_df['beat_teammate_qualifying'] = np.empty((20, 0)).tolist()

event_df['position_gain'] = np.empty((20, 0)).tolist()
event_df['q2_finish'] = np.empty((20, 0)).tolist()
event_df['q3_finish'] = np.empty((20, 0)).tolist()



for i, (race_df, qualifying_df, grid_df) in enumerate(zip(race_dfs, qualifying_dfs, grid_dfs)):
    for team in race_df['Car'].unique():
        # Collect teammate race data
        team_df = race_df.loc[race_df['Car']==team]
        try:
            event_df.loc[team_df.index[0], 'beat_teammate_race'].append(1)
            event_df.loc[team_df.index[1], 'beat_teammate_race'].append(0)
        except IndexError:
            continue
        except KeyError:
            continue

        # Collect teammate qualifying data
        team_df = qualifying_df.loc[qualifying_df['Car']==team]
        try:
            event_df.loc[team_df.index[1], 'beat_teammate_qualifying'].append(0)
            event_df.loc[team_df.index[0], 'beat_teammate_qualifying'].append(1)
        except IndexError:
            continue

    for driver in drivers:
        # Collect position gain data
        if race_df.loc[driver, 'Pos'] == 'NC':
            gain = 0
        elif race_df.loc[driver, 'Time/Retired'] in ['DNF', 'DNS']:
            gain = 0
        else:
            try:
                gain = int(grid_df.loc[driver, 'Pos']) - int(race_df.loc[driver, 'Pos'])
            except KeyError:
                gain = 20 - int(race_df.loc[driver, 'Pos'])
            except ValueError:
                gain = 0
        event_df.loc[driver, 'position_gain'].append(gain)
        
        # Collect Q2 qualification data
        try:
            if pd.isnull(qualifying_df.loc[driver, 'Q2']):
                event_df.loc[driver, 'q2_finish'].append(0)
            else:
                event_df.loc[driver, 'q2_finish'].append(1)
        except KeyError:
            event_df.loc[driver, 'q2_finish'].append(0)
        
        # Collect Q3 qualification data
        try:
            if pd.isnull(qualifying_df.loc[driver, 'Q3']):
                event_df.loc[driver, 'q3_finish'].append(0)
            else:
                event_df.loc[driver, 'q3_finish'].append(1)
        except KeyError:
            event_df.loc[driver, 'q3_finish'].append(0)

# We must normalise each probability towards mean to account for sample noise
event_df['P(beat_teammate_race)'] = [np.mean(l) for l in event_df['beat_teammate_race']]
event_df['P(beat_teammate_race)'] = (5 * event_df['P(beat_teammate_race)'] + 0.5) / 6
event_df['P(beat_teammate_qualifying)'] = [np.mean(l) for l in event_df['beat_teammate_qualifying']]
event_df['P(beat_teammate_qualifying)'] = (5 * event_df['P(beat_teammate_qualifying)'] + 0.5) / 6
event_df = pd.DataFrame(event_df[['team', 'P(beat_teammate_race)', 'P(beat_teammate_qualifying)']])
# event_df.head()
event_df
# Out:
#                                     team  P(beat_teammate_race)  \
# Driver
# Verstappen    Red Bull Racing Honda RBPT               0.916667
# Perez         Red Bull Racing Honda RBPT               0.083333
# Sainz                            Ferrari               0.916667
# Leclerc                          Ferrari               0.083333
# Russell                         Mercedes               0.916667
# Norris                  McLaren Mercedes               0.916667
# Hamilton                        Mercedes               0.083333
# Piastri                 McLaren Mercedes               0.083333
# Alonso      Aston Martin Aramco Mercedes               0.916667
# Stroll      Aston Martin Aramco Mercedes               0.083333
# Zhou                 Kick Sauber Ferrari               0.916667
# Magnussen                   Haas Ferrari               0.916667
# Ricciardo                  RB Honda RBPT               0.916667
# Tsunoda                    RB Honda RBPT               0.083333
# Albon                  Williams Mercedes               0.916667
# Hulkenberg                  Haas Ferrari               0.083333
# Ocon                      Alpine Renault               0.916667
# Gasly                     Alpine Renault               0.083333
# Bottas               Kick Sauber Ferrari               0.083333
# Sargeant               Williams Mercedes               0.083333
#
#             P(beat_teammate_qualifying)
# Driver
# Verstappen                     0.916667
# Perez                          0.083333
# Sainz                          0.083333
# Leclerc                        0.916667
# Russell                        0.916667
# Norris                         0.916667
# Hamilton                       0.083333
# Piastri                        0.083333
# Alonso                         0.916667
# Stroll                         0.083333
# Zhou                           0.083333
# Magnussen                      0.083333
# Ricciardo                      0.083333
# Tsunoda                        0.916667
# Albon                          0.916667
# Hulkenberg                     0.916667
# Ocon                           0.916667
# Gasly                          0.083333
# Bottas                         0.916667
# Sargeant                       0.083333

# %% [markdown]
# Finally, we must adjust the beating teammate probabilities to take into account the events that either (or both) drivers in each team are not classified in the race:

# %%
for team in event_df.team.unique():
    drivers = event_df[event_df['team']==team].index.tolist()
    p_no_dnf = (1 - df.loc[drivers[0], 'dnf']) * (1 - df.loc[drivers[1], 'dnf'])
    
        
    adjusted = adjust_odds(np.array(event_df.loc[drivers, 'P(beat_teammate_race)']), p_no_dnf, method='linear')
    event_df.loc[drivers, 'P(beat_teammate_race)'] = adjusted

        
    event_df.loc[drivers[0], 'P(beat_teammate_race)'] += (1 - df.loc[drivers[0], 'dnf']) * df.loc[drivers[1], 'dnf']
    event_df.loc[drivers[1], 'P(beat_teammate_race)'] += (1 - df.loc[drivers[1], 'dnf']) * df.loc[drivers[0], 'dnf']
    
event_df
# Out:
#                                     team  P(beat_teammate_race)  \
# Driver
# Verstappen    Red Bull Racing Honda RBPT               0.894571
# Perez         Red Bull Racing Honda RBPT               0.103828
# Sainz                            Ferrari               0.862995
# Leclerc                          Ferrari               0.132134
# Russell                         Mercedes               0.840485
# Norris                  McLaren Mercedes               0.898282
# Hamilton                        Mercedes               0.157037
# Piastri                 McLaren Mercedes               0.101412
# Alonso      Aston Martin Aramco Mercedes               0.854480
# Stroll      Aston Martin Aramco Mercedes               0.139104
# Zhou                 Kick Sauber Ferrari               0.874499
# Magnussen                   Haas Ferrari               0.848523
# Ricciardo                  RB Honda RBPT               0.905881
# Tsunoda                    RB Honda RBPT               0.091825
# Albon                  Williams Mercedes               0.860731
# Hulkenberg                  Haas Ferrari               0.150858
# Ocon                      Alpine Renault               0.833984
# Gasly                     Alpine Renault               0.158786
# Bottas               Kick Sauber Ferrari               0.119560
# Sargeant               Williams Mercedes               0.136283
#
#             P(beat_teammate_qualifying)
# Driver
# Verstappen                     0.916667
# Perez                          0.083333
# Sainz                          0.083333
# Leclerc                        0.916667
# Russell                        0.916667
# Norris                         0.916667
# Hamilton                       0.083333
# Piastri                        0.083333
# Alonso                         0.916667
# Stroll                         0.083333
# Zhou                           0.083333
# Magnussen                      0.083333
# Ricciardo                      0.083333
# Tsunoda                        0.916667
# Albon                          0.916667
# Hulkenberg                     0.916667
# Ocon                           0.916667
# Gasly                          0.083333
# Bottas                         0.916667
# Sargeant                       0.083333

# %%
for driver in df.index:
    if driver in event_df.index:
        ev_df.loc[driver, 'beat_teammate'] = event_df.loc[driver, 'P(beat_teammate_race)'] * 3 \
                                        + event_df.loc[driver, 'P(beat_teammate_qualifying)'] * 2
    else:
        print(driver)
        ev_df.loc[driver, 'beat_teammate'] = 0

# %% [markdown]
# The last source of Fantasy F1 points we need to model is streaks - drivers get 5 points for a qualifying streak and 10 points for a race streak.

# %%
q_streak_drivers = []
race_streak_drivers = []

# %%
for driver in pos_df.index:
    if driver in q_streak_drivers:
        streak_prob = q3_finish_pts(pos_df.loc[driver, 'mean_pos']) / 3
        ev_df.loc[driver, 'q_streak'] = streak_prob * 5
    else:
        ev_df.loc[driver, 'q_streak'] = 0

for driver in pos_df.index:
    if driver in race_streak_drivers:
        streak_prob = sum([pos_df.loc[driver, i] for i in range(1,11)])
        ev_df.loc[driver, 'race_streak'] = streak_prob * 10
    else:
        ev_df.loc[driver, 'race_streak'] = 0
        
ev_df
# Out:
#                  race      flap       dnf      qual      gain         q  \
# driver
# Hamilton    13.512162  0.911278 -0.434703  5.782725  1.551455  4.623366
# Perez       12.007024  0.531983 -0.828573  4.987489  1.601189  4.536237
# Ricciardo    3.488095  0.076206 -0.320030  0.762688  1.986835  2.426260
# Bottas       5.471686  0.304230 -1.613282  1.743706  1.863075  3.333040
# Verstappen  21.361951  1.517703 -0.434703  8.007533  1.427817  4.738927
# Sainz        9.845794  0.152264 -0.973943  4.581609  1.628061  4.474552
# Ocon         4.171973  0.010088 -1.445447  2.485279  1.790362  3.801549
# Leclerc     10.342090  0.228265 -1.125465  4.659518  1.622816  4.487507
# Russell      7.661355  0.380168 -1.282745  2.951319  1.749865  4.022034
# Alonso       6.513831  0.076206 -1.125465  3.359878  1.716806  4.175968
# Gasly        4.124979  0.076206 -1.125465  1.687102  1.869170  3.290635
# Norris       7.746614  0.304230 -0.320030  3.698853  1.690813  4.280136
# Piastri      2.311307  0.152264 -0.215637  0.264948  2.078382  1.718470
# Magnussen    1.497525  0.010088 -1.125465  0.185702  2.097440  1.567846
# Stroll       3.107688  0.010088 -1.282745  1.411564  1.900278  3.069212
# Tsunoda      1.957187  0.076206 -1.613282  0.612688  2.010964  2.242394
# Hulkenberg   1.066996  0.010088 -0.123609  0.000000  2.188445  0.846770
# Albon        1.452220  0.010088 -0.973943  0.227989  2.087020  1.650312
# Zhou         1.265697  0.152264 -0.828573  0.070599  2.129734  1.311155
# Sargeant     1.029434  0.010088 -0.689829  0.000000  2.187802  0.851786
#
#             beat_teammate  q_streak  race_streak
# driver
# Hamilton         0.637776       0.0          0.0
# Perez            0.478150       0.0          0.0
# Ricciardo        2.884309       0.0          0.0
# Bottas           2.192013       0.0          0.0
# Verstappen       4.517047       0.0          0.0
# Sainz            2.755650       0.0          0.0
# Ocon             4.335285       0.0          0.0
# Leclerc          2.229735       0.0          0.0
# Russell          4.354789       0.0          0.0
# Alonso           4.396773       0.0          0.0
# Gasly            0.643024       0.0          0.0
# Norris           4.528178       0.0          0.0
# Piastri          0.470901       0.0          0.0
# Magnussen        2.712237       0.0          0.0
# Stroll           0.583978       0.0          0.0
# Tsunoda          2.108807       0.0          0.0
# Hulkenberg       2.285908       0.0          0.0
# Albon            4.415528       0.0          0.0
# Zhou             2.790164       0.0          0.0
# Sargeant         0.575514       0.0          0.0

# %% [markdown]
# And those are all the point sources for drivers! Let's compile this into a new DataFrame to review:

# %%
driver_df = pd.DataFrame(ev_df.T.sum(), columns=['EV'])
driver_df.sort_values(by='EV', ascending=False)
# Out:
#                    EV
# driver
# Verstappen  41.136276
# Hamilton    26.584060
# Perez       23.313499
# Sainz       22.463988
# Leclerc     22.444465
# Norris      21.928794
# Russell     19.836785
# Alonso      19.113996
# Ocon        15.149089
# Bottas      13.294467
# Ricciardo   11.304362
# Gasly       10.565651
# Albon        8.869214
# Stroll       8.800064
# Tsunoda      7.394965
# Magnussen    6.945372
# Zhou         6.891041
# Piastri      6.780635
# Hulkenberg   6.274597
# Sargeant     3.964795

# %% [markdown]
# Next, let's add up the current points projections for constructors:

# %%
team_df = pd.DataFrame(index=pos_df['team'].unique().tolist())

for team in pos_df['team'].unique():
    t_df = ev_df[pos_df['team']==team]
    team_df.loc[team, 'EV'] = t_df['race'].sum() + t_df['qual'].sum() + t_df['q'].sum() + t_df['gain'].sum() 
team_df.sort_values(by='EV', ascending=False)
# Out:
#                      EV
# Red Bull      58.668167
# Mercedes      41.854281
# Ferrari       41.641948
# Aston Martin  25.255225
# McLaren       23.789523
# Alpine        23.221048
# Sauber        17.188692
# RB            15.487111
# Williams       9.486563
# Haas           9.450723

# %% [markdown]
# Constructors also get 5 points if both of their drivers get streaks in qualifying and 10 in race. We can work out the probability of this happening with the values from $\texttt{pos_df}$.

# %%
q_streak_teams = []
race_streak_teams = []

# %%
for team in q_streak_teams:
    drivers = pos_df[pos_df['team']==team].index.tolist()
    streak_prob = q3_finish_pts(pos_df.loc[drivers[0], 'mean_pos']) / 3 * q3_finish_pts(pos_df.loc[drivers[1], 'mean_pos']) / 3
    team_df.loc[team, 'EV'] += streak_prob * 5

for team in race_streak_teams:
    drivers = pos_df[pos_df['team']==team].index.tolist()
    streak_prob = sum([pos_df.loc[drivers[0], i] for i in range(1,11)]) * sum([pos_df.loc[drivers[1], i] for i in range(1,11)])
    team_df.loc[team, 'EV'] += streak_prob * 10

team_df.sort_values(by='EV', ascending=False)
# Out:
#                      EV
# Red Bull      58.668167
# Mercedes      41.854281
# Ferrari       41.641948
# Aston Martin  25.255225
# McLaren       23.789523
# Alpine        23.221048
# Sauber        17.188692
# RB            15.487111
# Williams       9.486563
# Haas           9.450723

# %% [markdown]
# ## Optimising EV Projections

# %% [markdown]
# Now we move onto the last part of the model - using these EV projections to optimise teams.
#
# To do this, we need to get the prices of each driver and constructor.

# %%
# https://docs.google.com/spreadsheets/d/1b5486fzknvQgXJxPuS7U88HwMYLrz-EfdfTO3-w5qx0/pub?output=csv

prices_pd = pd.read_csv('https://docs.google.com/spreadsheets/d/1b5486fzknvQgXJxPuS7U88HwMYLrz-EfdfTO3-w5qx0/pub?output=csv')

# Lists of known driver and team names for filtering
known_drivers = [
    "Verstappen", "Norris", "Perez", "Hamilton", "Leclerc", 
    "Piastri", "Russell", "Sainz", "Alonso", "Stroll", 
    "Ricciardo", "Tsunoda", "Gasly", "Ocon", "Albon", 
    "Zhou", "Bottas", "Hulkenberg", "Magnussen", "Sargeant"
]

known_teams = [
    "Red Bull", "Mclaren", "Mercedes", "Ferrari", "Aston Martin",
    "RB", "Alpine", "Sauber", "Williams", "Haas"
]

# Extract necessary columns for driver_prices
driver_prices_df = prices_pd[['Name', 'CurrentPrice']]
driver_prices_df = driver_prices_df.dropna()  # Drop any rows with missing values

# Convert dataframe to dictionary with 'Name' as keys and 'CurrentPrice' as values
driver_prices = dict(zip(driver_prices_df['Name'], driver_prices_df['CurrentPrice']))

# Filter driver_prices to include only known drivers
driver_prices_filtered = {k: float(v) for k, v in driver_prices.items() if k in known_drivers}

# Since 'Sauber' is listed as 'Kick Sauber' in the extracted data, adjust the known_teams list for matching
known_teams_adjusted = [team if team != "Sauber" else "Kick Sauber" for team in known_teams]

# Filter the original dictionary to include only known teams
team_prices_filtered = {k: float(v) for k, v in driver_prices.items() if k in known_teams_adjusted}

# driver_prices_filtered, team_prices_filtered

driver_prices, team_prices = driver_prices_filtered, team_prices_filtered

print(driver_prices)

team_prices['Sauber'] = team_prices.pop('Kick Sauber')
team_prices['McLaren'] = team_prices.pop('Mclaren')

print(team_prices)

# driver_prices = {
#     "Verstappen": 30,
#     "Norris": 23,
#     "Perez": 20.8,
#     "Hamilton": 19.3,
#     "Leclerc": 19.1,
#     "Piastri": 19,
#     "Russell": 18.8,
#     "Sainz": 18.5,
#     "Alonso": 15.8,
#     "Stroll": 10.7,
#     "Ricciardo": 9,
#     "Tsunoda": 8,
#     "Gasly": 7.8,
#     "Ocon": 7.8,
#     "Albon": 7,
#     "Zhou": 6.6,
#     "Bottas": 6.4,
#     "Hulkenberg": 6.4,
#     "Magnussen": 6.2,
#     "Sargeant": 5.5
# }

# team_prices = {
#     "Red Bull": 27.9,
#     "McLaren": 23.2,
#     "Mercedes": 20.1,
#     "Ferrari": 19.3,
#     "Aston Martin": 13.6,
#     "RB": 8.5,
#     "Alpine": 8.4,
#     "Sauber": 6.6,
#     "Williams": 6.3,
#     "Haas": 6.3
# }



for i in driver_prices:
    driver_df.loc[i, 'price'] = driver_prices[i]

for i in team_prices:
    team_df.loc[i, 'price'] = team_prices[i]
    
    
print(driver_df)
print(team_df)
# Out:
# {'Hamilton': 19.0, 'Russell': 18.7, 'Leclerc': 21.4, 'Sainz': 19.8, 'Verstappen': 29.7, 'Perez': 22.4, 'Norris': 23.5, 'Piastri': 19.7, 'Alonso': 16.3, 'Stroll': 12.0, 'Gasly': 7.4, 'Ocon': 8.6, 'Tsunoda': 8.1, 'Ricciardo': 9.2, 'Albon': 7.2, 'Sargeant': 5.9, 'Bottas': 5.9, 'Zhou': 6.8, 'Magnussen': 7.7, 'Hulkenberg': 7.2}
# {'Mercedes': 19.8, 'Ferrari': 20.9, 'Red Bull': 28.2, 'Aston Martin': 14.5, 'Alpine': 8.0, 'RB': 8.8, 'Williams': 6.6, 'Haas': 7.2, 'Sauber': 6.2, 'McLaren': 23.9}
#                    EV  price
# driver
# Hamilton    26.584060   19.0
# Perez       23.313499   22.4
# Ricciardo   11.304362    9.2
# Bottas      13.294467    5.9
# Verstappen  41.136276   29.7
# Sainz       22.463988   19.8
# Ocon        15.149089    8.6
# Leclerc     22.444465   21.4
# Russell     19.836785   18.7
# Alonso      19.113996   16.3
# Gasly       10.565651    7.4
# Norris      21.928794   23.5
# Piastri      6.780635   19.7
# Magnussen    6.945372    7.7
# Stroll       8.800064   12.0
# Tsunoda      7.394965    8.1
# Hulkenberg   6.274597    7.2
# Albon        8.869214    7.2
# Zhou         6.891041    6.8
# Sargeant     3.964795    5.9
#                      EV  price
# Mercedes      41.854281   19.8
# Red Bull      58.668167   28.2
# RB            15.487111    8.8
# Sauber        17.188692    6.2
# Ferrari       41.641948   20.9
# Alpine        23.221048    8.0
# Aston Martin  25.255225   14.5
# McLaren       23.789523   23.9
# Haas           9.450723    7.2
# Williams       9.486563    6.6

# %%
pd.concat([team_df.sort_values(by='EV', ascending=False), driver_df.sort_values(by='EV', ascending=False)])
# Out:
#                      EV  price
# Red Bull      58.668167   28.2
# Mercedes      41.854281   19.8
# Ferrari       41.641948   20.9
# Aston Martin  25.255225   14.5
# McLaren       23.789523   23.9
# Alpine        23.221048    8.0
# Sauber        17.188692    6.2
# RB            15.487111    8.8
# Williams       9.486563    6.6
# Haas           9.450723    7.2
# Verstappen    41.136276   29.7
# Hamilton      26.584060   19.0
# Perez         23.313499   22.4
# Sainz         22.463988   19.8
# Leclerc       22.444465   21.4
# Norris        21.928794   23.5
# Russell       19.836785   18.7
# Alonso        19.113996   16.3
# Ocon          15.149089    8.6
# Bottas        13.294467    5.9
# Ricciardo     11.304362    9.2
# Gasly         10.565651    7.4
# Albon          8.869214    7.2
# Stroll         8.800064   12.0
# Tsunoda        7.394965    8.1
# Magnussen      6.945372    7.7
# Zhou           6.891041    6.8
# Piastri        6.780635   19.7
# Hulkenberg     6.274597    7.2
# Sargeant       3.964795    5.9

# %%
driver_df.sort_values(by='EV', ascending=False)
# Out:
#                    EV  price
# driver
# Verstappen  41.136276   29.7
# Hamilton    26.584060   19.0
# Perez       23.313499   22.4
# Sainz       22.463988   19.8
# Leclerc     22.444465   21.4
# Norris      21.928794   23.5
# Russell     19.836785   18.7
# Alonso      19.113996   16.3
# Ocon        15.149089    8.6
# Bottas      13.294467    5.9
# Ricciardo   11.304362    9.2
# Gasly       10.565651    7.4
# Albon        8.869214    7.2
# Stroll       8.800064   12.0
# Tsunoda      7.394965    8.1
# Magnussen    6.945372    7.7
# Zhou         6.891041    6.8
# Piastri      6.780635   19.7
# Hulkenberg   6.274597    7.2
# Sargeant     3.964795    5.9

# %% [markdown]
# At last we are ready to construct a linear optimisation model!

# %%
def solve_team(budget, owned_drivers, owned_team, force_include, force_exclude, transfers=3):
    # Turn owned_drivers and owned_team into an array for linear programming
    owned_drivers = {d: 0 + int(d in owned_drivers) for d in driver_df.index}
    owned_team = {c: 0 + int(c in owned_team) for c in team_df.index}

    # Initialise optimisation problem and set up decision variables
    prob = LpProblem("F1_model", LpMaximize)
    drivers = LpVariable.dicts('drivers', driver_df.index, cat='Binary')
    teams = LpVariable.dicts('teams', team_df.index, cat='Binary')
    turbo = LpVariable.dicts('turbo', driver_df.index, cat='Binary')
    
    # display(drivers)
    # display(teams)
    
    # Set objective function
    prob += lpSum([drivers[d] * driver_df.loc[d, 'EV'] for d in drivers]) \
            + lpSum([teams[t] * team_df.loc[t, 'EV'] for t in teams]) \
            + lpSum([turbo[d] * driver_df.loc[d, 'EV'] for d in drivers])

    # Constrain number of drivers to 5, and number of teams to 2 and turbo drivers to 1
    prob += lpSum(drivers) == 5
    prob += lpSum(teams) == 2
    prob += lpSum(turbo) == 1
    
    # Total price of assets must be less than or equal to total budget
    prob += lpSum([drivers[d] * driver_df.loc[d, 'price'] for d in drivers]) + \
            lpSum([teams[t] * team_df.loc[t, 'price'] for t in teams]) <= budget

    # Turbo driver must cost at most 19.9 - this is not a requirement for 2024
    prob += lpSum([turbo[d] * driver_df.loc[d, 'price'] for d in drivers]) <= 35.9
    for d in drivers:
        prob += turbo[d] <= drivers[d]
    
    # The total number of assets kept the same must be at least 6 minus the number of available transfers
    prob += lpSum([owned_drivers[d] * drivers[d] for d in drivers]) \
                + lpSum([owned_team[t] * teams[t] for t in teams]) >= 7 - transfers

    # Force the inclusion and exclusion of given drivers and teams
    for d in force_include['driver']:
        prob += drivers[d] == 1
    for t in force_include['team']:
        prob += teams[t] == 1
    for d in force_exclude['driver']:
        prob += drivers[d] == 0
    for t in force_exclude['team']:
        prob += teams[t] == 0
    
    # We can expect Schumacher to outscore Latifi & Russell
    # for d in ['Latifi']:
    #     prob += drivers[d] <= drivers['Schumacher']

    # Solve problem and return optimal decision variables and objective value
    status = prob.solve()
    return {
        'drivers': sorted([d for d in drivers if drivers[d].varValue == 1], key=lambda x: -driver_prices[x]),
        'team': sorted([t for t in teams if teams[t].varValue == 1], key=lambda x: -team_prices[x]),
        'turbo driver': [d for d in drivers if turbo[d].varValue == 1][0],
        'EV': value(prob.objective)
    }

# %% [markdown]
# Let's solve the problem for my team this week!

# %%
# team 1

print(
    solve_team(
        budget=103,
        owned_drivers=['Zhou', 'Leclerc', 'Bottas', 'Magnussen', 'Albon'],
        owned_team=['Ferrari', 'Red Bull'],
        force_include={'driver': ['Leclerc'], 'team': ['Ferrari', 'Red Bull']},
        force_exclude={'driver': ['Ricciardo',
                                  'Ocon', 'Gasly'], 'team': ['Alpine', 'RB']},
        transfers=2,
    )
)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/f52f66e5e0744fadab25108ec7a5fbbb-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/f52f66e5e0744fadab25108ec7a5fbbb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 39 COLUMNS
# At line 345 RHS
# At line 380 BOUNDS
# At line 431 ENDATA
# Problem MODEL has 34 rows, 50 columns and 155 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 193.945 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0003I 2 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 20 rows, 31 columns (31 integer (31 of which binary)) and 96 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.9542
# Cbc0038I Pass   1: suminf.    1.95420 (4) obj. -184.306 iterations 4
# Cbc0038I Solution found of -162.665
# Cbc0038I Before mini branch and bound, 26 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 20 rows 31 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from -162.665 to -178.219 (0.02 seconds)
# Cbc0038I Round again with cutoff of -179.587
# Cbc0038I Reduced cost fixing fixed 11 variables on major pass 2
# Cbc0038I Pass   2: suminf.    1.95420 (4) obj. -191.904 iterations 7
# Cbc0038I Pass   3: suminf.    0.12101 (2) obj. -179.587 iterations 8
# Cbc0038I Pass   4: suminf.    0.97710 (2) obj. -189.787 iterations 1
# Cbc0038I Pass   5: suminf.    0.95312 (2) obj. -183.932 iterations 4
# Cbc0038I Pass   6: suminf.    0.95312 (2) obj. -183.932 iterations 0
# Cbc0038I Pass   7: suminf.    0.35043 (2) obj. -179.587 iterations 2
# Cbc0038I Pass   8: suminf.    0.97710 (2) obj. -187.193 iterations 1
# Cbc0038I Pass   9: suminf.    0.71154 (2) obj. -185.384 iterations 1
# Cbc0038I Pass  10: suminf.    0.71154 (2) obj. -185.384 iterations 0
# Cbc0038I Pass  11: suminf.    0.90244 (2) obj. -185.485 iterations 2
# Cbc0038I Pass  12: suminf.    0.71154 (2) obj. -185.384 iterations 2
# Cbc0038I Pass  13: suminf.    0.61028 (3) obj. -179.587 iterations 5
# Cbc0038I Pass  14: suminf.    0.53255 (2) obj. -179.587 iterations 2
# Cbc0038I Pass  15: suminf.    0.74809 (2) obj. -186.17 iterations 3
# Cbc0038I Solution found of -181.199
# Cbc0038I Before mini branch and bound, 20 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 20 rows 31 columns, reduced to 3 rows 9 columns
# Cbc0038I Mini branch and bound improved solution from -181.199 to -181.649 (0.03 seconds)
# Cbc0038I Round again with cutoff of -183.7
# Cbc0038I Reduced cost fixing fixed 15 variables on major pass 3
# Cbc0038I Pass  16: suminf.    1.95420 (4) obj. -191.904 iterations 0
# Cbc0038I Pass  17: suminf.    0.48466 (2) obj. -183.7 iterations 8
# Cbc0038I Pass  18: suminf.    0.97710 (2) obj. -189.787 iterations 1
# Cbc0038I Pass  19: suminf.    0.87675 (3) obj. -183.7 iterations 4
# Cbc0038I Pass  20: suminf.    0.66521 (3) obj. -183.7 iterations 1
# Cbc0038I Pass  21: suminf.    0.83051 (2) obj. -188.555 iterations 1
# Cbc0038I Pass  22: suminf.    0.25397 (2) obj. -183.7 iterations 2
# Cbc0038I Pass  23: suminf.    0.88550 (2) obj. -188.288 iterations 2
# Cbc0038I Pass  24: suminf.    0.47985 (2) obj. -183.7 iterations 1
# Cbc0038I Pass  25: suminf.    0.82806 (3) obj. -183.7 iterations 5
# Cbc0038I Pass  26: suminf.    0.69474 (2) obj. -184.272 iterations 2
# Cbc0038I Pass  27: suminf.    0.65476 (2) obj. -183.7 iterations 3
# Cbc0038I Pass  28: suminf.    0.94656 (2) obj. -187 iterations 1
# Cbc0038I Pass  29: suminf.    0.33185 (3) obj. -183.7 iterations 3
# Cbc0038I Pass  30: suminf.    0.33185 (3) obj. -183.7 iterations 0
# Cbc0038I Pass  31: suminf.    0.83051 (2) obj. -188.555 iterations 2
# Cbc0038I Pass  32: suminf.    0.25397 (2) obj. -183.7 iterations 2
# Cbc0038I Pass  33: suminf.    0.88550 (2) obj. -188.288 iterations 2
# Cbc0038I Pass  34: suminf.    0.47985 (2) obj. -183.7 iterations 1
# Cbc0038I Pass  35: suminf.    1.21212 (6) obj. -183.7 iterations 9
# Cbc0038I Pass  36: suminf.    1.21212 (6) obj. -183.7 iterations 1
# Cbc0038I Pass  37: suminf.    0.86441 (2) obj. -188.277 iterations 4
# Cbc0038I Pass  38: suminf.    0.86441 (2) obj. -188.277 iterations 0
# Cbc0038I Pass  39: suminf.    0.48466 (2) obj. -183.7 iterations 2
# Cbc0038I Pass  40: suminf.    0.97710 (2) obj. -189.787 iterations 1
# Cbc0038I Pass  41: suminf.    0.71154 (2) obj. -187.978 iterations 1
# Cbc0038I Pass  42: suminf.    0.71154 (2) obj. -187.978 iterations 0
# Cbc0038I Pass  43: suminf.    0.98901 (2) obj. -186.715 iterations 2
# Cbc0038I Pass  44: suminf.    0.20831 (2) obj. -183.7 iterations 3
# Cbc0038I Pass  45: suminf.    0.82443 (2) obj. -188.046 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 20 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 20 rows 31 columns, reduced to 7 rows 11 columns
# Cbc0038I Mini branch and bound improved solution from -181.649 to -183.054 (0.03 seconds)
# Cbc0038I Round again with cutoff of -186.161
# Cbc0038I Reduced cost fixing fixed 17 variables on major pass 4
# Cbc0038I Pass  45: suminf.    1.95420 (4) obj. -191.904 iterations 0
# Cbc0038I Pass  46: suminf.    0.70229 (2) obj. -186.161 iterations 8
# Cbc0038I Pass  47: suminf.    0.97710 (2) obj. -189.787 iterations 1
# Cbc0038I Pass  48: suminf.    0.76957 (2) obj. -186.161 iterations 4
# Cbc0038I Pass  49: suminf.    0.74416 (2) obj. -186.161 iterations 1
# Cbc0038I Pass  50: suminf.    0.94656 (2) obj. -187 iterations 2
# Cbc0038I Pass  51: suminf.    0.87240 (2) obj. -186.161 iterations 1
# Cbc0038I Pass  52: suminf.    0.50394 (2) obj. -186.161 iterations 2
# Cbc0038I Pass  53: suminf.    0.50394 (2) obj. -186.161 iterations 0
# Cbc0038I Pass  54: suminf.    0.88550 (2) obj. -188.288 iterations 2
# Cbc0038I Pass  55: suminf.    0.69749 (2) obj. -186.161 iterations 1
# Cbc0038I Pass  56: suminf.    0.89672 (2) obj. -186.161 iterations 3
# Cbc0038I Pass  57: suminf.    0.70229 (2) obj. -186.161 iterations 1
# Cbc0038I Pass  58: suminf.    0.97710 (2) obj. -189.787 iterations 1
# Cbc0038I Pass  59: suminf.    0.97710 (2) obj. -189.787 iterations 0
# Cbc0038I Pass  60: suminf.    0.88550 (2) obj. -186.759 iterations 3
# Cbc0038I Pass  61: suminf.    0.83265 (2) obj. -186.161 iterations 1
# Cbc0038I Pass  62: suminf.    0.88550 (2) obj. -186.759 iterations 1
# Cbc0038I Pass  63: suminf.    0.97710 (2) obj. -187.193 iterations 3
# Cbc0038I Pass  64: suminf.    0.97710 (2) obj. -187.193 iterations 0
# Cbc0038I Pass  65: suminf.    0.93171 (2) obj. -186.161 iterations 1
# Cbc0038I Pass  66: suminf.    1.57515 (4) obj. -186.161 iterations 1
# Cbc0038I Pass  67: suminf.    0.93171 (2) obj. -186.161 iterations 1
# Cbc0038I Pass  68: suminf.    0.93171 (2) obj. -186.161 iterations 0
# Cbc0038I Pass  69: suminf.    0.97710 (2) obj. -187.193 iterations 1
# Cbc0038I Pass  70: suminf.    0.93171 (2) obj. -186.161 iterations 1
# Cbc0038I Pass  71: suminf.    1.65138 (4) obj. -188.685 iterations 8
# Cbc0038I Pass  72: suminf.    0.69988 (2) obj. -186.161 iterations 8
# Cbc0038I Pass  73: suminf.    0.88550 (2) obj. -186.759 iterations 2
# Cbc0038I Pass  74: suminf.    0.83265 (2) obj. -186.161 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 22 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 20 rows 31 columns, reduced to 3 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -183.054 - took 0.01 seconds
# Cbc0012I Integer solution of -183.05383 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 1 added rows had average density of 7
# Cbc0013I At root node, 1 cuts changed objective from -191.90439 to -183.05383 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 2 row cuts average 3.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 7 row cuts average 7.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -183.053831688768, took 9 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 19 variables fixed on reduced cost
# Cuts at root node changed objective from -191.904 to -183.054
# Probing was tried 3 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                183.05383169
# Enumerated nodes:               0
# Total iterations:               9
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.05
#
# {'drivers': ['Leclerc', 'Stroll', 'Albon', 'Zhou', 'Bottas'], 'team': ['Red Bull', 'Ferrari'], 'turbo driver': 'Leclerc', 'EV': 183.05383168876983}

# %%
# team 2
print(
    solve_team(
        budget=103,
        owned_drivers=['Verstappen', 'Leclerc', 'Zhou', 'Hulkenberg', 'Sargeant'],
        owned_team=['Ferrari', 'Aston Martin'],
        force_include={'driver': [], 'team': ['Ferrari']},
        force_exclude={'driver': ['Ricciardo',
                                  'Ocon', 'Gasly'], 'team': ['Alpine', 'RB']},
        transfers=3,
    )
)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/3b39c21e4a0e4044b403408fd9fc780b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/3b39c21e4a0e4044b403408fd9fc780b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 37 COLUMNS
# At line 341 RHS
# At line 374 BOUNDS
# At line 425 ENDATA
# Problem MODEL has 32 rows, 50 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 212.585 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0004I processed model has 23 rows, 41 columns (41 integer (41 of which binary)) and 122 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.145455
# Cbc0038I Pass   1: suminf.    0.14545 (2) obj. -212.585 iterations 1
# Cbc0038I Solution found of -174.123
# Cbc0038I Before mini branch and bound, 39 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 23 rows 41 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -177.969
# Cbc0038I Pass   2: suminf.    0.14545 (2) obj. -212.585 iterations 0
# Cbc0038I Pass   3: suminf.    0.18545 (2) obj. -177.969 iterations 12
# Cbc0038I Pass   4: suminf.    0.45802 (5) obj. -177.969 iterations 16
# Cbc0038I Pass   5: suminf.    0.22514 (4) obj. -177.969 iterations 4
# Cbc0038I Pass   6: suminf.    0.25210 (4) obj. -189.645 iterations 6
# Cbc0038I Pass   7: suminf.    0.22901 (2) obj. -192.033 iterations 1
# Cbc0038I Solution found of -180.265
# Cbc0038I Before mini branch and bound, 29 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 23 rows 41 columns, reduced to 9 rows 12 columns
# Cbc0038I Mini branch and bound improved solution from -180.265 to -199.904 (0.02 seconds)
# Cbc0038I Round again with cutoff of -202.44
# Cbc0038I Reduced cost fixing fixed 19 variables on major pass 3
# Cbc0038I Pass   8: suminf.    0.14545 (2) obj. -212.585 iterations 0
# Cbc0038I Pass   9: suminf.    0.63462 (2) obj. -202.44 iterations 6
# Cbc0038I Pass  10: suminf.    0.78783 (2) obj. -202.44 iterations 5
# Cbc0038I Pass  11: suminf.    0.53938 (4) obj. -202.44 iterations 7
# Cbc0038I Pass  12: suminf.    0.26364 (2) obj. -203.115 iterations 1
# Cbc0038I Pass  13: suminf.    0.29614 (2) obj. -202.44 iterations 3
# Cbc0038I Pass  14: suminf.    0.26364 (2) obj. -203.115 iterations 3
# Cbc0038I Pass  15: suminf.    0.74438 (2) obj. -202.44 iterations 7
# Cbc0038I Pass  16: suminf.    0.74438 (2) obj. -202.44 iterations 2
# Cbc0038I Pass  17: suminf.    0.78182 (2) obj. -208.052 iterations 4
# Cbc0038I Pass  18: suminf.    0.51123 (2) obj. -202.44 iterations 3
# Cbc0038I Pass  19: suminf.    0.46971 (5) obj. -202.44 iterations 4
# Cbc0038I Pass  20: suminf.    0.27421 (5) obj. -202.44 iterations 3
# Cbc0038I Pass  21: suminf.    0.14545 (2) obj. -212.585 iterations 5
# Cbc0038I Pass  22: suminf.    0.14545 (2) obj. -212.585 iterations 1
# Cbc0038I Pass  23: suminf.    0.63462 (2) obj. -202.44 iterations 4
# Cbc0038I Pass  24: suminf.    0.97103 (4) obj. -202.44 iterations 3
# Cbc0038I Pass  25: suminf.    0.97103 (4) obj. -202.44 iterations 1
# Cbc0038I Pass  26: suminf.    0.33824 (2) obj. -204.862 iterations 6
# Cbc0038I Pass  27: suminf.    0.33824 (2) obj. -204.862 iterations 4
# Cbc0038I Pass  28: suminf.    0.87141 (2) obj. -202.44 iterations 5
# Cbc0038I Pass  29: suminf.    0.97273 (2) obj. -205.673 iterations 3
# Cbc0038I Pass  30: suminf.    0.97273 (2) obj. -205.673 iterations 2
# Cbc0038I Pass  31: suminf.    0.97273 (2) obj. -205.673 iterations 2
# Cbc0038I Pass  32: suminf.    1.22606 (4) obj. -202.44 iterations 4
# Cbc0038I Pass  33: suminf.    0.22727 (2) obj. -209.414 iterations 4
# Cbc0038I Pass  34: suminf.    0.56353 (2) obj. -202.44 iterations 4
# Cbc0038I Pass  35: suminf.    1.62168 (6) obj. -202.44 iterations 4
# Cbc0038I Pass  36: suminf.    0.71634 (4) obj. -202.44 iterations 3
# Cbc0038I Pass  37: suminf.    0.71421 (4) obj. -202.44 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 25 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 23 rows 41 columns, reduced to 4 rows 14 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -199.904 - took 0.01 seconds
# Cbc0012I Integer solution of -199.90409 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0012I Integer solution of -201.0981 found by DiveCoefficient after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0031I 6 added rows had average density of 16.833333
# Cbc0013I At root node, 6 cuts changed objective from -212.5855 to -203.50764 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 6 row cuts average 4.7 elements, 2 column cuts (2 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 446 row cuts average 20.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 172 row cuts average 8.9 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 246 row cuts average 18.1 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 109 row cuts average 16.9 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -201.0981 best solution, best possible -203.50764 (0.11 seconds)
# Cbc0001I Search completed - best objective -201.098100418083, took 1358 iterations and 8 nodes (0.12 seconds)
# Cbc0032I Strong branching done 52 times (184 iterations), fathomed 1 nodes and fixed 1 variables
# Cbc0035I Maximum depth 3, 45 variables fixed on reduced cost
# Cuts at root node changed objective from -212.585 to -203.508
# Probing was tried 100 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Gomory was tried 118 times and created 459 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Knapsack was tried 118 times and created 192 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 118 times and created 284 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 118 times and created 131 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                201.09810042
# Enumerated nodes:               8
# Total iterations:               1358
# Time (CPU seconds):             0.10
# Time (Wallclock seconds):       0.12
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.13
#
# {'drivers': ['Verstappen', 'Hulkenberg', 'Albon', 'Zhou', 'Bottas'], 'team': ['Ferrari', 'Mercedes'], 'turbo driver': 'Verstappen', 'EV': 201.09810041808845}

# %% [markdown]
# Over a range of different prices, here are the optimal solutions:

# %%
optimal_teams = {}

min_budget, max_budget = 100, 103
last_team = {}
b = min_budget
while b <= max_budget:
    b = round(b, 1)
    team = solve_team(
                budget=b,
                owned_drivers=[],
                owned_team=[],
                force_include={'driver': [], 'team': []},
                force_exclude={'driver': ['Ricciardo',
                                  'Ocon', 'Gasly'], 'team': ['Alpine', 'RB']},
                transfers=12
                )
    if team != last_team:
        optimal_teams[b] = team
    last_team = team
    b += 0.1

out_df = pd.DataFrame(optimal_teams).T
for i in range(5):
    out_df[f'driver {i+1}'] = [d[i] for d in out_df['drivers']]
out_df.index = [f'{out_df.index[i-1]}-{round(out_df.index[i] - 0.1, 1)}' 
                for i in range(1, len(out_df))] + [f'{out_df.index[-1]}-{max_budget}']
out_df.index.name = 'budget range'
out_df.drop('drivers', axis=1)[['driver 1', 'driver 2', 'driver 3', 'driver 4', 'driver 5', 
                                'turbo driver', 'team', 'EV']]
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/6422b351b2f441f1b11c40a9f6188119-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/6422b351b2f441f1b11c40a9f6188119-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 332 RHS
# At line 364 BOUNDS
# At line 415 ENDATA
# Problem MODEL has 31 rows, 50 columns and 145 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 209.467 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0004I processed model has 22 rows, 42 columns (42 integer (42 of which binary)) and 118 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.514706
# Cbc0038I Pass   1: suminf.    0.32407 (2) obj. -207.845 iterations 6
# Cbc0038I Solution found of -166.633
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -166.633 to -191.149 (0.00 seconds)
# Cbc0038I Round again with cutoff of -192.981
# Cbc0038I Reduced cost fixing fixed 11 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.32407 (2) obj. -207.845 iterations 0
# Cbc0038I Pass   3: suminf.    0.92855 (2) obj. -192.981 iterations 8
# Cbc0038I Pass   4: suminf.    0.97961 (4) obj. -192.981 iterations 10
# Cbc0038I Pass   5: suminf.    0.57440 (2) obj. -192.981 iterations 4
# Cbc0038I Pass   6: suminf.    0.79630 (2) obj. -198.437 iterations 5
# Cbc0038I Pass   7: suminf.    1.17865 (4) obj. -192.981 iterations 6
# Cbc0038I Pass   8: suminf.    0.57543 (2) obj. -192.981 iterations 5
# Cbc0038I Pass   9: suminf.    1.19828 (4) obj. -192.981 iterations 6
# Cbc0038I Pass  10: suminf.    0.62871 (2) obj. -192.981 iterations 2
# Cbc0038I Pass  11: suminf.    0.36111 (2) obj. -206.318 iterations 12
# Cbc0038I Pass  12: suminf.    0.90348 (2) obj. -192.981 iterations 4
# Cbc0038I Pass  13: suminf.    2.15187 (6) obj. -192.981 iterations 11
# Cbc0038I Pass  14: suminf.    2.05052 (6) obj. -192.981 iterations 6
# Cbc0038I Pass  15: suminf.    0.78504 (2) obj. -192.981 iterations 9
# Cbc0038I Pass  16: suminf.    0.52778 (2) obj. -205.2 iterations 5
# Cbc0038I Pass  17: suminf.    0.97531 (2) obj. -192.981 iterations 6
# Cbc0038I Pass  18: suminf.    1.22205 (4) obj. -192.981 iterations 6
# Cbc0038I Pass  19: suminf.    1.07990 (4) obj. -192.981 iterations 2
# Cbc0038I Pass  20: suminf.    0.49074 (2) obj. -206.727 iterations 6
# Cbc0038I Pass  21: suminf.    0.95024 (2) obj. -192.981 iterations 6
# Cbc0038I Pass  22: suminf.    1.37252 (6) obj. -192.981 iterations 8
# Cbc0038I Pass  23: suminf.    0.42647 (2) obj. -199.761 iterations 10
# Cbc0038I Pass  24: suminf.    0.60876 (2) obj. -192.981 iterations 7
# Cbc0038I Pass  25: suminf.    0.95370 (2) obj. -196.105 iterations 5
# Cbc0038I Pass  26: suminf.    0.82663 (2) obj. -192.981 iterations 5
# Cbc0038I Pass  27: suminf.    0.77559 (4) obj. -192.981 iterations 9
# Cbc0038I Pass  28: suminf.    0.17687 (2) obj. -195.176 iterations 5
# Cbc0038I Pass  29: suminf.    0.96894 (2) obj. -192.981 iterations 6
# Cbc0038I Pass  30: suminf.    0.79630 (2) obj. -194.783 iterations 6
# Cbc0038I Pass  31: suminf.    0.86959 (2) obj. -192.981 iterations 5
# Cbc0038I Rounding solution of -193.513 is better than previous of -191.149
#
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 8 rows 22 columns
# Cbc0038I Mini branch and bound improved solution from -193.513 to -203.372 (0.01 seconds)
# Cbc0038I Round again with cutoff of -204.591
# Cbc0038I Reduced cost fixing fixed 28 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.31818 (2) obj. -209.216 iterations 4
# Cbc0038I Pass  32: suminf.    0.54117 (2) obj. -204.591 iterations 4
# Cbc0038I Pass  33: suminf.    0.54117 (2) obj. -204.591 iterations 0
# Cbc0038I Pass  34: suminf.    0.54117 (2) obj. -204.591 iterations 0
# Cbc0038I Pass  35: suminf.    1.57721 (4) obj. -204.591 iterations 6
# Cbc0038I Pass  36: suminf.    0.79053 (2) obj. -204.591 iterations 3
# Cbc0038I Pass  37: suminf.    0.40000 (2) obj. -206.044 iterations 5
# Cbc0038I Pass  38: suminf.    0.47008 (2) obj. -204.591 iterations 3
# Cbc0038I Pass  39: suminf.    0.83366 (4) obj. -204.591 iterations 2
# Cbc0038I Pass  40: suminf.    0.82030 (4) obj. -204.591 iterations 1
# Cbc0038I Pass  41: suminf.    0.49091 (2) obj. -207.136 iterations 2
# Cbc0038I Pass  42: suminf.    0.36821 (2) obj. -204.591 iterations 2
# Cbc0038I Pass  43: suminf.    0.71429 (2) obj. -205.169 iterations 5
# Cbc0038I Pass  44: suminf.    0.45802 (2) obj. -205.994 iterations 1
# Cbc0038I Pass  45: suminf.    0.69968 (2) obj. -204.591 iterations 2
# Cbc0038I Pass  46: suminf.    0.31818 (2) obj. -206.621 iterations 4
# Cbc0038I Pass  47: suminf.    0.41606 (2) obj. -204.591 iterations 3
# Cbc0038I Pass  48: suminf.    0.47031 (3) obj. -204.591 iterations 5
# Cbc0038I Pass  49: suminf.    0.47031 (3) obj. -204.591 iterations 0
# Cbc0038I Pass  50: suminf.    0.69968 (2) obj. -204.591 iterations 4
# Cbc0038I Pass  51: suminf.    0.48241 (2) obj. -204.591 iterations 3
# Cbc0038I Pass  52: suminf.    0.28814 (2) obj. -206.312 iterations 3
# Cbc0038I Pass  53: suminf.    0.91007 (2) obj. -204.591 iterations 5
# Cbc0038I Pass  54: suminf.    0.31818 (2) obj. -209.216 iterations 4
# Cbc0038I Pass  55: suminf.    0.54117 (2) obj. -204.591 iterations 3
# Cbc0038I Pass  56: suminf.    0.91007 (2) obj. -204.591 iterations 2
# Cbc0038I Pass  57: suminf.    0.81180 (2) obj. -204.591 iterations 3
# Cbc0038I Pass  58: suminf.    0.81180 (2) obj. -204.591 iterations 1
# Cbc0038I Pass  59: suminf.    0.51818 (2) obj. -208.498 iterations 4
# Cbc0038I Pass  60: suminf.    0.70656 (2) obj. -204.591 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 3 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -203.372 - took 0.01 seconds
# Cbc0012I Integer solution of -203.37188 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 5 added rows had average density of 7
# Cbc0013I At root node, 5 cuts changed objective from -209.46676 to -204.22099 in 9 passes
# Cbc0014I Cut generator 0 (Probing) - 6 row cuts average 3.5 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 13 row cuts average 4.9 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 4 row cuts average 9.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 67 row cuts average 11.4 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -203.37188 best solution, best possible -203.82021 (0.02 seconds)
# Cbc0001I Search completed - best objective -203.371884710689, took 61 iterations and 2 nodes (0.02 seconds)
# Cbc0032I Strong branching done 12 times (38 iterations), fathomed 0 nodes and fixed 2 variables
# Cbc0035I Maximum depth 0, 28 variables fixed on reduced cost
# Cuts at root node changed objective from -209.467 to -203.82
# Probing was tried 9 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 9 times and created 13 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 9 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 9 times and created 67 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                203.37188471
# Enumerated nodes:               2
# Total iterations:               61
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/fc8165ff63ad41e88aefed32f8d6bdf0-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/fc8165ff63ad41e88aefed32f8d6bdf0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 332 RHS
# At line 364 BOUNDS
# At line 415 ENDATA
# Problem MODEL has 31 rows, 50 columns and 145 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 209.648 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0004I processed model has 22 rows, 42 columns (42 integer (42 of which binary)) and 118 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.5
# Cbc0038I Pass   1: suminf.    0.31481 (2) obj. -208.073 iterations 6
# Cbc0038I Solution found of -166.633
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -166.633 to -191.149 (0.00 seconds)
# Cbc0038I Round again with cutoff of -192.999
# Cbc0038I Reduced cost fixing fixed 11 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.31481 (2) obj. -208.073 iterations 0
# Cbc0038I Pass   3: suminf.    0.92781 (2) obj. -192.999 iterations 8
# Cbc0038I Pass   4: suminf.    0.99591 (4) obj. -192.999 iterations 10
# Cbc0038I Pass   5: suminf.    0.57513 (2) obj. -192.999 iterations 4
# Cbc0038I Pass   6: suminf.    0.80556 (2) obj. -198.665 iterations 5
# Cbc0038I Pass   7: suminf.    1.20781 (4) obj. -192.999 iterations 6
# Cbc0038I Pass   8: suminf.    0.57617 (2) obj. -192.999 iterations 5
# Cbc0038I Pass   9: suminf.    1.21057 (4) obj. -192.999 iterations 6
# Cbc0038I Pass  10: suminf.    0.62983 (2) obj. -192.999 iterations 2
# Cbc0038I Pass  11: suminf.    0.35185 (2) obj. -206.546 iterations 12
# Cbc0038I Pass  12: suminf.    0.90274 (2) obj. -192.999 iterations 4
# Cbc0038I Pass  13: suminf.    2.10765 (6) obj. -192.999 iterations 11
# Cbc0038I Pass  14: suminf.    2.01233 (6) obj. -192.999 iterations 6
# Cbc0038I Pass  15: suminf.    0.78592 (2) obj. -192.999 iterations 9
# Cbc0038I Pass  16: suminf.    0.51852 (2) obj. -205.428 iterations 5
# Cbc0038I Pass  17: suminf.    0.97605 (2) obj. -192.999 iterations 6
# Cbc0038I Pass  18: suminf.    1.18833 (4) obj. -192.999 iterations 6
# Cbc0038I Pass  19: suminf.    1.05213 (4) obj. -192.999 iterations 2
# Cbc0038I Pass  20: suminf.    0.48148 (2) obj. -206.955 iterations 6
# Cbc0038I Pass  21: suminf.    0.95098 (2) obj. -192.999 iterations 6
# Cbc0038I Pass  22: suminf.    1.36574 (6) obj. -192.999 iterations 8
# Cbc0038I Pass  23: suminf.    0.41176 (2) obj. -199.943 iterations 10
# Cbc0038I Pass  24: suminf.    0.60963 (2) obj. -192.999 iterations 7
# Cbc0038I Pass  25: suminf.    0.96296 (2) obj. -196.333 iterations 5
# Cbc0038I Pass  26: suminf.    0.82737 (2) obj. -192.999 iterations 5
# Cbc0038I Pass  27: suminf.    0.84717 (4) obj. -192.999 iterations 9
# Cbc0038I Pass  28: suminf.    0.16327 (2) obj. -195.342 iterations 5
# Cbc0038I Pass  29: suminf.    0.96981 (2) obj. -192.999 iterations 6
# Cbc0038I Pass  30: suminf.    0.78704 (2) obj. -195.011 iterations 6
# Cbc0038I Pass  31: suminf.    0.86885 (2) obj. -192.999 iterations 5
# Cbc0038I Rounding solution of -193.513 is better than previous of -191.149
#
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 9 rows 23 columns
# Cbc0038I Mini branch and bound improved solution from -193.513 to -203.372 (0.01 seconds)
# Cbc0038I Round again with cutoff of -204.627
# Cbc0038I Reduced cost fixing fixed 28 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.30909 (2) obj. -209.404 iterations 4
# Cbc0038I Pass  32: suminf.    0.53942 (2) obj. -204.627 iterations 4
# Cbc0038I Pass  33: suminf.    0.53942 (2) obj. -204.627 iterations 0
# Cbc0038I Pass  34: suminf.    0.53942 (2) obj. -204.627 iterations 0
# Cbc0038I Pass  35: suminf.    1.54772 (4) obj. -204.627 iterations 6
# Cbc0038I Pass  36: suminf.    0.79728 (4) obj. -204.627 iterations 3
# Cbc0038I Pass  37: suminf.    0.50909 (2) obj. -208.686 iterations 6
# Cbc0038I Pass  38: suminf.    0.70481 (2) obj. -204.627 iterations 2
# Cbc0038I Pass  39: suminf.    0.70481 (2) obj. -204.627 iterations 0
# Cbc0038I Pass  40: suminf.    0.30909 (2) obj. -209.404 iterations 2
# Cbc0038I Pass  41: suminf.    0.30909 (2) obj. -209.404 iterations 1
# Cbc0038I Pass  42: suminf.    0.53942 (2) obj. -204.627 iterations 2
# Cbc0038I Pass  43: suminf.    0.91268 (2) obj. -204.627 iterations 2
# Cbc0038I Pass  44: suminf.    0.36996 (2) obj. -204.627 iterations 2
# Cbc0038I Pass  45: suminf.    0.50000 (2) obj. -207.324 iterations 2
# Cbc0038I Pass  46: suminf.    0.36996 (2) obj. -204.627 iterations 2
# Cbc0038I Pass  47: suminf.    0.50000 (2) obj. -207.324 iterations 2
# Cbc0038I Pass  48: suminf.    0.58182 (2) obj. -206.095 iterations 3
# Cbc0038I Pass  49: suminf.    0.51105 (2) obj. -204.627 iterations 2
# Cbc0038I Pass  50: suminf.    0.58182 (2) obj. -206.095 iterations 2
# Cbc0038I Pass  51: suminf.    0.42727 (2) obj. -207.457 iterations 2
# Cbc0038I Pass  52: suminf.    0.42727 (2) obj. -207.457 iterations 1
# Cbc0038I Pass  53: suminf.    0.56372 (2) obj. -204.627 iterations 3
# Cbc0038I Pass  54: suminf.    0.69860 (4) obj. -204.627 iterations 5
# Cbc0038I Pass  55: suminf.    0.69860 (4) obj. -204.627 iterations 0
# Cbc0038I Pass  56: suminf.    0.65341 (2) obj. -204.627 iterations 3
# Cbc0038I Pass  57: suminf.    0.50909 (2) obj. -207.62 iterations 3
# Cbc0038I Pass  58: suminf.    0.39091 (2) obj. -207.761 iterations 1
# Cbc0038I Pass  59: suminf.    0.39091 (2) obj. -207.761 iterations 1
# Cbc0038I Pass  60: suminf.    0.54204 (2) obj. -204.627 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 31 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 3 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -203.372 - took 0.01 seconds
# Cbc0012I Integer solution of -203.37188 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 8 added rows had average density of 8.5
# Cbc0013I At root node, 8 cuts changed objective from -209.64812 to -204.38081 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 2.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 21 row cuts average 5.4 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 9 row cuts average 9.1 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 69 row cuts average 11.4 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -203.371884710689, took 61 iterations and 0 nodes (0.02 seconds)
# Cbc0032I Strong branching done 10 times (37 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 28 variables fixed on reduced cost
# Cuts at root node changed objective from -209.648 to -203.372
# Probing was tried 10 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 10 times and created 21 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 10 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 10 times and created 69 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                203.37188471
# Enumerated nodes:               0
# Total iterations:               61
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/7708b044fddf42b6a81b8cfd570ddc1d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/7708b044fddf42b6a81b8cfd570ddc1d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 332 RHS
# At line 364 BOUNDS
# At line 415 ENDATA
# Problem MODEL has 31 rows, 50 columns and 145 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 209.829 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0004I processed model has 22 rows, 42 columns (42 integer (42 of which binary)) and 118 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.485294
# Cbc0038I Pass   1: suminf.    0.30556 (2) obj. -208.301 iterations 6
# Cbc0038I Solution found of -166.633
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -166.633 to -191.149 (0.00 seconds)
# Cbc0038I Round again with cutoff of -193.017
# Cbc0038I Reduced cost fixing fixed 11 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.30556 (2) obj. -208.301 iterations 0
# Cbc0038I Pass   3: suminf.    0.92708 (2) obj. -193.017 iterations 8
# Cbc0038I Pass   4: suminf.    1.01221 (4) obj. -193.017 iterations 10
# Cbc0038I Pass   5: suminf.    0.57587 (2) obj. -193.017 iterations 4
# Cbc0038I Pass   6: suminf.    0.81481 (2) obj. -198.893 iterations 5
# Cbc0038I Pass   7: suminf.    1.23697 (4) obj. -193.017 iterations 6
# Cbc0038I Pass   8: suminf.    0.57691 (2) obj. -193.017 iterations 5
# Cbc0038I Pass   9: suminf.    1.22286 (4) obj. -193.017 iterations 6
# Cbc0038I Pass  10: suminf.    0.63095 (2) obj. -193.017 iterations 2
# Cbc0038I Pass  11: suminf.    0.34259 (2) obj. -206.773 iterations 12
# Cbc0038I Pass  12: suminf.    0.90201 (2) obj. -193.017 iterations 4
# Cbc0038I Pass  13: suminf.    2.06344 (6) obj. -193.017 iterations 11
# Cbc0038I Pass  14: suminf.    1.97414 (6) obj. -193.017 iterations 6
# Cbc0038I Pass  15: suminf.    0.78679 (2) obj. -193.017 iterations 9
# Cbc0038I Pass  16: suminf.    0.50926 (2) obj. -205.656 iterations 5
# Cbc0038I Pass  17: suminf.    0.97679 (2) obj. -193.017 iterations 6
# Cbc0038I Pass  18: suminf.    1.15461 (4) obj. -193.017 iterations 6
# Cbc0038I Pass  19: suminf.    1.02436 (4) obj. -193.017 iterations 2
# Cbc0038I Pass  20: suminf.    0.47222 (2) obj. -207.183 iterations 6
# Cbc0038I Pass  21: suminf.    0.95172 (2) obj. -193.017 iterations 6
# Cbc0038I Pass  22: suminf.    1.35895 (6) obj. -193.017 iterations 8
# Cbc0038I Pass  23: suminf.    0.39706 (2) obj. -200.124 iterations 10
# Cbc0038I Pass  24: suminf.    0.61051 (2) obj. -193.017 iterations 7
# Cbc0038I Pass  25: suminf.    0.97222 (2) obj. -196.561 iterations 5
# Cbc0038I Pass  26: suminf.    0.82811 (2) obj. -193.017 iterations 5
# Cbc0038I Pass  27: suminf.    0.91875 (4) obj. -193.017 iterations 9
# Cbc0038I Pass  28: suminf.    0.14966 (2) obj. -195.509 iterations 5
# Cbc0038I Pass  29: suminf.    0.97069 (2) obj. -193.017 iterations 6
# Cbc0038I Pass  30: suminf.    0.77778 (2) obj. -195.238 iterations 6
# Cbc0038I Pass  31: suminf.    0.86812 (2) obj. -193.017 iterations 5
# Cbc0038I Rounding solution of -193.513 is better than previous of -191.149
#
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 9 rows 23 columns
# Cbc0038I Mini branch and bound improved solution from -193.513 to -203.372 (0.01 seconds)
# Cbc0038I Round again with cutoff of -204.663
# Cbc0038I Reduced cost fixing fixed 28 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.30000 (2) obj. -209.593 iterations 4
# Cbc0038I Pass  32: suminf.    0.53767 (2) obj. -204.663 iterations 4
# Cbc0038I Pass  33: suminf.    0.53767 (2) obj. -204.663 iterations 0
# Cbc0038I Pass  34: suminf.    0.53767 (2) obj. -204.663 iterations 0
# Cbc0038I Pass  35: suminf.    1.42450 (4) obj. -204.663 iterations 6
# Cbc0038I Pass  36: suminf.    0.73461 (4) obj. -204.663 iterations 3
# Cbc0038I Pass  37: suminf.    0.50000 (2) obj. -208.875 iterations 6
# Cbc0038I Pass  38: suminf.    0.70306 (2) obj. -204.663 iterations 2
# Cbc0038I Pass  39: suminf.    0.70306 (2) obj. -204.663 iterations 0
# Cbc0038I Pass  40: suminf.    0.30000 (2) obj. -209.593 iterations 2
# Cbc0038I Pass  41: suminf.    0.30000 (2) obj. -209.593 iterations 1
# Cbc0038I Pass  42: suminf.    0.53767 (2) obj. -204.663 iterations 2
# Cbc0038I Pass  43: suminf.    0.91699 (2) obj. -204.663 iterations 2
# Cbc0038I Pass  44: suminf.    0.37171 (2) obj. -204.663 iterations 2
# Cbc0038I Pass  45: suminf.    0.50909 (2) obj. -207.513 iterations 2
# Cbc0038I Pass  46: suminf.    0.37171 (2) obj. -204.663 iterations 2
# Cbc0038I Pass  47: suminf.    0.50909 (2) obj. -207.513 iterations 2
# Cbc0038I Pass  48: suminf.    0.59091 (2) obj. -206.283 iterations 3
# Cbc0038I Pass  49: suminf.    0.51280 (2) obj. -204.663 iterations 2
# Cbc0038I Pass  50: suminf.    0.59091 (2) obj. -206.283 iterations 2
# Cbc0038I Pass  51: suminf.    0.41818 (2) obj. -207.645 iterations 2
# Cbc0038I Pass  52: suminf.    0.41818 (2) obj. -207.645 iterations 1
# Cbc0038I Pass  53: suminf.    0.56197 (2) obj. -204.663 iterations 3
# Cbc0038I Pass  54: suminf.    0.59740 (4) obj. -204.663 iterations 5
# Cbc0038I Pass  55: suminf.    0.59740 (4) obj. -204.663 iterations 0
# Cbc0038I Pass  56: suminf.    0.65166 (2) obj. -204.663 iterations 3
# Cbc0038I Pass  57: suminf.    0.50000 (2) obj. -207.809 iterations 3
# Cbc0038I Pass  58: suminf.    0.38182 (2) obj. -207.95 iterations 1
# Cbc0038I Pass  59: suminf.    0.38182 (2) obj. -207.95 iterations 1
# Cbc0038I Pass  60: suminf.    0.54029 (2) obj. -204.663 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 31 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 3 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -203.372 - took 0.01 seconds
# Cbc0012I Integer solution of -203.37188 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 5 added rows had average density of 6.2
# Cbc0013I At root node, 5 cuts changed objective from -209.82949 to -204.58925 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 9 row cuts average 2.6 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 10.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 21 row cuts average 4.6 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 4 row cuts average 5.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 54 row cuts average 10.3 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -203.37188 best solution, best possible -203.61678 (0.02 seconds)
# Cbc0001I Search completed - best objective -203.371884710689, took 61 iterations and 2 nodes (0.02 seconds)
# Cbc0032I Strong branching done 12 times (34 iterations), fathomed 0 nodes and fixed 5 variables
# Cbc0035I Maximum depth 0, 28 variables fixed on reduced cost
# Cuts at root node changed objective from -209.829 to -203.617
# Probing was tried 10 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 10 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 10 times and created 21 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 10 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 10 times and created 54 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                203.37188471
# Enumerated nodes:               2
# Total iterations:               61
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/f29c0c0d3a174555b26c6baaef915fe7-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/f29c0c0d3a174555b26c6baaef915fe7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 332 RHS
# At line 364 BOUNDS
# At line 415 ENDATA
# Problem MODEL has 31 rows, 50 columns and 145 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 210.011 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0004I processed model has 22 rows, 42 columns (42 integer (42 of which binary)) and 118 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.470588
# Cbc0038I Pass   1: suminf.    0.29630 (2) obj. -208.528 iterations 6
# Cbc0038I Solution found of -166.633
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -166.633 to -191.149 (0.00 seconds)
# Cbc0038I Round again with cutoff of -193.035
# Cbc0038I Reduced cost fixing fixed 11 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.29630 (2) obj. -208.528 iterations 0
# Cbc0038I Pass   3: suminf.    0.92634 (2) obj. -193.035 iterations 8
# Cbc0038I Pass   4: suminf.    1.02851 (4) obj. -193.035 iterations 10
# Cbc0038I Pass   5: suminf.    0.57661 (2) obj. -193.035 iterations 4
# Cbc0038I Pass   6: suminf.    0.82407 (2) obj. -199.121 iterations 5
# Cbc0038I Pass   7: suminf.    1.26613 (4) obj. -193.035 iterations 6
# Cbc0038I Pass   8: suminf.    0.57764 (2) obj. -193.035 iterations 5
# Cbc0038I Pass   9: suminf.    1.23515 (4) obj. -193.035 iterations 6
# Cbc0038I Pass  10: suminf.    0.63207 (2) obj. -193.035 iterations 2
# Cbc0038I Pass  11: suminf.    0.33333 (2) obj. -207.001 iterations 12
# Cbc0038I Pass  12: suminf.    0.90127 (2) obj. -193.035 iterations 4
# Cbc0038I Pass  13: suminf.    2.01923 (6) obj. -193.035 iterations 11
# Cbc0038I Pass  14: suminf.    1.93595 (6) obj. -193.035 iterations 6
# Cbc0038I Pass  15: suminf.    0.78766 (2) obj. -193.035 iterations 9
# Cbc0038I Pass  16: suminf.    0.50000 (2) obj. -205.883 iterations 5
# Cbc0038I Pass  17: suminf.    0.97752 (2) obj. -193.035 iterations 6
# Cbc0038I Pass  18: suminf.    1.12089 (4) obj. -193.035 iterations 6
# Cbc0038I Pass  19: suminf.    0.99658 (4) obj. -193.035 iterations 2
# Cbc0038I Pass  20: suminf.    0.46296 (2) obj. -207.41 iterations 6
# Cbc0038I Pass  21: suminf.    0.95246 (2) obj. -193.035 iterations 6
# Cbc0038I Pass  22: suminf.    1.35216 (6) obj. -193.035 iterations 8
# Cbc0038I Pass  23: suminf.    0.38235 (2) obj. -200.305 iterations 10
# Cbc0038I Pass  24: suminf.    0.61138 (2) obj. -193.035 iterations 7
# Cbc0038I Pass  25: suminf.    0.98148 (2) obj. -196.789 iterations 5
# Cbc0038I Pass  26: suminf.    0.82885 (2) obj. -193.035 iterations 5
# Cbc0038I Pass  27: suminf.    0.99034 (4) obj. -193.035 iterations 9
# Cbc0038I Pass  28: suminf.    0.13605 (2) obj. -195.675 iterations 5
# Cbc0038I Pass  29: suminf.    0.97156 (2) obj. -193.035 iterations 6
# Cbc0038I Pass  30: suminf.    0.76852 (2) obj. -195.466 iterations 6
# Cbc0038I Pass  31: suminf.    0.86738 (2) obj. -193.035 iterations 5
# Cbc0038I Rounding solution of -193.513 is better than previous of -191.149
#
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 9 rows 23 columns
# Cbc0038I Mini branch and bound improved solution from -193.513 to -206.298 (0.01 seconds)
# Cbc0038I Round again with cutoff of -207.041
# Cbc0038I Reduced cost fixing fixed 29 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.29091 (2) obj. -209.781 iterations 4
# Cbc0038I Pass  32: suminf.    0.42304 (2) obj. -207.041 iterations 4
# Cbc0038I Pass  33: suminf.    0.42304 (2) obj. -207.041 iterations 0
# Cbc0038I Pass  34: suminf.    0.42304 (2) obj. -207.041 iterations 0
# Cbc0038I Pass  35: suminf.    0.63324 (4) obj. -207.041 iterations 4
# Cbc0038I Pass  36: suminf.    0.42304 (2) obj. -207.041 iterations 3
# Cbc0038I Pass  37: suminf.    0.49091 (2) obj. -209.063 iterations 5
# Cbc0038I Pass  38: suminf.    0.49091 (2) obj. -209.063 iterations 0
# Cbc0038I Pass  39: suminf.    0.58844 (2) obj. -207.041 iterations 2
# Cbc0038I Pass  40: suminf.    0.29091 (2) obj. -209.781 iterations 2
# Cbc0038I Pass  41: suminf.    0.29091 (2) obj. -209.781 iterations 1
# Cbc0038I Pass  42: suminf.    0.63324 (4) obj. -207.041 iterations 2
# Cbc0038I Pass  43: suminf.    0.74457 (4) obj. -207.041 iterations 1
# Cbc0038I Pass  44: suminf.    0.63324 (4) obj. -207.041 iterations 1
# Cbc0038I Pass  45: suminf.    0.42304 (2) obj. -207.041 iterations 2
# Cbc0038I Pass  46: suminf.    0.83838 (3) obj. -207.041 iterations 5
# Cbc0038I Pass  47: suminf.    0.29091 (2) obj. -207.187 iterations 4
# Cbc0038I Pass  48: suminf.    0.29794 (2) obj. -207.041 iterations 3
# Cbc0038I Pass  49: suminf.    0.73791 (4) obj. -207.041 iterations 3
# Cbc0038I Pass  50: suminf.    0.32727 (2) obj. -208.411 iterations 3
# Cbc0038I Pass  51: suminf.    0.32727 (2) obj. -208.411 iterations 0
# Cbc0038I Pass  52: suminf.    0.39332 (2) obj. -207.041 iterations 3
# Cbc0038I Pass  53: suminf.    0.32727 (2) obj. -208.411 iterations 3
# Cbc0038I Pass  54: suminf.    0.39332 (2) obj. -207.041 iterations 3
# Cbc0038I Pass  55: suminf.    0.66144 (2) obj. -207.041 iterations 2
# Cbc0038I Pass  56: suminf.    0.61369 (3) obj. -207.041 iterations 2
# Cbc0038I Pass  57: suminf.    0.61369 (3) obj. -207.041 iterations 2
# Cbc0038I Pass  58: suminf.    0.66144 (2) obj. -207.041 iterations 4
# Cbc0038I Pass  59: suminf.    0.61369 (3) obj. -207.041 iterations 5
# Cbc0038I Pass  60: suminf.    0.89871 (2) obj. -207.041 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 33 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 3 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -206.298 - took 0.01 seconds
# Cbc0012I Integer solution of -206.29813 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 1 added rows had average density of 5
# Cbc0013I At root node, 1 cuts changed objective from -210.01085 to -206.51697 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 2 column cuts (2 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -206.298130633973, took 6 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 34 variables fixed on reduced cost
# Cuts at root node changed objective from -210.011 to -206.517
# Probing was tried 2 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                206.29813063
# Enumerated nodes:               0
# Total iterations:               6
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/420453ba98d844ac9a1fcfa1fb8fb07d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/420453ba98d844ac9a1fcfa1fb8fb07d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 332 RHS
# At line 364 BOUNDS
# At line 415 ENDATA
# Problem MODEL has 31 rows, 50 columns and 145 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 210.192 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0004I processed model has 22 rows, 42 columns (42 integer (42 of which binary)) and 118 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.455882
# Cbc0038I Pass   1: suminf.    0.28704 (2) obj. -208.756 iterations 6
# Cbc0038I Solution found of -166.633
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -166.633 to -191.149 (0.01 seconds)
# Cbc0038I Round again with cutoff of -193.053
# Cbc0038I Reduced cost fixing fixed 11 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.28704 (2) obj. -208.756 iterations 0
# Cbc0038I Pass   3: suminf.    0.92560 (2) obj. -193.053 iterations 8
# Cbc0038I Pass   4: suminf.    1.04481 (4) obj. -193.053 iterations 10
# Cbc0038I Pass   5: suminf.    0.57735 (2) obj. -193.053 iterations 4
# Cbc0038I Pass   6: suminf.    0.83333 (2) obj. -199.348 iterations 5
# Cbc0038I Pass   7: suminf.    1.29529 (4) obj. -193.053 iterations 6
# Cbc0038I Pass   8: suminf.    0.57838 (2) obj. -193.053 iterations 5
# Cbc0038I Pass   9: suminf.    1.24744 (4) obj. -193.053 iterations 6
# Cbc0038I Pass  10: suminf.    0.63319 (2) obj. -193.053 iterations 2
# Cbc0038I Pass  11: suminf.    0.32407 (2) obj. -207.229 iterations 12
# Cbc0038I Pass  12: suminf.    0.90053 (2) obj. -193.053 iterations 4
# Cbc0038I Pass  13: suminf.    1.97501 (6) obj. -193.053 iterations 11
# Cbc0038I Pass  14: suminf.    1.89776 (6) obj. -193.053 iterations 7
# Cbc0038I Pass  15: suminf.    0.78854 (2) obj. -193.053 iterations 4
# Cbc0038I Pass  16: suminf.    0.49074 (2) obj. -206.111 iterations 5
# Cbc0038I Pass  17: suminf.    0.97826 (2) obj. -193.053 iterations 4
# Cbc0038I Pass  18: suminf.    1.08717 (4) obj. -193.053 iterations 8
# Cbc0038I Pass  19: suminf.    0.96881 (4) obj. -193.053 iterations 4
# Cbc0038I Pass  20: suminf.    0.45370 (2) obj. -207.638 iterations 6
# Cbc0038I Pass  21: suminf.    0.95319 (2) obj. -193.053 iterations 6
# Cbc0038I Pass  22: suminf.    1.34538 (6) obj. -193.053 iterations 7
# Cbc0038I Pass  23: suminf.    0.36765 (2) obj. -200.487 iterations 10
# Cbc0038I Pass  24: suminf.    0.61226 (2) obj. -193.053 iterations 7
# Cbc0038I Pass  25: suminf.    0.99074 (2) obj. -197.016 iterations 5
# Cbc0038I Pass  26: suminf.    0.82958 (2) obj. -193.053 iterations 5
# Cbc0038I Pass  27: suminf.    1.06192 (4) obj. -193.053 iterations 9
# Cbc0038I Pass  28: suminf.    0.12245 (2) obj. -195.841 iterations 5
# Cbc0038I Pass  29: suminf.    0.97244 (2) obj. -193.053 iterations 6
# Cbc0038I Pass  30: suminf.    0.75926 (2) obj. -195.694 iterations 6
# Cbc0038I Pass  31: suminf.    0.86664 (2) obj. -193.053 iterations 5
# Cbc0038I Rounding solution of -193.513 is better than previous of -191.149
#
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 9 rows 23 columns
# Cbc0038I Mini branch and bound improved solution from -193.513 to -206.298 (0.01 seconds)
# Cbc0038I Round again with cutoff of -207.077
# Cbc0038I Reduced cost fixing fixed 29 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.28182 (2) obj. -209.97 iterations 4
# Cbc0038I Pass  32: suminf.    0.42130 (2) obj. -207.077 iterations 4
# Cbc0038I Pass  33: suminf.    0.70848 (2) obj. -207.077 iterations 1
# Cbc0038I Pass  34: suminf.    0.70848 (2) obj. -207.077 iterations 2
# Cbc0038I Pass  35: suminf.    0.58894 (2) obj. -207.077 iterations 3
# Cbc0038I Pass  36: suminf.    0.53204 (4) obj. -207.077 iterations 5
# Cbc0038I Pass  37: suminf.    0.60401 (4) obj. -207.077 iterations 1
# Cbc0038I Pass  38: suminf.    0.53204 (4) obj. -207.077 iterations 1
# Cbc0038I Pass  39: suminf.    1.67720 (4) obj. -207.077 iterations 7
# Cbc0038I Pass  40: suminf.    0.94562 (4) obj. -207.077 iterations 2
# Cbc0038I Pass  41: suminf.    0.56501 (2) obj. -207.077 iterations 3
# Cbc0038I Pass  42: suminf.    0.44545 (2) obj. -209.556 iterations 3
# Cbc0038I Pass  43: suminf.    0.32727 (2) obj. -207.103 iterations 2
# Cbc0038I Pass  44: suminf.    0.32727 (2) obj. -207.103 iterations 0
# Cbc0038I Pass  45: suminf.    0.32853 (2) obj. -207.077 iterations 3
# Cbc0038I Pass  46: suminf.    0.32727 (2) obj. -207.103 iterations 3
# Cbc0038I Pass  47: suminf.    0.32853 (2) obj. -207.077 iterations 3
# Cbc0038I Pass  48: suminf.    0.58824 (2) obj. -208.614 iterations 5
# Cbc0038I Pass  49: suminf.    0.36364 (2) obj. -208.327 iterations 3
# Cbc0038I Pass  50: suminf.    0.42392 (2) obj. -207.077 iterations 3
# Cbc0038I Pass  51: suminf.    0.78353 (4) obj. -207.077 iterations 4
# Cbc0038I Pass  52: suminf.    0.53435 (2) obj. -207.779 iterations 2
# Cbc0038I Pass  53: suminf.    0.71289 (2) obj. -207.077 iterations 3
# Cbc0038I Pass  54: suminf.    0.45802 (2) obj. -207.972 iterations 7
# Cbc0038I Pass  55: suminf.    0.45802 (2) obj. -207.972 iterations 0
# Cbc0038I Pass  56: suminf.    0.65850 (2) obj. -207.077 iterations 4
# Cbc0038I Pass  57: suminf.    0.31818 (2) obj. -208.599 iterations 4
# Cbc0038I Pass  58: suminf.    0.39157 (2) obj. -207.077 iterations 3
# Cbc0038I Pass  59: suminf.    1.34662 (4) obj. -207.077 iterations 2
# Cbc0038I Pass  60: suminf.    1.01494 (4) obj. -207.077 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 3 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -206.298 - took 0.01 seconds
# Cbc0012I Integer solution of -206.29813 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 2 added rows had average density of 6
# Cbc0013I At root node, 2 cuts changed objective from -210.19221 to -206.34119 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 2.2 elements, 2 column cuts (2 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 3 row cuts average 3.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 8 row cuts average 8.9 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -206.298130633973, took 17 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 34 variables fixed on reduced cost
# Cuts at root node changed objective from -210.192 to -206.341
# Probing was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                206.29813063
# Enumerated nodes:               0
# Total iterations:               17
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/034c69607dd1459982150bb1c938ecbd-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/034c69607dd1459982150bb1c938ecbd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 332 RHS
# At line 364 BOUNDS
# At line 415 ENDATA
# Problem MODEL has 31 rows, 50 columns and 145 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 210.374 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0004I processed model has 22 rows, 42 columns (42 integer (42 of which binary)) and 118 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.441176
# Cbc0038I Pass   1: suminf.    0.27778 (2) obj. -208.984 iterations 6
# Cbc0038I Solution found of -166.633
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -166.633 to -191.149 (0.00 seconds)
# Cbc0038I Round again with cutoff of -193.071
# Cbc0038I Reduced cost fixing fixed 11 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.27778 (2) obj. -208.984 iterations 0
# Cbc0038I Pass   3: suminf.    0.92486 (2) obj. -193.071 iterations 8
# Cbc0038I Pass   4: suminf.    1.06111 (4) obj. -193.071 iterations 10
# Cbc0038I Pass   5: suminf.    0.57808 (2) obj. -193.071 iterations 4
# Cbc0038I Pass   6: suminf.    0.84259 (2) obj. -199.576 iterations 5
# Cbc0038I Pass   7: suminf.    1.32445 (4) obj. -193.071 iterations 6
# Cbc0038I Pass   8: suminf.    0.57912 (2) obj. -193.071 iterations 5
# Cbc0038I Pass   9: suminf.    1.25973 (4) obj. -193.071 iterations 6
# Cbc0038I Pass  10: suminf.    0.63431 (2) obj. -193.071 iterations 2
# Cbc0038I Pass  11: suminf.    0.31481 (2) obj. -207.457 iterations 12
# Cbc0038I Pass  12: suminf.    0.89979 (2) obj. -193.071 iterations 4
# ...
# Cbc0038I Pass  15: suminf.    0.12963 (2) obj. -203.561 iterations 3
# Cbc0038I Pass  16: suminf.    1.69233 (4) obj. -193.507 iterations 11
# Cbc0038I Pass  17: suminf.    0.00840 (2) obj. -199.06 iterations 6
# Cbc0038I Pass  18: suminf.    0.30719 (2) obj. -193.507 iterations 4
# Cbc0038I Pass  19: suminf.    0.32754 (2) obj. -193.507 iterations 2
# Cbc0038I Pass  20: suminf.    0.94327 (4) obj. -193.507 iterations 17
# Cbc0038I Pass  21: suminf.    0.76607 (3) obj. -193.507 iterations 6
# Cbc0038I Pass  22: suminf.    0.79093 (2) obj. -193.507 iterations 3
# Cbc0038I Pass  23: suminf.    1.14977 (4) obj. -193.507 iterations 8
# Cbc0038I Pass  24: suminf.    0.20370 (2) obj. -197.619 iterations 5
# Cbc0038I Pass  25: suminf.    0.37093 (2) obj. -193.507 iterations 4
# Cbc0038I Pass  26: suminf.    1.04712 (4) obj. -193.507 iterations 4
# Cbc0038I Pass  27: suminf.    1.89513 (6) obj. -193.507 iterations 5
# Cbc0038I Pass  28: suminf.    0.03242 (2) obj. -193.507 iterations 5
# Cbc0038I Pass  29: suminf.    0.65741 (2) obj. -201.298 iterations 5
# Cbc0038I Pass  30: suminf.    0.34056 (2) obj. -193.507 iterations 4
# Cbc0038I Pass  31: suminf.    0.70130 (3) obj. -193.507 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 9 rows 23 columns
# Cbc0038I Mini branch and bound improved solution from -191.149 to -210.842 (0.01 seconds)
# Cbc0038I Round again with cutoff of -211.619
# Cbc0038I Reduced cost fixing fixed 29 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.05455 (2) obj. -214.683 iterations 2
# Cbc0038I Pass  32: suminf.    0.20230 (2) obj. -211.619 iterations 3
# Cbc0038I Pass  33: suminf.    1.40718 (4) obj. -211.619 iterations 2
# Cbc0038I Pass  34: suminf.    1.27562 (4) obj. -211.619 iterations 1
# Cbc0038I Pass  35: suminf.    0.75455 (2) obj. -212.603 iterations 3
# Cbc0038I Pass  36: suminf.    0.70707 (2) obj. -211.619 iterations 3
# Cbc0038I Pass  37: suminf.    0.70707 (2) obj. -211.619 iterations 0
# Cbc0038I Pass  38: suminf.    0.95481 (3) obj. -211.619 iterations 3
# Cbc0038I Pass  39: suminf.    0.70707 (2) obj. -211.619 iterations 3
# Cbc0038I Pass  40: suminf.    0.70707 (2) obj. -211.619 iterations 0
# Cbc0038I Pass  41: suminf.    0.21818 (2) obj. -211.675 iterations 6
# Cbc0038I Pass  42: suminf.    0.21818 (2) obj. -211.675 iterations 0
# Cbc0038I Pass  43: suminf.    0.22091 (2) obj. -211.619 iterations 3
# Cbc0038I Pass  44: suminf.    0.21818 (2) obj. -211.675 iterations 3
# Cbc0038I Pass  45: suminf.    0.22091 (2) obj. -211.619 iterations 3
# Cbc0038I Pass  46: suminf.    0.93599 (4) obj. -211.619 iterations 6
# Cbc0038I Pass  47: suminf.    0.93599 (4) obj. -211.619 iterations 0
# Cbc0038I Pass  48: suminf.    0.17258 (2) obj. -211.619 iterations 3
# Cbc0038I Pass  49: suminf.    0.09091 (2) obj. -213.313 iterations 3
# Cbc0038I Pass  50: suminf.    1.21834 (4) obj. -211.619 iterations 4
# Cbc0038I Pass  51: suminf.    1.06637 (4) obj. -211.619 iterations 1
# Cbc0038I Pass  52: suminf.    0.05455 (2) obj. -214.683 iterations 2
# Cbc0038I Pass  53: suminf.    0.20230 (2) obj. -211.619 iterations 3
# Cbc0038I Pass  54: suminf.    0.20230 (2) obj. -211.619 iterations 0
# Cbc0038I Pass  55: suminf.    0.34021 (2) obj. -211.619 iterations 2
# Cbc0038I Pass  56: suminf.    0.15455 (2) obj. -212.397 iterations 4
# Cbc0038I Pass  57: suminf.    0.15455 (2) obj. -212.397 iterations 0
# Cbc0038I Pass  58: suminf.    0.19206 (2) obj. -211.619 iterations 3
# Cbc0038I Pass  59: suminf.    0.05455 (2) obj. -214.683 iterations 6
# Cbc0038I Pass  60: suminf.    0.06299 (2) obj. -211.619 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 3 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -210.842 - took 0.01 seconds
# Cbc0012I Integer solution of -210.84195 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 3 added rows had average density of 7.6666667
# Cbc0013I At root node, 12 cuts changed objective from -214.72633 to -210.84195 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 7.5 elements, 4 column cuts (4 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 4 row cuts average 4.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 10 row cuts average 7.9 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -210.841947984149, took 7 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 29 variables fixed on reduced cost
# Cuts at root node changed objective from -214.726 to -210.842
# Probing was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 3 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 3 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                210.84194798
# Enumerated nodes:               0
# Total iterations:               7
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/56e82b9a723a4bd3b48f97eacb32b871-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/my/tc78stk53_j2yhw59qmmh3b00000gn/T/56e82b9a723a4bd3b48f97eacb32b871-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 332 RHS
# At line 364 BOUNDS
# At line 415 ENDATA
# Problem MODEL has 31 rows, 50 columns and 145 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 214.908 - 0.00 seconds
# Cgl0002I 5 variables fixed
# Cgl0004I processed model has 22 rows, 42 columns (42 integer (42 of which binary)) and 118 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.0735294
# Cbc0038I Pass   1: suminf.    0.04630 (2) obj. -214.676 iterations 3
# Cbc0038I Solution found of -166.633
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -166.633 to -191.149 (0.00 seconds)
# Cbc0038I Round again with cutoff of -193.525
# Cbc0038I Reduced cost fixing fixed 11 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.04630 (2) obj. -214.676 iterations 0
# Cbc0038I Pass   3: suminf.    0.90642 (2) obj. -193.525 iterations 2
# Cbc0038I Pass   4: suminf.    0.67465 (4) obj. -193.525 iterations 4
# Cbc0038I Pass   5: suminf.    0.59942 (4) obj. -193.525 iterations 1
# Cbc0038I Pass   6: suminf.    0.99074 (2) obj. -206.145 iterations 3
# Cbc0038I Pass   7: suminf.    0.47752 (2) obj. -193.525 iterations 3
# Cbc0038I Pass   8: suminf.    1.24179 (4) obj. -193.525 iterations 6
# Cbc0038I Pass   9: suminf.    0.48726 (2) obj. -193.525 iterations 4
# Cbc0038I Pass  10: suminf.    0.88889 (2) obj. -203.428 iterations 4
# Cbc0038I Pass  11: suminf.    0.48616 (2) obj. -193.525 iterations 3
# Cbc0038I Pass  12: suminf.    0.83093 (2) obj. -193.525 iterations 9
# Cbc0038I Pass  13: suminf.    0.15455 (2) obj. -195.841 iterations 3
# Cbc0038I Pass  14: suminf.    0.53774 (2) obj. -193.525 iterations 5
# Cbc0038I Pass  15: suminf.    0.12037 (2) obj. -203.788 iterations 3
# Cbc0038I Pass  16: suminf.    1.68695 (4) obj. -193.525 iterations 8
# Cbc0038I Solution found of -199.216
# Cbc0038I Before mini branch and bound, 23 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 7 rows 19 columns
# Cbc0038I Mini branch and bound improved solution from -199.216 to -213.768 (0.01 seconds)
# Cbc0038I Round again with cutoff of -213.996
# Cbc0038I Reduced cost fixing fixed 34 variables on major pass 3
# Cbc0038I Pass  17: suminf.    0.07353 (2) obj. -214.908 iterations 3
# Cbc0038I Pass  18: suminf.    0.14745 (2) obj. -213.996 iterations 3
# Cbc0038I Pass  19: suminf.    0.39706 (2) obj. -214.348 iterations 3
# Cbc0038I Pass  20: suminf.    0.39706 (2) obj. -214.348 iterations 0
# Cbc0038I Pass  21: suminf.    0.42558 (2) obj. -213.996 iterations 2
# Cbc0038I Pass  22: suminf.    0.38912 (2) obj. -213.996 iterations 3
# Cbc0038I Pass  23: suminf.    0.33824 (2) obj. -214.624 iterations 2
# Cbc0038I Pass  24: suminf.    0.38912 (2) obj. -213.996 iterations 2
# Cbc0038I Pass  25: suminf.    0.33824 (2) obj. -214.624 iterations 2
# Cbc0038I Pass  26: suminf.    0.38912 (2) obj. -213.996 iterations 2
# Cbc0038I Pass  27: suminf.    0.33824 (2) obj. -214.624 iterations 2
# Cbc0038I Pass  28: suminf.    0.33824 (2) obj. -214.624 iterations 0
# Cbc0038I Pass  29: suminf.    0.07353 (2) obj. -214.908 iterations 2
# Cbc0038I Pass  30: suminf.    0.07353 (2) obj. -214.908 iterations 0
# Cbc0038I Pass  31: suminf.    0.14745 (2) obj. -213.996 iterations 3
# Cbc0038I Pass  32: suminf.    0.07353 (2) obj. -214.908 iterations 3
# Cbc0038I Pass  33: suminf.    0.14745 (2) obj. -213.996 iterations 3
# Cbc0038I Pass  34: suminf.    0.42558 (2) obj. -213.996 iterations 1
# Cbc0038I Pass  35: suminf.    0.39706 (2) obj. -214.348 iterations 2
# Cbc0038I Pass  36: suminf.    0.42558 (2) obj. -213.996 iterations 2
# Cbc0038I Pass  37: suminf.    0.39706 (2) obj. -214.348 iterations 2
# Cbc0038I Pass  38: suminf.    0.39706 (2) obj. -214.348 iterations 0
# Cbc0038I Pass  39: suminf.    0.33824 (2) obj. -214.624 iterations 1
# Cbc0038I Pass  40: suminf.    0.33824 (2) obj. -214.624 iterations 1
# Cbc0038I Pass  41: suminf.    0.38912 (2) obj. -213.996 iterations 3
# Cbc0038I Pass  42: suminf.    0.38912 (2) obj. -213.996 iterations 1
# Cbc0038I Pass  43: suminf.    0.38912 (2) obj. -213.996 iterations 2
# Cbc0038I Pass  44: suminf.    0.33824 (2) obj. -214.624 iterations 2
# Cbc0038I Pass  45: suminf.    0.38912 (2) obj. -213.996 iterations 2
# Cbc0038I Pass  46: suminf.    0.33824 (2) obj. -214.624 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 37 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 22 rows 42 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -213.768 - took 0.01 seconds
# Cbc0012I Integer solution of -213.76819 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -214.90769 to -214.90769 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -213.768193907433, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 33 variables fixed on reduced cost
# Cuts at root node changed objective from -214.908 to -214.908
# Probing was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                213.76819391
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#                 driver 1  driver 2   driver 3 driver 4  driver 5 turbo driver  \
# budget range
# 100.0-100.2   Verstappen    Alonso      Albon   Bottas  Sargeant   Verstappen
# 100.3-101.1   Verstappen    Alonso      Albon     Zhou    Bottas   Verstappen
# 101.2-101.5   Verstappen    Alonso  Magnussen    Albon    Bottas   Verstappen
# 101.6-101.6   Verstappen    Alonso    Tsunoda    Albon    Bottas   Verstappen
# 101.7-102.0   Verstappen  Hamilton       Zhou   Bottas  Sargeant   Verstappen
# 102.1-102.9   Verstappen  Hamilton      Albon   Bottas  Sargeant   Verstappen
# 103.0-103     Verstappen  Hamilton      Albon     Zhou    Bottas   Verstappen
#
#                             team          EV
# budget range
# 100.0-100.2   [Red Bull, Sauber]  203.371885
# 100.3-101.1   [Red Bull, Sauber]  206.298131
# 101.2-101.5   [Red Bull, Sauber]  206.352461
# 101.6-101.6   [Red Bull, Sauber]  206.802054
# 101.7-102.0   [Red Bull, Sauber]  208.863775
# 102.1-102.9   [Red Bull, Sauber]  210.841948
# 103.0-103     [Red Bull, Sauber]  213.768194

# %% [markdown]
# The accuracy of the model is difficult to test. Fantasy F1 is extremely high-variance, and there is no data available to back-test. There is also no hindsight metric available to reduce noise, such as xG can be used for football. Initial results are positive though; so far this season I am in the top 2.5% of players, despite lacking anything beyond a very novice knowledge of F1.
